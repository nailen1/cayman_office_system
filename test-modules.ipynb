# %%
from cayman_office_system import *
# Out:
# INFO:shining_pebbles:Shining Pebbles package initialized
# INFO:numexpr.utils:Note: NumExpr detected 10 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# /Users/juneyoungpark/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# # Order

# %%
ord = Order(index=0)
# Out:
# - open: Life Asset trade instruction 20240902.xlsx in /Users/juneyoungpark/dev/module-cayman_office_system/cayman_office_system/dataset-order
# - order date: 2024-09-02

# %%
ord.df
# Out:
#                ticker  amount        ticker_bbg
# date
# 2024-09-02  007340 KS    2500  007340 KS Equity
# 2024-09-02  282690 KS    2500  282690 KS Equity
# 2024-09-02  003030 KS     900  003030 KS Equity
# 2024-09-02  271560 KS    2200  271560 KS Equity

# %%
ord.equities
# Out:
# 2024-09-23        name_kr                          name market_index  \
# ticker_bbg
# 003030 KS Equity   세아제강지주      SEAH STEEL HOLDINGS CORP  KOSPI Index
# 007340 KS Equity  DN오토모티브            DN AUTOMOTIVE CORP  KOSPI Index
# 271560 KS Equity      오리온  ORION CORP/REPUBLIC OF KOREA  KOSPI Index
# 282690 KS Equity    동아타이어  DONG AH TIRE & RUBBER CO LTD  KOSPI Index
#
# 2024-09-23                        sector  cap(/1e8)  price_last
# ticker_bbg
# 003030 KS Equity               Materials     7546.0    182200.0
# 007340 KS Equity  Consumer Discretionary    10113.0    101200.0
# 271560 KS Equity        Consumer Staples    36998.0     93600.0
# 282690 KS Equity  Consumer Discretionary     1853.0     13500.0

# %%
ord.info
# Out:
#                ticker  name_kr                          name  amount  \
# date
# 2024-09-02  007340 KS  DN오토모티브            DN AUTOMOTIVE CORP    2500
# 2024-09-02  282690 KS    동아타이어  DONG AH TIRE & RUBBER CO LTD    2500
# 2024-09-02  003030 KS   세아제강지주      SEAH STEEL HOLDINGS CORP     900
# 2024-09-02  271560 KS      오리온  ORION CORP/REPUBLIC OF KOREA    2200
#
#             price_acquisition_approx  price_last  return_approx  \
# date
# 2024-09-02                     88200    101200.0      14.739229
# 2024-09-02                     13040     13500.0       3.527607
# 2024-09-02                    176200    182200.0       3.405221
# 2024-09-02                     91300     93600.0       2.519168
#
#             acquisition_approx_krw  evaluation_krw  acquisition_approx_usd  \
# date
# 2024-09-02               220500000     253000000.0           164755.108903
# 2024-09-02                32600000      33750000.0            24358.351702
# ...

# %% [markdown]
# # Trade

# %%
trd = Trade(index=-1)
# Out:
# - set (date, index) = (2024-09-20, -1)
# - net_amount: 1931465216.0

# %%
trd.df
# Out:
#          date                 name     ticker type  num_shares  average_price  \
# 0  2024-09-20             SK hynix  000660 KS  Buy         800  157177.625000
# 1  2024-09-20  SeAH Steel Holdings  003030 KS  Buy        1200  185050.583333
# 2  2024-09-20           DongwonInd  006040 KS  Buy        2500   30808.260000
# 3  2024-09-20        DN AUTOMOTIVE  007340 KS  Buy        4500  102093.444444
# 4  2024-09-20              TKCORP.  023160 KS  Buy       15000   14427.932667
# 5  2024-09-20                ORION  271560 KS  Buy        6000   90870.500000
# 6  2024-09-20  WooriFinancialGroup  316140 KS  Buy       18000   15758.318889
#
#    consideration  commission   net_amount
# 0    125742100.0      125742  125867842.0
# 1    222060700.0      222061  222282761.0
# 2     77020650.0       77021   77097671.0
# 3    459420500.0      459420  459879920.0
# 4    216418990.0      216419  216635409.0
# 5    545223000.0      545223  545768223.0
# 6    283649740.0      283650  283933390.0

# %%
trd.data
# Out:
# [{'date': '2024-09-20', 'ticker': '000660 KS', 'num_shares': 800},
#  {'date': '2024-09-20', 'ticker': '003030 KS', 'num_shares': 1200},
#  {'date': '2024-09-20', 'ticker': '006040 KS', 'num_shares': 2500},
#  {'date': '2024-09-20', 'ticker': '007340 KS', 'num_shares': 4500},
#  {'date': '2024-09-20', 'ticker': '023160 KS', 'num_shares': 15000},
#  {'date': '2024-09-20', 'ticker': '271560 KS', 'num_shares': 6000},
#  {'date': '2024-09-20', 'ticker': '316140 KS', 'num_shares': 18000}]

# %%
trd.amount
# Out:
# {'date': '2024-09-20', 'amount_order': 1931465216.0}

# %%
trd.raws_transaction[0]
# Out:
#                 Unnamed: 0 Unnamed: 1 Unnamed: 2              Unnamed: 3  \
# 20                    Type        NaN        NaN                     KSE
# 21  ISIN Code / Abbr. Code        NaN        NaN  KR7000660001 / A000660
# 22    Security Description        NaN        NaN                SK hynix
# 23                     NaN        NaN        NaN                     NaN
# 24   No. of Shares / Price        NaN        NaN                     NaN
# 25                     NaN        NaN        NaN                     NaN
# 26                     NaN        NaN        NaN                     NaN
# 27                     NaN        NaN        NaN                     NaN
# 28                     NaN        NaN        NaN                     NaN
# 29                     NaN        NaN        NaN                     NaN
# 30                     NaN        NaN        NaN                     NaN
# 31                     NaN        NaN        NaN                     NaN
# ...

# %% [markdown]
# # Transaction

# %%
transaction = trd.transactions[0]

# %%
transaction.data_raw
# Out:
# {'Type': ['KSE', 'Buy'],
#  'ISIN Code / Abbr. Code': ['KR7000660001 / A000660'],
#  'Security Description': ['SK hynix'],
#  'Total No. of Shares': ['Shs', 800],
#  'Average Price': ['KRW', 157177.625],
#  'Considerations': ['KRW', 125742100],
#  'Commission': ['KRW', 125742],
#  'Sales Tax': ['KRW', 0],
#  'Capital Gains Tax': ['KRW', 0],
#  'Net Amount': ['KRW', 125867842]}

# %%
transaction.df
# Out:
#                ticker num_shares currency  price_executed      amount
# date
# 2024-09-20  000660 KS         10   /  KRW        156400.0   1564000.0
# 2024-09-20  000660 KS         34   /  KRW        156500.0   5321000.0
# 2024-09-20  000660 KS         75   /  KRW        156600.0  11745000.0
# 2024-09-20  000660 KS         71   /  KRW        156700.0  11125700.0
# 2024-09-20  000660 KS         98   /  KRW        156800.0  15366400.0
# 2024-09-20  000660 KS         33   /  KRW        156900.0   5177700.0
# 2024-09-20  000660 KS         16   /  KRW        157000.0   2512000.0
# 2024-09-20  000660 KS        193   /  KRW        157100.0  30320300.0
# 2024-09-20  000660 KS         21   /  KRW        157200.0   3301200.0
# 2024-09-20  000660 KS         23   /  KRW        157300.0   3617900.0
# 2024-09-20  000660 KS         12   /  KRW        157400.0   1888800.0
# 2024-09-20  000660 KS          8   /  KRW        157500.0   1260000.0
# ...

# %%
transaction.data
# Out:
# {'date': '2024-09-20',
#  'name': 'SK hynix',
#  'ticker': '000660 KS',
#  'type': 'Buy',
#  'num_shares': 800,
#  'average_price': 157177.625,
#  'consideration': 125742100.0,
#  'commission': 125742,
#  'net_amount': 125867842.0}

# %%
transaction.show_info()
# Out:
# Check Identity of Data: (system) == (calculated)
# - num_shares: 800 == 800
# - consideration: 125742100 == 125742100.0
# - commission: 125742 == 125742
# - average_price: 157177.625 == 157177.625
# - net_amount: 125867842 == 125867842.0
# {'date': '2024-09-20', 'name': 'SK hynix', 'ticker': '000660 KS', 'type': 'Buy', 'num_shares': 800, 'average_price': 157177.625, 'consideration': 125742100.0, 'commission': 125742, 'net_amount': 125867842.0}
#                ticker num_shares currency  price_executed      amount
# date
# 2024-09-20  000660 KS         10   /  KRW        156400.0   1564000.0
# 2024-09-20  000660 KS         34   /  KRW        156500.0   5321000.0
# 2024-09-20  000660 KS         75   /  KRW        156600.0  11745000.0
# 2024-09-20  000660 KS         71   /  KRW        156700.0  11125700.0
# 2024-09-20  000660 KS         98   /  KRW        156800.0  15366400.0
# 2024-09-20  000660 KS         33   /  KRW        156900.0   5177700.0
# ...

# %% [markdown]
# # Trades

# %%
trades = Trades()
# Out:
# - set (date, index) = (2024-09-02, None)
# - net_amount: 614581438.0
# - set (date, index) = (2024-09-05, None)
# - net_amount: 529470241.0
# - set (date, index) = (2024-09-06, None)
# - net_amount: 91060069.0
# - set (date, index) = (2024-09-09, None)
# - net_amount: 384482599.0
# - set (date, index) = (2024-09-10, None)
# - net_amount: 625076151.0
# - set (date, index) = (2024-09-12, None)
# - net_amount: 528686258.0
# - set (date, index) = (2024-09-13, None)
# - net_amount: 519691172.0
# - set (date, index) = (2024-09-19, None)
# - net_amount: 727234488.0
# - set (date, index) = (2024-09-20, None)
# - net_amount: 1931465216.0

# %%
trades.history
# Out:
#           date                 name     ticker type  num_shares  \
# 0   2024-09-02  SeAH Steel Holdings  003030 KS  Buy         900
# 1   2024-09-02        DN AUTOMOTIVE  007340 KS  Buy        2500
# 2   2024-09-02                ORION  271560 KS  Buy        2200
# 3   2024-09-02         DONG AH TIRE  282690 KS  Buy        2500
# 4   2024-09-05  SeAH Steel Holdings  003030 KS  Buy         800
# 5   2024-09-05        DN AUTOMOTIVE  007340 KS  Buy        2500
# 6   2024-09-05                ORION  271560 KS  Buy        1800
# 7   2024-09-06        DN AUTOMOTIVE  007340 KS  Buy        1000
# 8   2024-09-09  SeAH Steel Holdings  003030 KS  Buy         500
# 9   2024-09-09        DN AUTOMOTIVE  007340 KS  Buy        2231
# 10  2024-09-09                ORION  271560 KS  Buy        1000
# 11  2024-09-10             SK hynix  000660 KS  Buy        1200
# 12  2024-09-10  SeAH Steel Holdings  003030 KS  Buy         200
# 13  2024-09-10        DN AUTOMOTIVE  007340 KS  Buy        3500
# ...

# %%
trades.pl
# Out:
#           date     ticker                          name  num_shares  \
# 0   2024-09-02  003030 KS      SEAH STEEL HOLDINGS CORP         900
# 1   2024-09-02  007340 KS            DN AUTOMOTIVE CORP        2500
# 2   2024-09-02  271560 KS  ORION CORP/REPUBLIC OF KOREA        2200
# 3   2024-09-02  282690 KS  DONG AH TIRE & RUBBER CO LTD        2500
# 4   2024-09-05  003030 KS      SEAH STEEL HOLDINGS CORP         800
# 5   2024-09-05  007340 KS            DN AUTOMOTIVE CORP        2500
# 6   2024-09-05  271560 KS  ORION CORP/REPUBLIC OF KOREA        1800
# 7   2024-09-06  007340 KS            DN AUTOMOTIVE CORP        1000
# 8   2024-09-09  003030 KS      SEAH STEEL HOLDINGS CORP         500
# 9   2024-09-09  007340 KS            DN AUTOMOTIVE CORP        2231
# 10  2024-09-09  271560 KS  ORION CORP/REPUBLIC OF KOREA        1000
# 11  2024-09-10  000660 KS                  SK HYNIX INC        1200
# 12  2024-09-10  003030 KS      SEAH STEEL HOLDINGS CORP         200
# ...

# %%
trades_of_half = Trades(start_date='2024-09-15')
trades_of_half.history
# Out:
# - set (date, index) = (2024-09-19, None)
# - net_amount: 727234488.0
# - set (date, index) = (2024-09-20, None)
# - net_amount: 1931465216.0
#           date                 name     ticker type  num_shares  \
# 0   2024-09-19  SeAH Steel Holdings  003030 KS  Buy         699
# 1   2024-09-19        DN AUTOMOTIVE  007340 KS  Buy        1500
# 2   2024-09-19              TKCORP.  023160 KS  Buy        8500
# 3   2024-09-19                ORION  271560 KS  Buy        2000
# 4   2024-09-19  WooriFinancialGroup  316140 KS  Buy       10000
# 5   2024-09-20             SK hynix  000660 KS  Buy         800
# 6   2024-09-20  SeAH Steel Holdings  003030 KS  Buy        1200
# 7   2024-09-20           DongwonInd  006040 KS  Buy        2500
# 8   2024-09-20        DN AUTOMOTIVE  007340 KS  Buy        4500
# 9   2024-09-20              TKCORP.  023160 KS  Buy       15000
# 10  2024-09-20                ORION  271560 KS  Buy        6000
# ...

# %%
trades_of_half.pl
# Out:
#           date     ticker                          name  num_shares  \
# 0   2024-09-19  003030 KS      SEAH STEEL HOLDINGS CORP         699
# 1   2024-09-19  007340 KS            DN AUTOMOTIVE CORP        1500
# 2   2024-09-19  023160 KS                TK CORPORATION        8500
# 3   2024-09-19  271560 KS  ORION CORP/REPUBLIC OF KOREA        2000
# 4   2024-09-19  316140 KS     WOORI FINANCIAL GROUP INC       10000
# 5   2024-09-20  000660 KS                  SK HYNIX INC         800
# 6   2024-09-20  003030 KS      SEAH STEEL HOLDINGS CORP        1200
# 7   2024-09-20  006040 KS     DONGWON INDUSTRIES CO LTD        2500
# 8   2024-09-20  007340 KS            DN AUTOMOTIVE CORP        4500
# 9   2024-09-20  023160 KS                TK CORPORATION       15000
# 10  2024-09-20  271560 KS  ORION CORP/REPUBLIC OF KOREA        6000
# 11  2024-09-20  316140 KS     WOORI FINANCIAL GROUP INC       18000
#
#     price_average  price_last   net_amount   evaluation          pl    return
# ...

# %% [markdown]
# # Holdings

# %%
holdings = Holdings()
# Out:
# - set (date, index) = (2024-09-02, None)
# - net_amount: 614581438.0
# - set (date, index) = (2024-09-05, None)
# - net_amount: 529470241.0
# - set (date, index) = (2024-09-06, None)
# - net_amount: 91060069.0
# - set (date, index) = (2024-09-09, None)
# - net_amount: 384482599.0
# - set (date, index) = (2024-09-10, None)
# - net_amount: 625076151.0
# - set (date, index) = (2024-09-12, None)
# - net_amount: 528686258.0
# - set (date, index) = (2024-09-13, None)
# - net_amount: 519691172.0
# - set (date, index) = (2024-09-19, None)
# - net_amount: 727234488.0
# - set (date, index) = (2024-09-20, None)
# - net_amount: 1931465216.0

# %%
holdings.list
# Out:
#                                    name  num_shares    net_amount  \
# ticker
# 007340 KS            DN AUTOMOTIVE CORP       20731  1.948792e+09
# 271560 KS  ORION CORP/REPUBLIC OF KOREA       16800  1.513383e+09
# 003030 KS      SEAH STEEL HOLDINGS CORP        4999  8.905191e+08
# 000660 KS                  SK HYNIX INC        4400  7.116224e+08
# 316140 KS     WOORI FINANCIAL GROUP INC       28000  4.413804e+08
# 023160 KS                TK CORPORATION       23500  3.364008e+08
# 006040 KS     DONGWON INDUSTRIES CO LTD        2500  7.709767e+07
# 282690 KS  DONG AH TIRE & RUBBER CO LTD        2500  3.255249e+07
#
#              evaluation           pl    return
# ticker
# 007340 KS  2.097977e+09  149185655.0  7.655291
# 271560 KS  1.572480e+09   59096830.0  3.904948
# 003030 KS  9.108178e+08   20298670.0  2.279420
# 000660 KS  7.128000e+08    1177589.0  0.165479
# 316140 KS  4.398800e+08   -1500400.0 -0.339934
# 023160 KS  3.433350e+08    6934185.0  2.061287
# ...

# %%
holdings.pl
# Out:
#                                    name  num_shares    net_amount  \
# ticker
# 000660 KS                  SK HYNIX INC        4400  7.116224e+08
# 003030 KS      SEAH STEEL HOLDINGS CORP        4999  8.905191e+08
# 006040 KS     DONGWON INDUSTRIES CO LTD        2500  7.709767e+07
# 007340 KS            DN AUTOMOTIVE CORP       20731  1.948792e+09
# 023160 KS                TK CORPORATION       23500  3.364008e+08
# 271560 KS  ORION CORP/REPUBLIC OF KOREA       16800  1.513383e+09
# 282690 KS  DONG AH TIRE & RUBBER CO LTD        2500  3.255249e+07
# 316140 KS     WOORI FINANCIAL GROUP INC       28000  4.413804e+08
#
#              evaluation           pl  price_average  price_last    return
# ticker
# 000660 KS  7.128000e+08    1177589.0  161732.366136    162000.0  0.165479
# 003030 KS  9.108178e+08   20298670.0  178139.453891    182200.0  2.279420
# 006040 KS  7.875000e+07    1652329.0   30839.068400     31500.0  2.143163
# ...

# %% [markdown]
# # Account

# %%
account = Account()
# Out:
# - set (date, index) = (2024-09-02, None)
# - net_amount: 614581438.0
# - set (date, index) = (2024-09-05, None)
# - net_amount: 529470241.0
# - set (date, index) = (2024-09-06, None)
# - net_amount: 91060069.0
# - set (date, index) = (2024-09-09, None)
# - net_amount: 384482599.0
# - set (date, index) = (2024-09-10, None)
# - net_amount: 625076151.0
# - set (date, index) = (2024-09-12, None)
# - net_amount: 528686258.0
# - set (date, index) = (2024-09-13, None)
# - net_amount: 519691172.0
# - set (date, index) = (2024-09-19, None)
# - net_amount: 727234488.0
# - set (date, index) = (2024-09-20, None)
# - net_amount: 1931465216.0
# - set (date, index) = (2024-09-23, None)
# - net_amount: 726876600.0

# %%
account.equities
# Out:
# 2024-09-23        name_kr                          name  market_index  \
# ticker_bbg
# 000660 KS Equity   SK하이닉스                  SK HYNIX INC   KOSPI Index
# 003030 KS Equity   세아제강지주      SEAH STEEL HOLDINGS CORP   KOSPI Index
# 006040 KS Equity     동원산업     DONGWON INDUSTRIES CO LTD   KOSPI Index
# 007340 KS Equity  DN오토모티브            DN AUTOMOTIVE CORP   KOSPI Index
# 023160 KS Equity       태광                TK CORPORATION  KOSDAQ Index
# 271560 KS Equity      오리온  ORION CORP/REPUBLIC OF KOREA   KOSPI Index
# 282690 KS Equity    동아타이어  DONG AH TIRE & RUBBER CO LTD   KOSPI Index
# 316140 KS Equity   우리금융지주     WOORI FINANCIAL GROUP INC   KOSPI Index
#
# 2024-09-23                        sector  cap(/1e8)  price_last
# ticker_bbg
# 000660 KS Equity  Information Technology  1115556.0    162000.0
# 003030 KS Equity               Materials     7546.0    182200.0
# 006040 KS Equity        Consumer Staples    11346.0     31500.0
# ...

# %%
account.cash
# Out:
#                 cash_usd      cash_krw
# date
# 2024-09-01  1.533081e+07  2.050955e+10
# 2024-09-02  1.487160e+07  1.990340e+10
# 2024-09-05  1.447486e+07  1.931742e+10
# 2024-09-06  1.440665e+07  1.923287e+10
# 2024-09-09  1.411865e+07  1.884839e+10
# 2024-09-10  1.365356e+07  1.835038e+10
# 2024-09-12  1.325961e+07  1.779439e+10
# 2024-09-13  1.286990e+07  1.716266e+10
# 2024-09-19  1.232272e+07  1.637751e+10
# 2024-09-20  1.086945e+07  1.444604e+10
# 2024-09-23  1.032253e+07  1.371916e+10

# %%
account.stock
# Out:
#                stock_usd     stock_krw
# date
# 2024-09-02  4.576830e+05  6.125400e+08
# 2024-09-03  4.668492e+05  6.264650e+08
# 2024-09-04  4.586597e+05  6.125400e+08
# 2024-09-05  8.602900e+05  1.148100e+09
# 2024-09-06  9.215730e+05  1.230300e+09
# 2024-09-09  1.226554e+06  1.637450e+09
# 2024-09-10  1.637297e+06  2.200527e+09
# 2024-09-11  1.659073e+06  2.223656e+09
# 2024-09-12  2.102452e+06  2.821491e+09
# 2024-09-13  2.472397e+06  3.297064e+09
# 2024-09-19  3.067076e+06  4.076298e+09
# 2024-09-20  4.633999e+06  6.158816e+09
# 2024-09-23  5.204300e+06  6.916775e+09

# %%
account.nav
# Out:
#                 cash_usd      cash_krw     stock_usd     stock_krw  \
# date
# 2024-09-01  1.533081e+07  2.050955e+10  0.000000e+00  0.000000e+00
# 2024-09-02  1.487160e+07  1.990340e+10  4.576830e+05  6.125400e+08
# 2024-09-03  1.487160e+07  1.990340e+10  4.668492e+05  6.264650e+08
# 2024-09-04  1.487160e+07  1.990340e+10  4.586597e+05  6.125400e+08
# 2024-09-05  1.447486e+07  1.931742e+10  8.602900e+05  1.148100e+09
# 2024-09-06  1.440665e+07  1.923287e+10  9.215730e+05  1.230300e+09
# 2024-09-09  1.411865e+07  1.884839e+10  1.226554e+06  1.637450e+09
# 2024-09-10  1.365356e+07  1.835038e+10  1.637297e+06  2.200527e+09
# 2024-09-11  1.365356e+07  1.835038e+10  1.659073e+06  2.223656e+09
# 2024-09-12  1.325961e+07  1.779439e+10  2.102452e+06  2.821491e+09
# 2024-09-13  1.286990e+07  1.716266e+10  2.472397e+06  3.297064e+09
# 2024-09-19  1.232272e+07  1.637751e+10  3.067076e+06  4.076298e+09
# 2024-09-20  1.086945e+07  1.444604e+10  4.633999e+06  6.158816e+09
# ...

# %%
account.get_timeseries_nav(currency='USD')
# Out:
#                 cash_usd     stock_usd       nav_usd  weight_cash  \
# date
# 2024-09-01  1.533081e+07  0.000000e+00  1.533081e+07   100.000000
# 2024-09-02  1.487160e+07  4.576830e+05  1.532928e+07    97.014322
# 2024-09-03  1.487160e+07  4.668492e+05  1.533845e+07    96.956346
# 2024-09-04  1.487160e+07  4.586597e+05  1.533026e+07    97.008141
# 2024-09-05  1.447486e+07  8.602900e+05  1.533515e+07    94.390077
# 2024-09-06  1.440665e+07  9.215730e+05  1.532822e+07    93.987736
# 2024-09-09  1.411865e+07  1.226554e+06  1.534520e+07    92.006918
# 2024-09-10  1.365356e+07  1.637297e+06  1.529086e+07    89.292314
# 2024-09-11  1.365356e+07  1.659073e+06  1.531263e+07    89.165330
# 2024-09-12  1.325961e+07  2.102452e+06  1.536206e+07    86.313993
# 2024-09-13  1.286990e+07  2.472397e+06  1.534230e+07    83.885095
# 2024-09-19  1.232272e+07  3.067076e+06  1.538979e+07    80.070711
# 2024-09-20  1.086945e+07  4.633999e+06  1.550345e+07    70.109882
# ...

# %%
account.latest
# Out:
# cash_usd            1.032253e+07
# cash_krw            1.371916e+10
# stock_usd           5.204300e+06
# stock_krw           6.916775e+09
# nav_usd             1.552683e+07
# nav_krw             2.063594e+10
# weight_cash         6.648190e+01
# weight_stock        3.351810e+01
# total_net_amount    6.678624e+09
# total_evaluation    6.916775e+09
# total_pl            2.381508e+08
# total_return        1.217448e+00
# Name: 2024-09-23, dtype: float64

# %%
account.weights
# Out:
#                                    name  num_shares    net_amount  \
# ticker
# 007340 KS            DN AUTOMOTIVE CORP       22731  2.150405e+09
# 271560 KS  ORION CORP/REPUBLIC OF KOREA       19000  1.719339e+09
# 003030 KS      SEAH STEEL HOLDINGS CORP        5249  9.365943e+08
# 000660 KS                  SK HYNIX INC        5000  8.086596e+08
# 316140 KS     WOORI FINANCIAL GROUP INC       30000  4.727161e+08
# 023160 KS                TK CORPORATION       28000  4.024836e+08
# 006040 KS     DONGWON INDUSTRIES CO LTD        5000  1.558748e+08
# 282690 KS  DONG AH TIRE & RUBBER CO LTD        2500  3.255249e+07
#
#              evaluation           pl  price_average  price_last    return  \
# ticker
# 007340 KS  2.300377e+09  149972443.0   94602.294532    101200.0  6.974150
# 271560 KS  1.778400e+09   59061280.0   90491.511579     93600.0  3.435116
# 003030 KS  9.563678e+08   19773541.0  178432.893694    182200.0  2.111217
# ...

# %%
account.nav
# Out:
#                 cash_usd      cash_krw     stock_usd     stock_krw  \
# date
# 2024-09-01  1.533081e+07  2.050955e+10  0.000000e+00  0.000000e+00
# 2024-09-02  1.487160e+07  1.990340e+10  4.576830e+05  6.125400e+08
# 2024-09-03  1.487160e+07  1.990340e+10  4.668492e+05  6.264650e+08
# 2024-09-04  1.487160e+07  1.990340e+10  4.586597e+05  6.125400e+08
# 2024-09-05  1.447486e+07  1.931742e+10  8.602900e+05  1.148100e+09
# 2024-09-06  1.440665e+07  1.923287e+10  9.215730e+05  1.230300e+09
# 2024-09-09  1.411865e+07  1.884839e+10  1.226554e+06  1.637450e+09
# 2024-09-10  1.365356e+07  1.835038e+10  1.637297e+06  2.200527e+09
# 2024-09-11  1.365356e+07  1.835038e+10  1.659073e+06  2.223656e+09
# 2024-09-12  1.325961e+07  1.779439e+10  2.102452e+06  2.821491e+09
# 2024-09-13  1.286990e+07  1.716266e+10  2.472397e+06  3.297064e+09
# 2024-09-19  1.232272e+07  1.637751e+10  3.067076e+06  4.076298e+09
# 2024-09-20  1.086945e+07  1.444604e+10  4.633999e+06  6.158816e+09
# ...

# %%
account.latest
# Out:
# cash_usd            1.032253e+07
# cash_krw            1.371916e+10
# stock_usd           5.204300e+06
# stock_krw           6.916775e+09
# nav_usd             1.552683e+07
# nav_krw             2.063594e+10
# weight_cash         6.648190e+01
# weight_stock        3.351810e+01
# total_net_amount    6.678624e+09
# total_evaluation    6.916775e+09
# total_pl            2.381508e+08
# total_return        1.217448e+00
# Name: 2024-09-23, dtype: float64

# %%
plot_nav(account.nav)
# Out:
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# ...

# %%
dfs = account.get_dfs_concise()
dfs
# Out:
# {'absolutes':                                    name  num_shares  price_last    evaluation  \
#  ticker
#  007340 KS            DN AUTOMOTIVE CORP       22731    101200.0  2.300377e+09
#  271560 KS  ORION CORP/REPUBLIC OF KOREA       19000     93600.0  1.778400e+09
#  003030 KS      SEAH STEEL HOLDINGS CORP        5249    182200.0  9.563678e+08
#  000660 KS                  SK HYNIX INC        5000    162000.0  8.100000e+08
#  316140 KS     WOORI FINANCIAL GROUP INC       30000     15710.0  4.713000e+08
#  023160 KS                TK CORPORATION       28000     14610.0  4.090800e+08
#  006040 KS     DONGWON INDUSTRIES CO LTD        5000     31500.0  1.575000e+08
#  282690 KS  DONG AH TIRE & RUBBER CO LTD        2500     13500.0  3.375000e+07
#
#                      pl
#  ticker
#  007340 KS  149972443.0
#  271560 KS   59061280.0
#  003030 KS   19773541.0
#  000660 KS    1340449.0
#  316140 KS   -1416054.0
#  023160 KS    6596368.0
#  006040 KS    1625231.0
# ...

# %%
df = dfs['absolutes']
df
# Out:
#                                    name  num_shares  price_last    evaluation  \
# ticker
# 007340 KS            DN AUTOMOTIVE CORP       22731    101200.0  2.300377e+09
# 271560 KS  ORION CORP/REPUBLIC OF KOREA       19000     93600.0  1.778400e+09
# 003030 KS      SEAH STEEL HOLDINGS CORP        5249    182200.0  9.563678e+08
# 000660 KS                  SK HYNIX INC        5000    162000.0  8.100000e+08
# 316140 KS     WOORI FINANCIAL GROUP INC       30000     15710.0  4.713000e+08
# 023160 KS                TK CORPORATION       28000     14610.0  4.090800e+08
# 006040 KS     DONGWON INDUSTRIES CO LTD        5000     31500.0  1.575000e+08
# 282690 KS  DONG AH TIRE & RUBBER CO LTD        2500     13500.0  3.375000e+07
#
#                     pl
# ticker
# 007340 KS  149972443.0
# 271560 KS   59061280.0
# 003030 KS   19773541.0
# 000660 KS    1340449.0
# 316140 KS   -1416054.0
# 023160 KS    6596368.0
# 006040 KS    1625231.0
# 282690 KS    1197510.0

# %%
df['num_shares'] = df['num_shares'].apply(lambda x: f"{x:,}")
df['price_last'] = df['price_last'].apply(lambda x: f"{x:,.0f}")
df['evaluation'] = df['evaluation'].apply(lambda x: f"{x:,.0f}")
df['pl'] = df['pl'].apply(lambda x: f"{x:,.0f}")
df
# Out:
# /var/folders/_1/0byqfsn56tzdr_b7z00g95xw0000gn/T/ipykernel_91947/2168961937.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['num_shares'] = df['num_shares'].apply(lambda x: f"{x:,}")
# /var/folders/_1/0byqfsn56tzdr_b7z00g95xw0000gn/T/ipykernel_91947/2168961937.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_last'] = df['price_last'].apply(lambda x: f"{x:,.0f}")
# /var/folders/_1/0byqfsn56tzdr_b7z00g95xw0000gn/T/ipykernel_91947/2168961937.py:3: SettingWithCopyWarning:
# ...

# %%
round(dfs['portions'],2)
# Out:
#                                    name  return  weight  attribution
# ticker
# 007340 KS            DN AUTOMOTIVE CORP    6.97   11.15         0.78
# 271560 KS  ORION CORP/REPUBLIC OF KOREA    3.44    8.62         0.30
# 003030 KS      SEAH STEEL HOLDINGS CORP    2.11    4.63         0.10
# 000660 KS                  SK HYNIX INC    0.17    3.93         0.01
# 316140 KS     WOORI FINANCIAL GROUP INC   -0.30    2.28        -0.01
# 023160 KS                TK CORPORATION    1.64    1.98         0.03
# 006040 KS     DONGWON INDUSTRIES CO LTD    1.04    0.76         0.01
# 282690 KS  DONG AH TIRE & RUBBER CO LTD    3.68    0.16         0.01

# %%
df = account.weights
df

# %%
srs = account.nav_latest
srs

# %%
srs['attribution'] = df['attribution'].sum()
srs

# %%
df['weight'].sum()

# %%
df['attribution'].sum()

# %%
df['pl'].sum()

# %%
acc

# %%
get_ks_equity_info(ord.tickers)

# %%
ks = get_ks_market_info()
ks

# %%
tickers = [get_ticker_bbg_of_ticker(ticker) for ticker in ord.tickers]
tickers

# %%
ks[ks.index.isin(tickers)]

# %%
ord.info

# %%
trd = Trade()

# %%
ord.info

# %%
trd = Trade()
trd

# %%
trds = Trades()
trds

# %%
trds.history

# %%
trds.timeseries_evaluation

# %%
holdings = Holdings()

# %%
df = holdings.list
df

# %%
df['평가액(원)'] = df['evaluation'].apply(lambda x: convert_to_unit(x, 'KR'))
df

# %%
trds.trades

# %%
order = Order()

# %%
order.sheet

# %%
order_latest = Order()
order_latest

# %%
order_latest.info

# %%
holdings = Holdings()
holdings

# %%
holdings.history

# %%
holdings.info

# %%
account = Account()
account

# %%
account.df

# %%
account.balance

# %%
get_weight_approx()
