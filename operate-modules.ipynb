# %%
from cayman_office_system import *
# Out:
# INFO:shining_pebbles:Shining Pebbles package initialized
# INFO:numexpr.utils:Note: NumExpr detected 10 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.

# %%
trades = Trades()
# Out:
# | import trade of (date, index) = (2024-09-02, None)
# |- cash flow of trade: -614581438.0
# | import trade of (date, index) = (2024-09-05, None)
# |- cash flow of trade: -529470241.0
# | import trade of (date, index) = (2024-09-06, None)
# |- cash flow of trade: -91060069.0
# | import trade of (date, index) = (2024-09-09, None)
# |- cash flow of trade: -384482599.0
# | import trade of (date, index) = (2024-09-10, None)
# |- cash flow of trade: -625076151.0
# | import trade of (date, index) = (2024-09-12, None)
# |- cash flow of trade: -528686258.0
# | import trade of (date, index) = (2024-09-13, None)
# |- cash flow of trade: -519691172.0
# | import trade of (date, index) = (2024-09-19, None)
# |- cash flow of trade: -727234488.0
# | import trade of (date, index) = (2024-09-20, None)
# |- cash flow of trade: -1931465216.0
# | import trade of (date, index) = (2024-09-23, None)
# |- cash flow of trade: -726876600.0
# | import trade of (date, index) = (2024-09-24, None)
# ...

# %%
f = Fund(trades=trades)

# %%
f.fund_code
# Out:
# 'LKEF'

# %%
f.fund_name
# Out:
# 'LIFE KOREA ENGAGEMENT FUND'

# %%
f.date, f.month
# Out:
# ('2024-10-29', '10')

# %%
f.timeseries['df']
# Out:
#                cash: usd     cash: krw    stock: usd    stock: krw  \
# date
# 2024-09-01  1.578991e+07  2.112374e+10  0.000000e+00  0.000000e+00
# 2024-09-02  1.533070e+07  2.051784e+10  4.585422e+05  6.136900e+08
# 2024-09-03  1.533070e+07  2.057227e+10  4.666070e+05  6.261400e+08
# 2024-09-04  1.533070e+07  2.047415e+10  4.586597e+05  6.125400e+08
# 2024-09-05  1.493396e+07  1.993012e+10  8.602900e+05  1.148100e+09
# 2024-09-06  1.486575e+07  1.984578e+10  9.215730e+05  1.230300e+09
# 2024-09-07  1.486575e+07  1.984578e+10  9.215730e+05  1.230300e+09
# 2024-09-08  1.486575e+07  1.984578e+10  9.215730e+05  1.230300e+09
# 2024-09-09  1.457925e+07  1.956535e+10  1.220157e+06  1.637450e+09
# 2024-09-10  1.411416e+07  1.896944e+10  1.637297e+06  2.200527e+09
# 2024-09-11  1.411416e+07  1.891721e+10  1.659073e+06  2.223656e+09
# 2024-09-12  1.372021e+07  1.841252e+10  2.102452e+06  2.821491e+09
# 2024-09-13  1.333050e+07  1.777689e+10  2.472397e+06  3.297064e+09
# ...

# %%
f.timeseries['stock']
# Out:
#               stock: usd    stock: krw   usdkrw
# date
# 2024-09-01  0.000000e+00  0.000000e+00  1337.80
# 2024-09-02  4.585422e+05  6.136900e+08  1338.35
# 2024-09-03  4.666070e+05  6.261400e+08  1341.90
# 2024-09-04  4.586597e+05  6.125400e+08  1335.50
# 2024-09-05  8.602900e+05  1.148100e+09  1334.55
# 2024-09-06  9.215730e+05  1.230300e+09  1335.00
# 2024-09-07  9.215730e+05  1.230300e+09  1335.00
# 2024-09-08  9.215730e+05  1.230300e+09  1335.00
# 2024-09-09  1.220157e+06  1.637450e+09  1342.00
# 2024-09-10  1.637297e+06  2.200527e+09  1344.00
# 2024-09-11  1.659073e+06  2.223656e+09  1340.30
# 2024-09-12  2.102452e+06  2.821491e+09  1342.00
# 2024-09-13  2.472397e+06  3.297064e+09  1333.55
# 2024-09-14  2.472397e+06  3.297064e+09  1333.55
# 2024-09-15  2.472397e+06  3.297064e+09  1333.55
# 2024-09-16  2.472397e+06  3.297064e+09  1333.55
# 2024-09-17  2.472397e+06  3.297064e+09  1333.55
# 2024-09-18  2.472397e+06  3.297064e+09  1333.55
# ...

# %%
list(f.trades.stock.values())[8].plot()
# Out:
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# ...

# %%
trades.stock['003030 KS'].raw
# Out:
#           date     ticker                      name type  num_shares  \
# 0   2024-09-02  003030 KS  SEAH STEEL HOLDINGS CORP  Buy         900
# 1   2024-09-05  003030 KS  SEAH STEEL HOLDINGS CORP  Buy         800
# 2   2024-09-09  003030 KS  SEAH STEEL HOLDINGS CORP  Buy         500
# 3   2024-09-10  003030 KS  SEAH STEEL HOLDINGS CORP  Buy         200
# 4   2024-09-12  003030 KS  SEAH STEEL HOLDINGS CORP  Buy         350
# 5   2024-09-13  003030 KS  SEAH STEEL HOLDINGS CORP  Buy         350
# 6   2024-09-19  003030 KS  SEAH STEEL HOLDINGS CORP  Buy         699
# 7   2024-09-20  003030 KS  SEAH STEEL HOLDINGS CORP  Buy        1200
# 8   2024-09-23  003030 KS  SEAH STEEL HOLDINGS CORP  Buy         250
# 9   2024-09-24  003030 KS  SEAH STEEL HOLDINGS CORP  Buy         500
# 10  2024-09-26  003030 KS  SEAH STEEL HOLDINGS CORP  Buy         250
# 11  2024-10-24  003030 KS  SEAH STEEL HOLDINGS CORP  Buy          91
#
# ...

# %%
f.stock['003030 KS']
# Out:
#           date     ticker                      name  num_shares_cum  \
# 0   2024-09-02  003030 KS  SEAH STEEL HOLDINGS CORP           900.0
# 1   2024-09-03  003030 KS  SEAH STEEL HOLDINGS CORP           900.0
# 2   2024-09-04  003030 KS  SEAH STEEL HOLDINGS CORP           900.0
# 3   2024-09-05  003030 KS  SEAH STEEL HOLDINGS CORP          1700.0
# 4   2024-09-06  003030 KS  SEAH STEEL HOLDINGS CORP          1700.0
# 5   2024-09-07  003030 KS  SEAH STEEL HOLDINGS CORP          1700.0
# 6   2024-09-08  003030 KS  SEAH STEEL HOLDINGS CORP          1700.0
# 7   2024-09-09  003030 KS  SEAH STEEL HOLDINGS CORP          2200.0
# 8   2024-09-10  003030 KS  SEAH STEEL HOLDINGS CORP          2400.0
# 9   2024-09-11  003030 KS  SEAH STEEL HOLDINGS CORP          2400.0
# 10  2024-09-12  003030 KS  SEAH STEEL HOLDINGS CORP          2750.0
# 11  2024-09-13  003030 KS  SEAH STEEL HOLDINGS CORP          3100.0
# 12  2024-09-14  003030 KS  SEAH STEEL HOLDINGS CORP          3100.0
# ...

# %%
stock.timeseries

# %%
stock.plot()

# %%
holdings = Holdings(trades=trades)

# %%
holdings.df

# %%
holdings.equities

# %%
ts = Timeseries(trades=trades)

# %%
ts.df

# %%
ts.get_timeseries_nav()

# %%
ts.get_timeseries_price()

# %%
5 * 400 * 1400

# %%
200 * 400 * 1400
