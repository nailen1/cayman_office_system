# %%
from cayman_office_system import *

# %%
KEYS_TRANSACTION = ['Type',
 'ISIN Code / Abbr. Code',
 'Security Description',
 'Total No. of Shares',
 'Average Price',
 'Considerations',
 'Commission',
 'Sales Tax',
 'Capital Gains Tax',
 'Net Amount']

KEY_SELLBUY = 'No. of Shares / Price'

import re
from datetime import datetime

FILE_NAME_PREFIX_TRADE = 'LKEF Trade'

def get_date_from_file_name(file_name, form):
    match = re.search(r'\d{8}', file_name)
    if not match:
        return None
    
    date_str = match.group()
    date_obj = datetime.strptime(date_str, '%Y%m%d')
    
    return date_obj.strftime(form)

def get_dates_of_trades_in_file_folder(file_folder=file_folder['trade'], form='%Y-%m-%d'):
    file_names = scan_files_including_regex(file_folder=file_folder, regex='LKEF Trade')
    dates = [get_date_from_file_name(file_name=file_name, form=form) for file_name in file_names]
    return dates

def open_df_trade_by_date(date, file_folder=file_folder['trade'], verbose=False):
    date = date.replace('-', '')
    regex = FILE_NAME_PREFIX_TRADE+f'.*{date}'
    file_name = scan_files_including_regex(file_folder=file_folder, regex=regex, date=date)[-1]
    df = open_excel(file_folder=file_folder, file_name=file_name, engine='xlrd')
    if verbose:
        print('File Name: ', file_name)
    return df

def open_df_trade_by_index(index, file_folder=file_folder['trade'], verbose=False):
    regex = FILE_NAME_PREFIX_TRADE
    file_name = scan_files_including_regex(file_folder=file_folder, regex=regex)[index]
    df = open_excel(file_folder=file_folder, file_name=file_name, engine='xlrd')
    if verbose:
        print('File Name: ', file_name)
    return df

def get_keys_from_df_trade(df):
    keys = sorted(list(df['Unnamed: 0'].dropna()))
    return keys

def get_data_indicies_of_keys(keys, df):
    dct_indices = {}
    for key in keys:
        indices_of_key = list(df[df['Unnamed: 0']==key].index)
        dct_indices[key] = indices_of_key
    return dct_indices
    
def get_pair_index_of_info(dct_indices):
    index_i = 0
    index_f = dct_indices['Type'][0]-1
    return (index_i, index_f)

def get_pairs_index_of_transaction(dct_indices):
    indices_i = dct_indices['Type']
    indices_f = dct_indices['Net Amount']
    pairs_index = [(index_i, index_f+1) for index_i, index_f in zip(indices_i, indices_f)]
    return pairs_index

def get_df_raw_info(df, pair_info):
    index_i, index_f = pair_info
    df_info = df.iloc[index_i:index_f]
    return df_info

def get_df_raw_transaction(df, pair_raw_transaction):
    index_i, index_f = pair_raw_transaction
    df_raw_transaction = df.iloc[index_i:index_f]
    return df_raw_transaction

def get_df_transaction_by_index(df, index, pairs_transaction):
    pair_transaction = pairs_transaction[index]
    df_transaction = get_df_raw_transaction(df, pair_transaction)
    return df_transaction

# def get_dfs_transaction(df, pairs_trade):
#     dfs = {}
#     for index in range(len(pairs_trade)):
#         df_trade = get_df_transaction_by_index(df, index, pairs_trade)
#         dfs[index] = df_trade
#     return dfs

def get_dfs_transaction(df, pairs_transaction):
    dfs = []
    for i, pair in enumerate(pairs_transaction):
        df_transaction = get_df_transaction_by_index(df, i, pair)
        dfs.append(df_transaction)
    return dfs

def get_row_in_transaction(transaction, key):
    row = transaction[transaction['Unnamed: 0']==key]
    return row

def get_values_of_key_in_transaction(transaction, key):
    row = get_row_in_transaction(transaction, key)
    srs = row.dropna(axis=1).iloc[0]
    values = list(srs[1:])
    return values

def get_data_in_transaction(transaction, keys):
    dct = {}
    for key in keys:
        values = get_values_of_key_in_transaction(transaction, key)
        dct[key] = values
    return dct

def get_df_sellbuy(transaction):
    df = transaction[~transaction['Unnamed: 6'].isna()].dropna(axis=1)
    df.columns = ['num_shares', 'currency', 'price_executed']
    return df

def get_ticker_in_transaction(data):
    isin_code, abbr_code = data['ISIN Code / Abbr. Code'][-1].split('/')
    isin_code, abbr_code = isin_code.strip(), abbr_code.strip()
    ticker = f'{isin_code[3:-3]} KS'
    return ticker

def get_type_in_transaction(data):
    return data['Type'][-1]

def get_isin_and_abbr_code_in_transaction(data):
    isin_code, abbr_code = data['ISIN Code / Abbr. Code'][-1].split('/')
    isin_code, abbr_code = isin_code.strip(), abbr_code.strip()
    return isin_code, abbr_code

def get_isin_code_in_transaction(data):
    return get_isin_and_abbr_code_in_transaction(data)[0]

def get_abbr_code_in_transaction(data):
    return get_isin_and_abbr_code_in_transaction(data)[1]

def get_ticker_in_transaction(data):
    isin_code = get_isin_code_in_transaction(data)
    ticker = f'{isin_code[3:-3]} KS'
    return ticker

def get_name_in_transaction(data):
    return data['Security Description'][-1]

def get_consideration_in_transaction(data):
    return data['Considerations'][-1]

def get_commission_in_transaction(data):
    return data['Commission'][-1]

def get_sales_tax_in_transaction(data):
    return data['Sales Tax'][-1]

def get_capital_gains_tax_in_transaction(data):
    return data['Capital Gains Tax'][-1]

def get_net_amount_in_transaction(data):
    return data['Net Amount'][-1]

def get_total_no_of_shares_in_transaction(data):
    return data['Total No. of Shares'][-1]

def get_average_price_in_transaction(data):
    return data['Average Price'][-1]

# %%
class Trade:
    def __init__(self, date=None, index=None, file_folder=file_folder['trade']):
        self.file_folder = file_folder
        self.date = date
        self.index = index
        self.set_date_and_index(date, index)
        self.raw = self.open_raw()
        self.keys = get_keys_from_df_trade(self.raw)
        self.indices = get_data_indicies_of_keys(self.keys, self.raw)
        self.pair_info = get_pair_index_of_info(self.indices)
        self.pairs_transaction = get_pairs_index_of_transaction(self.indices)
        self.transactions = self.get_transactions()


    def set_date_and_index(self, date, index):
        if date and index:
            raise ValueError('Both date and index are given.')
        elif date:
            self.date = date
            self.index = None
        elif index:
            self.index = index
            dates = get_dates_of_trades_in_file_folder(file_folder=self.file_folder, form='%Y-%m-%d')
            self.date = dates[self.index]
        else:
            self.index = -1
            dates = get_dates_of_trades_in_file_folder(file_folder=self.file_folder, form='%Y-%m-%d')
            self.date = dates[self.index]

        print(f'- set (date, index) = ({self.date}, {self.index})')
        return self

    def open_raw(self):
        if self.index:
            df = open_df_trade_by_index(self.index, file_folder=self.file_folder)
        elif self.date:
            df = open_df_trade_by_date(self.date, file_folder=self.file_folder)
        self.raw = df
        return df
    
    def get_raw_info(self):
        df_info = get_df_raw_info(self.raw, self.pair_info)
        return df_info
    
    def get_raws_tranaction(self):
        dfs = [get_df_raw_transaction(self.raw, pair) for pair in self.pairs_transaction]
        self.raws_transaction = dfs        
        return dfs
    
    def get_transactions(self):
        if not hasattr(self, 'raws_transaction'):
            self.get_raws_tranaction()
        transactions = [Transaction(raw, self.date) for raw in self.raws_transaction]
        self.transactions = transactions
        return transactions

    
class Transaction:
    def __init__(self, raw, date):
        self.raw = raw
        self.date = date
        self.info = self.get_data()
        self.get_properties()
        self.ticker = self.get_ticker()
        self.df_sellbuy = self.get_df_sellbuy()
        self.data = self.get_data_calculated()
        
    def get_data(self):
        data = get_data_in_transaction(self.raw, KEYS_TRANSACTION)
        self.info = data
        return data
    
    def get_properties(self):
        data = self.info
        self.type = get_type_in_transaction(data)
        self.name = get_name_in_transaction(data)
        self.isin_code = get_isin_code_in_transaction(data)
        self.abbr_code = get_abbr_code_in_transaction(data)
        self.consideration = get_consideration_in_transaction(data)
        self.commission = get_commission_in_transaction(data)
        self.sales_tax = get_sales_tax_in_transaction(data)
        self.capital_gain_tax = get_capital_gains_tax_in_transaction(data)
        self.net_amount = get_net_amount_in_transaction(data)
        self.num_shares = get_total_no_of_shares_in_transaction(data)
        self.average_price = get_average_price_in_transaction(data)
        return self
    
    def get_ticker(self):
        ticker = get_ticker_in_transaction(self.info)
        self.ticker = ticker
        return ticker
    
    def get_df_sellbuy(self):
        df = get_df_sellbuy(self.raw)
        df['date'] = self.date
        df['ticker'] = self.ticker
        df['amount'] = df['num_shares'] * df['price_executed']
        cols_ordered = ['date', 'ticker', 'num_shares', 'currency', 'price_executed', 'amount']
        df = df[cols_ordered]
        df = df.set_index('date')
        self.df_sellbuy = df
        return df
    
    def get_num_shares_calculated(self):
        num_shares = self.df_sellbuy['num_shares'].sum()
        self.num_shares_calculated = num_shares
        return num_shares

    def get_consideration_calculated(self):
        consideration = self.df_sellbuy['amount'].sum()
        self.consideration_calculated = consideration
        return consideration
    
    def get_commission_calculated(self, rnd=True):
        consideration = self.consideration_calculated
        commission = consideration/1000
        if rnd:
            commission = round(commission)
        self.commission_calculated = commission
        return commission
    
    def get_average_price_calculated(self):
        if not hasattr(self, 'consieration_calculated'):
            self.get_consideration_calculated()
        if not hasattr(self, 'num_shares_calculated'):
            self.get_num_shares_calculated()
        average_price = self.consideration_calculated/self.num_shares_calculated
        self.average_price_calculated = average_price
        return average_price
    
    def get_net_amount_calculated(self):
        if not hasattr(self, 'consieration_calculated'):
            self.get_consideration_calculated()
        if not hasattr(self, 'commission_calculated'):
            self.get_commission_calculated()
        net_amount = self.consideration_calculated + self.commission_calculated
        self.net_amount_calculated = net_amount
        return net_amount
    
    def get_data_calculated(self):
        if not hasattr(self, 'df_sellbuy'):
            self.get_df_sellbuy()
        self.get_num_shares_calculated()
        self.get_consideration_calculated()
        self.get_commission_calculated()
        self.get_average_price_calculated()
        self.get_net_amount_calculated()
        data = {
            'num_shares': self.num_shares_calculated,
            'consideration': self.consideration_calculated,
            'commission': self.commission_calculated,
            'average_price': self.average_price_calculated,
            'net_amount': self.net_amount_calculated
        }
        self.data_calculated = data
        return data

    def check_identity_of_data(self):
        print(f'Check Identity of Data: (system) == (calculated)')
        if self.num_shares == self.num_shares_calculated:
            print(f'- num_shares: {self.num_shares} == {self.num_shares_calculated}')
        else:
            print(f'- num_shares: {self.num_shares} != {self.num_shares_calculated}')
        if self.consideration == self.consideration_calculated:
            print(f'- consideration: {self.consideration} == {self.consideration_calculated}')
        else:    
            print(f'- consideration: {self.consideration} != {self.consideration_calculated}')
        if self.commission == self.commission_calculated:
            print(f'- commission: {self.commission} == {self.commission_calculated}')
        else:
            print(f'- commission: {self.commission} != {self.commission_calculated}')
        if self.average_price == self.average_price_calculated:
            print(f'- average_price: {self.average_price} == {self.average_price_calculated}')
        else:
            print(f'- average_price: {self.average_price} != {self.average_price_calculated}')
        if self.net_amount == self.net_amount_calculated:
            print(f'- net_amount: {self.net_amount} == {self.net_amount_calculated}')
        else:
            print(f'- net_amount: {self.net_amount} != {self.net_amount_calculated}')
        return None
    
    def show_info(self):
        self.check_identity_of_data()
        print(self.get_data_calculated())
        return self.df_sellbuy

# %%
tr = Trade()
# Out:
# - set (date, index) = (2024-09-09, -1)

# %%
tr.transactions[2].show_info()
# Out:
# Check Identity of Data: (system) == (calculated)
# - num_shares: 1000 == 1000
# - consideration: 88238200 == 88238200.0
# - commission: 88238 == 88238
# - average_price: 88238.2 == 88238.2
# - net_amount: 88326438 == 88326438.0
# {'num_shares': 1000, 'consideration': 88238200.0, 'commission': 88238, 'average_price': 88238.2, 'net_amount': 88326438.0}
#                ticker num_shares currency  price_executed      amount
# date
# 2024-09-09  271560 KS         43   /  KRW         87400.0   3758200.0
# 2024-09-09  271560 KS         90   /  KRW         87500.0   7875000.0
# 2024-09-09  271560 KS         81   /  KRW         87600.0   7095600.0
# 2024-09-09  271560 KS         23   /  KRW         87700.0   2017100.0
# 2024-09-09  271560 KS         23   /  KRW         87800.0   2019400.0
# 2024-09-09  271560 KS         75   /  KRW         87900.0   6592500.0
# 2024-09-09  271560 KS         25   /  KRW         88000.0   2200000.0
# 2024-09-09  271560 KS         71   /  KRW         88100.0   6255100.0
# 2024-09-09  271560 KS         37   /  KRW         88200.0   3263400.0
# 2024-09-09  271560 KS        166   /  KRW         88300.0  14657800.0
# 2024-09-09  271560 KS         42   /  KRW         88400.0   3712800.0
# 2024-09-09  271560 KS          2   /  KRW         88500.0    177000.0
# 2024-09-09  271560 KS         28   /  KRW         88600.0   2480800.0
# 2024-09-09  271560 KS         32   /  KRW         88700.0   2838400.0
# 2024-09-09  271560 KS        114   /  KRW         88800.0  10123200.0
# 2024-09-09  271560 KS         49   /  KRW         88900.0   4356100.0
# 2024-09-09  271560 KS         51   /  KRW         89000.0   4539000.0
# 2024-09-09  271560 KS         48   /  KRW         89100.0   4276800.0

# %%
trxs = tr.get_raws_tranaction()
trxs
# Out:
# [                Unnamed: 0 Unnamed: 1 Unnamed: 2              Unnamed: 3  \
#  20                    Type        NaN        NaN                     KSE
#  21  ISIN Code / Abbr. Code        NaN        NaN  KR7003030004 / A003030
#  22    Security Description        NaN        NaN     SeAH Steel Holdings
#  23                     NaN        NaN        NaN                     NaN
#  24   No. of Shares / Price        NaN        NaN                     NaN
#  25                     NaN        NaN        NaN                     NaN
#  26                     NaN        NaN        NaN                     NaN
#  27                     NaN        NaN        NaN                     NaN
#  28                     NaN        NaN        NaN                     NaN
#  29                     NaN        NaN        NaN                     NaN
#  30                     NaN        NaN        NaN                     NaN
#  31                     NaN        NaN        NaN                     NaN
#  32                     NaN        NaN        NaN                     NaN
#  33                     NaN        NaN        NaN                     NaN
#  34                     NaN        NaN        NaN                     NaN
#  35                     NaN        NaN        NaN                     NaN
#  36                     NaN        NaN        NaN                     NaN
#  37                     NaN        NaN        NaN                     NaN
#  38                     NaN        NaN        NaN                     NaN
#  39                     NaN        NaN        NaN                     NaN
#  40                     NaN        NaN        NaN                     NaN
#  41                     NaN        NaN        NaN                     NaN
#  42                     NaN        NaN        NaN                     NaN
#  43                     NaN        NaN        NaN                     NaN
#  44                     NaN        NaN        NaN                     NaN
#  45     Total No. of Shares        NaN        Shs                     NaN
#  46           Average Price        NaN        KRW                     NaN
#  47          Considerations        NaN        KRW                     NaN
#  48              Commission        NaN        KRW                     NaN
#  49               Sales Tax        NaN        KRW                     NaN
#  50       Capital Gains Tax        NaN        KRW                     NaN
#  51              Net Amount        NaN        KRW                     NaN
#
#     Unnamed: 4 Unnamed: 5  Unnamed: 6
#  20        Buy        NaN         NaN
#  21        NaN        NaN         NaN
#  22        NaN        NaN         NaN
#  23        NaN        NaN         NaN
#  24          1     /  KRW    172600.0
#  25         15     /  KRW    173200.0
#  26          1     /  KRW    173300.0
#  27          5     /  KRW    173400.0
#  28          6     /  KRW    173500.0
#  29          7     /  KRW    173600.0
#  30         37     /  KRW    173700.0
#  31         37     /  KRW    173800.0
#  32          4     /  KRW    173900.0
#  33         24     /  KRW    174000.0
#  34         48     /  KRW    174100.0
#  35         31     /  KRW    174200.0
#  36         83     /  KRW    174300.0
#  37         26     /  KRW    174400.0
#  38         17     /  KRW    174500.0
#  39         42     /  KRW    174600.0
#  40         28     /  KRW    174700.0
#  41         32     /  KRW    174800.0
#  42         39     /  KRW    174900.0
#  43         17     /  KRW    175000.0
#  44        NaN        NaN         NaN
#  45        500        NaN         NaN
#  46     174271        NaN         NaN
#  47   87135500        NaN         NaN
#  48      87136        NaN         NaN
#  49          0        NaN         NaN
#  50          0        NaN         NaN
#  51   87222636        NaN         NaN  ,
#                  Unnamed: 0 Unnamed: 1 Unnamed: 2              Unnamed: 3  \
#  53                    Type        NaN        NaN                     KSE
#  54  ISIN Code / Abbr. Code        NaN        NaN  KR7007340003 / A007340
#  55    Security Description        NaN        NaN           DN AUTOMOTIVE
#  56                     NaN        NaN        NaN                     NaN
#  57   No. of Shares / Price        NaN        NaN                     NaN
#  58                     NaN        NaN        NaN                     NaN
#  59                     NaN        NaN        NaN                     NaN
#  60                     NaN        NaN        NaN                     NaN
#  61                     NaN        NaN        NaN                     NaN
#  62                     NaN        NaN        NaN                     NaN
#  63                     NaN        NaN        NaN                     NaN
#  64                     NaN        NaN        NaN                     NaN
#  65                     NaN        NaN        NaN                     NaN
#  66                     NaN        NaN        NaN                     NaN
#  67                     NaN        NaN        NaN                     NaN
#  68                     NaN        NaN        NaN                     NaN
#  69                     NaN        NaN        NaN                     NaN
#  70                     NaN        NaN        NaN                     NaN
#  71                     NaN        NaN        NaN                     NaN
#  72                     NaN        NaN        NaN                     NaN
#  73                     NaN        NaN        NaN                     NaN
#  74                     NaN        NaN        NaN                     NaN
#  75                     NaN        NaN        NaN                     NaN
#  76                     NaN        NaN        NaN                     NaN
#  77                     NaN        NaN        NaN                     NaN
#  78                     NaN        NaN        NaN                     NaN
#  79     Total No. of Shares        NaN        Shs                     NaN
#  80           Average Price        NaN        KRW                     NaN
#  81          Considerations        NaN        KRW                     NaN
#  82              Commission        NaN        KRW                     NaN
#  83               Sales Tax        NaN        KRW                     NaN
#  84       Capital Gains Tax        NaN        KRW                     NaN
#  85              Net Amount        NaN        KRW                     NaN
#
#      Unnamed: 4 Unnamed: 5  Unnamed: 6
#  53         Buy        NaN         NaN
#  54         NaN        NaN         NaN
#  55         NaN        NaN         NaN
#  56         NaN        NaN         NaN
#  57          27     /  KRW     91900.0
#  58          37     /  KRW     92000.0
#  59          36     /  KRW     92100.0
#  60          17     /  KRW     92200.0
#  61         155     /  KRW     92300.0
#  62           6     /  KRW     92400.0
#  63          70     /  KRW     92500.0
#  64           1     /  KRW     92700.0
#  65           6     /  KRW     92800.0
#  66          24     /  KRW     92900.0
#  67          96     /  KRW     93000.0
#  68          25     /  KRW     93100.0
#  69          29     /  KRW     93200.0
#  70           1     /  KRW     93300.0
#  71          84     /  KRW     93400.0
#  72         193     /  KRW     93500.0
#  73          40     /  KRW     93600.0
#  74          20     /  KRW     93700.0
#  75          50     /  KRW     93800.0
#  76         252     /  KRW     93900.0
#  77        1062     /  KRW     94000.0
#  78         NaN        NaN         NaN
#  79        2231        NaN         NaN
#  80  93556.6114        NaN         NaN
#  81   208724800        NaN         NaN
#  82      208725        NaN         NaN
#  83           0        NaN         NaN
#  84           0        NaN         NaN
#  85   208933525        NaN         NaN  ,
#                   Unnamed: 0 Unnamed: 1 Unnamed: 2              Unnamed: 3  \
#  87                     Type        NaN        NaN                     KSE
#  88   ISIN Code / Abbr. Code        NaN        NaN  KR7271560005 / A271560
#  89     Security Description        NaN        NaN                   ORION
#  90                      NaN        NaN        NaN                     NaN
#  91    No. of Shares / Price        NaN        NaN                     NaN
#  92                      NaN        NaN        NaN                     NaN
#  93                      NaN        NaN        NaN                     NaN
#  94                      NaN        NaN        NaN                     NaN
#  95                      NaN        NaN        NaN                     NaN
#  96                      NaN        NaN        NaN                     NaN
#  97                      NaN        NaN        NaN                     NaN
#  98                      NaN        NaN        NaN                     NaN
#  99                      NaN        NaN        NaN                     NaN
#  100                     NaN        NaN        NaN                     NaN
#  101                     NaN        NaN        NaN                     NaN
#  102                     NaN        NaN        NaN                     NaN
#  103                     NaN        NaN        NaN                     NaN
#  104                     NaN        NaN        NaN                     NaN
#  105                     NaN        NaN        NaN                     NaN
#  106                     NaN        NaN        NaN                     NaN
#  107                     NaN        NaN        NaN                     NaN
#  108                     NaN        NaN        NaN                     NaN
#  109                     NaN        NaN        NaN                     NaN
#  110     Total No. of Shares        NaN        Shs                     NaN
#  111           Average Price        NaN        KRW                     NaN
#  112          Considerations        NaN        KRW                     NaN
#  113              Commission        NaN        KRW                     NaN
#  114               Sales Tax        NaN        KRW                     NaN
#  115       Capital Gains Tax        NaN        KRW                     NaN
#  116              Net Amount        NaN        KRW                     NaN
#
#      Unnamed: 4 Unnamed: 5  Unnamed: 6
#  87         Buy        NaN         NaN
#  88         NaN        NaN         NaN
#  89         NaN        NaN         NaN
#  90         NaN        NaN         NaN
#  91          43     /  KRW     87400.0
#  92          90     /  KRW     87500.0
#  93          81     /  KRW     87600.0
#  94          23     /  KRW     87700.0
#  95          23     /  KRW     87800.0
#  96          75     /  KRW     87900.0
#  97          25     /  KRW     88000.0
#  98          71     /  KRW     88100.0
#  99          37     /  KRW     88200.0
#  100        166     /  KRW     88300.0
#  101         42     /  KRW     88400.0
#  102          2     /  KRW     88500.0
#  103         28     /  KRW     88600.0
#  104         32     /  KRW     88700.0
#  105        114     /  KRW     88800.0
#  106         49     /  KRW     88900.0
#  107         51     /  KRW     89000.0
#  108         48     /  KRW     89100.0
#  109        NaN        NaN         NaN
#  110       1000        NaN         NaN
#  111    88238.2        NaN         NaN
#  112   88238200        NaN         NaN
#  113      88238        NaN         NaN
#  114          0        NaN         NaN
#  115          0        NaN         NaN
#  116   88326438        NaN         NaN  ]

# %%
trxs[0]
# Out:
#                 Unnamed: 0 Unnamed: 1 Unnamed: 2              Unnamed: 3  \
# 20                    Type        NaN        NaN                     KSE
# 21  ISIN Code / Abbr. Code        NaN        NaN  KR7003030004 / A003030
# 22    Security Description        NaN        NaN     SeAH Steel Holdings
# 23                     NaN        NaN        NaN                     NaN
# 24   No. of Shares / Price        NaN        NaN                     NaN
# 25                     NaN        NaN        NaN                     NaN
# 26                     NaN        NaN        NaN                     NaN
# 27                     NaN        NaN        NaN                     NaN
# 28                     NaN        NaN        NaN                     NaN
# 29                     NaN        NaN        NaN                     NaN
# 30                     NaN        NaN        NaN                     NaN
# 31                     NaN        NaN        NaN                     NaN
# 32                     NaN        NaN        NaN                     NaN
# 33                     NaN        NaN        NaN                     NaN
# 34                     NaN        NaN        NaN                     NaN
# 35                     NaN        NaN        NaN                     NaN
# 36                     NaN        NaN        NaN                     NaN
# 37                     NaN        NaN        NaN                     NaN
# 38                     NaN        NaN        NaN                     NaN
# 39                     NaN        NaN        NaN                     NaN
# 40                     NaN        NaN        NaN                     NaN
# 41                     NaN        NaN        NaN                     NaN
# 42                     NaN        NaN        NaN                     NaN
# 43                     NaN        NaN        NaN                     NaN
# 44                     NaN        NaN        NaN                     NaN
# 45     Total No. of Shares        NaN        Shs                     NaN
# 46           Average Price        NaN        KRW                     NaN
# 47          Considerations        NaN        KRW                     NaN
# 48              Commission        NaN        KRW                     NaN
# 49               Sales Tax        NaN        KRW                     NaN
# 50       Capital Gains Tax        NaN        KRW                     NaN
# 51              Net Amount        NaN        KRW                     NaN
#
#    Unnamed: 4 Unnamed: 5  Unnamed: 6
# 20        Buy        NaN         NaN
# 21        NaN        NaN         NaN
# 22        NaN        NaN         NaN
# 23        NaN        NaN         NaN
# 24          1     /  KRW    172600.0
# 25         15     /  KRW    173200.0
# 26          1     /  KRW    173300.0
# 27          5     /  KRW    173400.0
# 28          6     /  KRW    173500.0
# 29          7     /  KRW    173600.0
# 30         37     /  KRW    173700.0
# 31         37     /  KRW    173800.0
# 32          4     /  KRW    173900.0
# 33         24     /  KRW    174000.0
# 34         48     /  KRW    174100.0
# 35         31     /  KRW    174200.0
# 36         83     /  KRW    174300.0
# 37         26     /  KRW    174400.0
# 38         17     /  KRW    174500.0
# 39         42     /  KRW    174600.0
# 40         28     /  KRW    174700.0
# 41         32     /  KRW    174800.0
# 42         39     /  KRW    174900.0
# 43         17     /  KRW    175000.0
# 44        NaN        NaN         NaN
# 45        500        NaN         NaN
# 46     174271        NaN         NaN
# 47   87135500        NaN         NaN
# 48      87136        NaN         NaN
# 49          0        NaN         NaN
# 50          0        NaN         NaN
# 51   87222636        NaN         NaN

# %%
trxs[0]
# Out:
#                 Unnamed: 0 Unnamed: 1 Unnamed: 2              Unnamed: 3  \
# 20                    Type        NaN        NaN                     KSE
# 21  ISIN Code / Abbr. Code        NaN        NaN  KR7003030004 / A003030
# 22    Security Description        NaN        NaN     SeAH Steel Holdings
# 23                     NaN        NaN        NaN                     NaN
# 24   No. of Shares / Price        NaN        NaN                     NaN
# 25                     NaN        NaN        NaN                     NaN
# 26                     NaN        NaN        NaN                     NaN
# 27                     NaN        NaN        NaN                     NaN
# 28                     NaN        NaN        NaN                     NaN
# 29                     NaN        NaN        NaN                     NaN
# 30                     NaN        NaN        NaN                     NaN
# 31                     NaN        NaN        NaN                     NaN
# 32                     NaN        NaN        NaN                     NaN
# 33                     NaN        NaN        NaN                     NaN
# 34                     NaN        NaN        NaN                     NaN
# 35                     NaN        NaN        NaN                     NaN
# 36                     NaN        NaN        NaN                     NaN
# 37                     NaN        NaN        NaN                     NaN
# 38                     NaN        NaN        NaN                     NaN
# 39                     NaN        NaN        NaN                     NaN
# 40                     NaN        NaN        NaN                     NaN
# 41                     NaN        NaN        NaN                     NaN
# 42                     NaN        NaN        NaN                     NaN
# 43                     NaN        NaN        NaN                     NaN
# 44                     NaN        NaN        NaN                     NaN
# 45     Total No. of Shares        NaN        Shs                     NaN
# 46           Average Price        NaN        KRW                     NaN
# 47          Considerations        NaN        KRW                     NaN
# 48              Commission        NaN        KRW                     NaN
# 49               Sales Tax        NaN        KRW                     NaN
# 50       Capital Gains Tax        NaN        KRW                     NaN
# 51              Net Amount        NaN        KRW                     NaN
#
#    Unnamed: 4 Unnamed: 5  Unnamed: 6
# 20        Buy        NaN         NaN
# 21        NaN        NaN         NaN
# 22        NaN        NaN         NaN
# 23        NaN        NaN         NaN
# 24          1     /  KRW    172600.0
# 25         15     /  KRW    173200.0
# 26          1     /  KRW    173300.0
# 27          5     /  KRW    173400.0
# 28          6     /  KRW    173500.0
# 29          7     /  KRW    173600.0
# 30         37     /  KRW    173700.0
# 31         37     /  KRW    173800.0
# 32          4     /  KRW    173900.0
# 33         24     /  KRW    174000.0
# 34         48     /  KRW    174100.0
# 35         31     /  KRW    174200.0
# 36         83     /  KRW    174300.0
# 37         26     /  KRW    174400.0
# 38         17     /  KRW    174500.0
# 39         42     /  KRW    174600.0
# 40         28     /  KRW    174700.0
# 41         32     /  KRW    174800.0
# 42         39     /  KRW    174900.0
# 43         17     /  KRW    175000.0
# 44        NaN        NaN         NaN
# 45        500        NaN         NaN
# 46     174271        NaN         NaN
# 47   87135500        NaN         NaN
# 48      87136        NaN         NaN
# 49          0        NaN         NaN
# 50          0        NaN         NaN
# 51   87222636        NaN         NaN

# %%
tr.date
# Out:
# '2024-09-09'

# %%
trx = Transaction(raw=trxs[0], date=tr.date)
trx

# %%
trx.ticker
# Out:
# '003030 KS'

# %%
trx.df_sellbuy
# Out:
#                ticker num_shares currency  price_executed      amount
# date
# 2024-09-09  003030 KS          1   /  KRW        172600.0    172600.0
# 2024-09-09  003030 KS         15   /  KRW        173200.0   2598000.0
# 2024-09-09  003030 KS          1   /  KRW        173300.0    173300.0
# 2024-09-09  003030 KS          5   /  KRW        173400.0    867000.0
# 2024-09-09  003030 KS          6   /  KRW        173500.0   1041000.0
# 2024-09-09  003030 KS          7   /  KRW        173600.0   1215200.0
# 2024-09-09  003030 KS         37   /  KRW        173700.0   6426900.0
# 2024-09-09  003030 KS         37   /  KRW        173800.0   6430600.0
# 2024-09-09  003030 KS          4   /  KRW        173900.0    695600.0
# 2024-09-09  003030 KS         24   /  KRW        174000.0   4176000.0
# 2024-09-09  003030 KS         48   /  KRW        174100.0   8356800.0
# 2024-09-09  003030 KS         31   /  KRW        174200.0   5400200.0
# 2024-09-09  003030 KS         83   /  KRW        174300.0  14466900.0
# 2024-09-09  003030 KS         26   /  KRW        174400.0   4534400.0
# 2024-09-09  003030 KS         17   /  KRW        174500.0   2966500.0
# 2024-09-09  003030 KS         42   /  KRW        174600.0   7333200.0
# 2024-09-09  003030 KS         28   /  KRW        174700.0   4891600.0
# 2024-09-09  003030 KS         32   /  KRW        174800.0   5593600.0
# 2024-09-09  003030 KS         39   /  KRW        174900.0   6821100.0
# 2024-09-09  003030 KS         17   /  KRW        175000.0   2975000.0

# %%
trx.info
# Out:
# {'Type': ['KSE', 'Buy'],
#  'ISIN Code / Abbr. Code': ['KR7003030004 / A003030'],
#  'Security Description': ['SeAH Steel Holdings'],
#  'Total No. of Shares': ['Shs', 500],
#  'Average Price': ['KRW', 174271],
#  'Considerations': ['KRW', 87135500],
#  'Commission': ['KRW', 87136],
#  'Sales Tax': ['KRW', 0],
#  'Capital Gains Tax': ['KRW', 0],
#  'Net Amount': ['KRW', 87222636]}

# %%
trx.get_data_calculated()
# Out:
# {'num_shares': 500,
#  'consideration': 87135500.0,
#  'commission': 87136,
#  'average_price': 174271.0,
#  'net_amount': 87222636.0}

# %%
trx.check_identity_of_data()
# Out:
# Check Identity of Data: (system) == (calculated)
# - num_shares: 500 == 500
# - consideration: 87135500 == 87135500.0
# - commission: 87136 == 87136
# - average_price: 174271 == 174271.0
# - net_amount: 87222636 == 87222636.0

# %%
trx = Transaction(raw=trxs[1], date=tr.date)
trx.df_sellbuy
# Out:
#                ticker num_shares currency  price_executed      amount
# date
# 2024-09-09  007340 KS         27   /  KRW         91900.0   2481300.0
# 2024-09-09  007340 KS         37   /  KRW         92000.0   3404000.0
# 2024-09-09  007340 KS         36   /  KRW         92100.0   3315600.0
# 2024-09-09  007340 KS         17   /  KRW         92200.0   1567400.0
# 2024-09-09  007340 KS        155   /  KRW         92300.0  14306500.0
# 2024-09-09  007340 KS          6   /  KRW         92400.0    554400.0
# 2024-09-09  007340 KS         70   /  KRW         92500.0   6475000.0
# 2024-09-09  007340 KS          1   /  KRW         92700.0     92700.0
# 2024-09-09  007340 KS          6   /  KRW         92800.0    556800.0
# 2024-09-09  007340 KS         24   /  KRW         92900.0   2229600.0
# 2024-09-09  007340 KS         96   /  KRW         93000.0   8928000.0
# 2024-09-09  007340 KS         25   /  KRW         93100.0   2327500.0
# 2024-09-09  007340 KS         29   /  KRW         93200.0   2702800.0
# 2024-09-09  007340 KS          1   /  KRW         93300.0     93300.0
# 2024-09-09  007340 KS         84   /  KRW         93400.0   7845600.0
# 2024-09-09  007340 KS        193   /  KRW         93500.0  18045500.0
# 2024-09-09  007340 KS         40   /  KRW         93600.0   3744000.0
# 2024-09-09  007340 KS         20   /  KRW         93700.0   1874000.0
# 2024-09-09  007340 KS         50   /  KRW         93800.0   4690000.0
# 2024-09-09  007340 KS        252   /  KRW         93900.0  23662800.0
# 2024-09-09  007340 KS       1062   /  KRW         94000.0  99828000.0

# %%
trx.check_identity_of_data()
# Out:
# - num_shares: 2231 == 2231
# - consideration: 208724800 == 208724800.0
# - commission: 208725 == 208725
# - average_price: 93556.6114 != 93556.61138502913
# - net_amount: 208933525 == 208933525.0

# %%
trx = Transaction(raw=trxs[2], date=tr.date)
trx.df_sellbuy
# Out:
#                ticker num_shares currency  price_executed      amount
# date
# 2024-09-09  271560 KS         43   /  KRW         87400.0   3758200.0
# 2024-09-09  271560 KS         90   /  KRW         87500.0   7875000.0
# 2024-09-09  271560 KS         81   /  KRW         87600.0   7095600.0
# 2024-09-09  271560 KS         23   /  KRW         87700.0   2017100.0
# 2024-09-09  271560 KS         23   /  KRW         87800.0   2019400.0
# 2024-09-09  271560 KS         75   /  KRW         87900.0   6592500.0
# 2024-09-09  271560 KS         25   /  KRW         88000.0   2200000.0
# 2024-09-09  271560 KS         71   /  KRW         88100.0   6255100.0
# 2024-09-09  271560 KS         37   /  KRW         88200.0   3263400.0
# 2024-09-09  271560 KS        166   /  KRW         88300.0  14657800.0
# 2024-09-09  271560 KS         42   /  KRW         88400.0   3712800.0
# 2024-09-09  271560 KS          2   /  KRW         88500.0    177000.0
# 2024-09-09  271560 KS         28   /  KRW         88600.0   2480800.0
# 2024-09-09  271560 KS         32   /  KRW         88700.0   2838400.0
# 2024-09-09  271560 KS        114   /  KRW         88800.0  10123200.0
# 2024-09-09  271560 KS         49   /  KRW         88900.0   4356100.0
# 2024-09-09  271560 KS         51   /  KRW         89000.0   4539000.0
# 2024-09-09  271560 KS         48   /  KRW         89100.0   4276800.0

# %%
trx.check_identity_of_data()
# Out:
# - num_shares: 1000 == 1000
# - consideration: 88238200 == 88238200.0
# - commission: 88238 == 88238
# - average_price: 88238.2 == 88238.2
# - net_amount: 88326438 == 88326438.0

# %%
data = trx.info
data
# Out:
# {'Type': ['KSE', 'Buy'],
#  'ISIN Code / Abbr. Code': ['KR7003030004 / A003030'],
#  'Security Description': ['SeAH Steel Holdings'],
#  'Total No. of Shares': ['Shs', 500],
#  'Average Price': ['KRW', 174271],
#  'Considerations': ['KRW', 87135500],
#  'Commission': ['KRW', 87136],
#  'Sales Tax': ['KRW', 0],
#  'Capital Gains Tax': ['KRW', 0],
#  'Net Amount': ['KRW', 87222636]}

# %%
trx.ticker
# Out:
# '003030 KS'

# %%
df = trx.get_df_sellbuy()
df
# Out:
#                ticker num_shares currency  price_executed      amount
# date
# 2024-09-09  003030 KS          1   /  KRW        172600.0    172600.0
# 2024-09-09  003030 KS         15   /  KRW        173200.0   2598000.0
# 2024-09-09  003030 KS          1   /  KRW        173300.0    173300.0
# 2024-09-09  003030 KS          5   /  KRW        173400.0    867000.0
# 2024-09-09  003030 KS          6   /  KRW        173500.0   1041000.0
# 2024-09-09  003030 KS          7   /  KRW        173600.0   1215200.0
# 2024-09-09  003030 KS         37   /  KRW        173700.0   6426900.0
# 2024-09-09  003030 KS         37   /  KRW        173800.0   6430600.0
# 2024-09-09  003030 KS          4   /  KRW        173900.0    695600.0
# 2024-09-09  003030 KS         24   /  KRW        174000.0   4176000.0
# 2024-09-09  003030 KS         48   /  KRW        174100.0   8356800.0
# 2024-09-09  003030 KS         31   /  KRW        174200.0   5400200.0
# 2024-09-09  003030 KS         83   /  KRW        174300.0  14466900.0
# 2024-09-09  003030 KS         26   /  KRW        174400.0   4534400.0
# 2024-09-09  003030 KS         17   /  KRW        174500.0   2966500.0
# 2024-09-09  003030 KS         42   /  KRW        174600.0   7333200.0
# 2024-09-09  003030 KS         28   /  KRW        174700.0   4891600.0
# 2024-09-09  003030 KS         32   /  KRW        174800.0   5593600.0
# 2024-09-09  003030 KS         39   /  KRW        174900.0   6821100.0
# 2024-09-09  003030 KS         17   /  KRW        175000.0   2975000.0

# %%
df['amount'].sum()
# Out:
# 87135500.0

# %%
round(87135500.0/1000)
# Out:
# 87136

# %%
87135500.0/1000 * 100
# Out:
# 8713550.0

# %%
tr.raw
# Out:
#                                             Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0                                                  NaN        NaN        NaN
# 1                  9th Fl. Samsung Electronics Bldg.,         NaN        NaN
# 2     11, 74-gil Seocho-daero Seocho-gu, Seoul 06620,         NaN        NaN
# 3                                    Republic of Korea        NaN        NaN
# 4                                                  NaN        NaN        NaN
# ..                                                 ...        ...        ...
# 129                                                NaN        NaN        NaN
# 130  Please notify us by email (middle.st@samsung.c...        NaN        NaN
# 131  in this confirmation by 5pm (Korea time) on th...        NaN        NaN
# 132  Note we shall not be liable for any indirect o...        NaN        NaN
# 133           incurred in respect of this transaction.        NaN        NaN
#
#     Unnamed: 3 Unnamed: 4 Unnamed: 5  Unnamed: 6
# 0          NaN        NaN        NaN         NaN
# 1          NaN        NaN        NaN         NaN
# 2          NaN        NaN        NaN         NaN
# 3          NaN        NaN        NaN         NaN
# 4          NaN        NaN        NaN         NaN
# ..         ...        ...        ...         ...
# 129        NaN        NaN        NaN         NaN
# 130        NaN        NaN        NaN         NaN
# 131        NaN        NaN        NaN         NaN
# 132        NaN        NaN        NaN         NaN
# 133        NaN        NaN        NaN         NaN
#
# [134 rows x 7 columns]

# %%
tr.pair_info
# Out:
# (0, 19)

# %%
tr.get_raw_info()
# Out:
#                                           Unnamed: 0  \
# 0                                                NaN
# 1                9th Fl. Samsung Electronics Bldg.,
# 2   11, 74-gil Seocho-daero Seocho-gu, Seoul 06620,
# 3                                  Republic of Korea
# 4                                                NaN
# 5                                 Trade Confirmation
# 6                                                NaN
# 7                                               Date
# 8                                                NaN
# 9                                               From
# 10                                                To
# 11                                               NaN
# 12                                      Trade Date :
# 13                                 Settlement Date :
# 14                                               NaN
# 15                                               NaN
# 16                               Our Reference No. :
# 17                                   Korea IRC No. :
# 18                                        A/C Name :
#
#                           Unnamed: 1 Unnamed: 2                  Unnamed: 3  \
# 0                                NaN        NaN                         NaN
# 1                                NaN        NaN                         NaN
# 2                                NaN        NaN                         NaN
# 3                                NaN        NaN                         NaN
# 4                                NaN        NaN                         NaN
# 5                                NaN        NaN                         NaN
# 6                                NaN        NaN                         NaN
# 7                       09 Sep. 2024        NaN                         NaN
# 8                                NaN        NaN                         NaN
# 9       Samsung Securities Co., Ltd.        NaN                         NaN
# 10  OP INVESTMENT MANAGEMENT LIMITED        NaN                         NaN
# 11                               NaN        NaN                         NaN
# 12                               NaN        NaN                09 Sep. 2024
# 13                               NaN        NaN                11 Sep. 2024
# 14                               NaN        NaN                         NaN
# 15                               NaN        NaN                         NaN
# 16                               NaN        NaN                715543911501
# 17                               NaN        NaN        213800QGQF7FJ5PN1850
# 18                               NaN        NaN  LIFE Korea Engagement Fund
#
#    Unnamed: 4 Unnamed: 5  Unnamed: 6
# 0         NaN        NaN         NaN
# 1         NaN        NaN         NaN
# 2         NaN        NaN         NaN
# 3         NaN        NaN         NaN
# 4         NaN        NaN         NaN
# 5         NaN        NaN         NaN
# 6         NaN        NaN         NaN
# 7         NaN        NaN         NaN
# 8         NaN        NaN         NaN
# 9         NaN        NaN         NaN
# 10        NaN        NaN         NaN
# 11        NaN        NaN         NaN
# 12        NaN        NaN         NaN
# 13        NaN        NaN         NaN
# 14        NaN        NaN         NaN
# 15        NaN        NaN         NaN
# 16        NaN        NaN         NaN
# 17        NaN        NaN         NaN
# 18        NaN        NaN         NaN

# %%
tr.pairs_transaction
# Out:
# [(20, 52), (53, 86), (87, 117)]

# %%
dfs = tr.get_raws_tranaction()

# %%
dfs[2]
# Out:
#                  Unnamed: 0 Unnamed: 1 Unnamed: 2              Unnamed: 3  \
# 87                     Type        NaN        NaN                     KSE
# 88   ISIN Code / Abbr. Code        NaN        NaN  KR7271560005 / A271560
# 89     Security Description        NaN        NaN                   ORION
# 90                      NaN        NaN        NaN                     NaN
# 91    No. of Shares / Price        NaN        NaN                     NaN
# 92                      NaN        NaN        NaN                     NaN
# 93                      NaN        NaN        NaN                     NaN
# 94                      NaN        NaN        NaN                     NaN
# 95                      NaN        NaN        NaN                     NaN
# 96                      NaN        NaN        NaN                     NaN
# 97                      NaN        NaN        NaN                     NaN
# 98                      NaN        NaN        NaN                     NaN
# 99                      NaN        NaN        NaN                     NaN
# 100                     NaN        NaN        NaN                     NaN
# 101                     NaN        NaN        NaN                     NaN
# 102                     NaN        NaN        NaN                     NaN
# 103                     NaN        NaN        NaN                     NaN
# 104                     NaN        NaN        NaN                     NaN
# 105                     NaN        NaN        NaN                     NaN
# 106                     NaN        NaN        NaN                     NaN
# 107                     NaN        NaN        NaN                     NaN
# 108                     NaN        NaN        NaN                     NaN
# 109                     NaN        NaN        NaN                     NaN
# 110     Total No. of Shares        NaN        Shs                     NaN
# 111           Average Price        NaN        KRW                     NaN
# 112          Considerations        NaN        KRW                     NaN
# 113              Commission        NaN        KRW                     NaN
# 114               Sales Tax        NaN        KRW                     NaN
# 115       Capital Gains Tax        NaN        KRW                     NaN
# 116              Net Amount        NaN        KRW                     NaN
#
#     Unnamed: 4 Unnamed: 5  Unnamed: 6
# 87         Buy        NaN         NaN
# 88         NaN        NaN         NaN
# 89         NaN        NaN         NaN
# 90         NaN        NaN         NaN
# 91          43     /  KRW     87400.0
# 92          90     /  KRW     87500.0
# 93          81     /  KRW     87600.0
# 94          23     /  KRW     87700.0
# 95          23     /  KRW     87800.0
# 96          75     /  KRW     87900.0
# 97          25     /  KRW     88000.0
# 98          71     /  KRW     88100.0
# 99          37     /  KRW     88200.0
# 100        166     /  KRW     88300.0
# 101         42     /  KRW     88400.0
# 102          2     /  KRW     88500.0
# 103         28     /  KRW     88600.0
# 104         32     /  KRW     88700.0
# 105        114     /  KRW     88800.0
# 106         49     /  KRW     88900.0
# 107         51     /  KRW     89000.0
# 108         48     /  KRW     89100.0
# 109        NaN        NaN         NaN
# 110       1000        NaN         NaN
# 111    88238.2        NaN         NaN
# 112   88238200        NaN         NaN
# 113      88238        NaN         NaN
# 114          0        NaN         NaN
# 115          0        NaN         NaN
# 116   88326438        NaN         NaN

# %%
get_df_transaction_by_index(tr.raw, 0, tr.pairs_transaction)
# Out:
#                 Unnamed: 0 Unnamed: 1 Unnamed: 2              Unnamed: 3  \
# 20                    Type        NaN        NaN                     KSE
# 21  ISIN Code / Abbr. Code        NaN        NaN  KR7003030004 / A003030
# 22    Security Description        NaN        NaN     SeAH Steel Holdings
# 23                     NaN        NaN        NaN                     NaN
# 24   No. of Shares / Price        NaN        NaN                     NaN
# 25                     NaN        NaN        NaN                     NaN
# 26                     NaN        NaN        NaN                     NaN
# 27                     NaN        NaN        NaN                     NaN
# 28                     NaN        NaN        NaN                     NaN
# 29                     NaN        NaN        NaN                     NaN
# 30                     NaN        NaN        NaN                     NaN
# 31                     NaN        NaN        NaN                     NaN
# 32                     NaN        NaN        NaN                     NaN
# 33                     NaN        NaN        NaN                     NaN
# 34                     NaN        NaN        NaN                     NaN
# 35                     NaN        NaN        NaN                     NaN
# 36                     NaN        NaN        NaN                     NaN
# 37                     NaN        NaN        NaN                     NaN
# 38                     NaN        NaN        NaN                     NaN
# 39                     NaN        NaN        NaN                     NaN
# 40                     NaN        NaN        NaN                     NaN
# 41                     NaN        NaN        NaN                     NaN
# 42                     NaN        NaN        NaN                     NaN
# 43                     NaN        NaN        NaN                     NaN
# 44                     NaN        NaN        NaN                     NaN
# 45     Total No. of Shares        NaN        Shs                     NaN
# 46           Average Price        NaN        KRW                     NaN
# 47          Considerations        NaN        KRW                     NaN
# 48              Commission        NaN        KRW                     NaN
# 49               Sales Tax        NaN        KRW                     NaN
# 50       Capital Gains Tax        NaN        KRW                     NaN
# 51              Net Amount        NaN        KRW                     NaN
#
#    Unnamed: 4 Unnamed: 5  Unnamed: 6
# 20        Buy        NaN         NaN
# 21        NaN        NaN         NaN
# 22        NaN        NaN         NaN
# 23        NaN        NaN         NaN
# 24          1     /  KRW    172600.0
# 25         15     /  KRW    173200.0
# 26          1     /  KRW    173300.0
# 27          5     /  KRW    173400.0
# 28          6     /  KRW    173500.0
# 29          7     /  KRW    173600.0
# 30         37     /  KRW    173700.0
# 31         37     /  KRW    173800.0
# 32          4     /  KRW    173900.0
# 33         24     /  KRW    174000.0
# 34         48     /  KRW    174100.0
# 35         31     /  KRW    174200.0
# 36         83     /  KRW    174300.0
# 37         26     /  KRW    174400.0
# 38         17     /  KRW    174500.0
# 39         42     /  KRW    174600.0
# 40         28     /  KRW    174700.0
# 41         32     /  KRW    174800.0
# 42         39     /  KRW    174900.0
# 43         17     /  KRW    175000.0
# 44        NaN        NaN         NaN
# 45        500        NaN         NaN
# 46     174271        NaN         NaN
# 47   87135500        NaN         NaN
# 48      87136        NaN         NaN
# 49          0        NaN         NaN
# 50          0        NaN         NaN
# 51   87222636        NaN         NaN

# %%
tr.num_transaction
# Out:
# 3

# %%
tr.ids_transaction
# Out:
# [0, 1, 2]

# %%
transaction = dct[0]
transaction
# Out:
#                 Unnamed: 0 Unnamed: 1 Unnamed: 2              Unnamed: 3  \
# 20                    Type        NaN        NaN                     KSE
# 21  ISIN Code / Abbr. Code        NaN        NaN  KR7003030004 / A003030
# 22    Security Description        NaN        NaN     SeAH Steel Holdings
# 23                     NaN        NaN        NaN                     NaN
# 24   No. of Shares / Price        NaN        NaN                     NaN
# 25                     NaN        NaN        NaN                     NaN
# 26                     NaN        NaN        NaN                     NaN
# 27                     NaN        NaN        NaN                     NaN
# 28                     NaN        NaN        NaN                     NaN
# 29                     NaN        NaN        NaN                     NaN
# 30                     NaN        NaN        NaN                     NaN
# 31                     NaN        NaN        NaN                     NaN
# 32                     NaN        NaN        NaN                     NaN
# 33                     NaN        NaN        NaN                     NaN
# 34                     NaN        NaN        NaN                     NaN
# 35                     NaN        NaN        NaN                     NaN
# 36                     NaN        NaN        NaN                     NaN
# 37                     NaN        NaN        NaN                     NaN
# 38                     NaN        NaN        NaN                     NaN
# 39                     NaN        NaN        NaN                     NaN
# 40                     NaN        NaN        NaN                     NaN
# 41                     NaN        NaN        NaN                     NaN
# 42                     NaN        NaN        NaN                     NaN
# 43                     NaN        NaN        NaN                     NaN
# 44                     NaN        NaN        NaN                     NaN
# 45     Total No. of Shares        NaN        Shs                     NaN
# 46           Average Price        NaN        KRW                     NaN
# 47          Considerations        NaN        KRW                     NaN
# 48              Commission        NaN        KRW                     NaN
# 49               Sales Tax        NaN        KRW                     NaN
# 50       Capital Gains Tax        NaN        KRW                     NaN
# 51              Net Amount        NaN        KRW                     NaN
#
#    Unnamed: 4 Unnamed: 5  Unnamed: 6
# 20        Buy        NaN         NaN
# 21        NaN        NaN         NaN
# 22        NaN        NaN         NaN
# 23        NaN        NaN         NaN
# 24          1     /  KRW    172600.0
# 25         15     /  KRW    173200.0
# 26          1     /  KRW    173300.0
# 27          5     /  KRW    173400.0
# 28          6     /  KRW    173500.0
# 29          7     /  KRW    173600.0
# 30         37     /  KRW    173700.0
# 31         37     /  KRW    173800.0
# 32          4     /  KRW    173900.0
# 33         24     /  KRW    174000.0
# 34         48     /  KRW    174100.0
# 35         31     /  KRW    174200.0
# 36         83     /  KRW    174300.0
# 37         26     /  KRW    174400.0
# 38         17     /  KRW    174500.0
# 39         42     /  KRW    174600.0
# 40         28     /  KRW    174700.0
# 41         32     /  KRW    174800.0
# 42         39     /  KRW    174900.0
# 43         17     /  KRW    175000.0
# 44        NaN        NaN         NaN
# 45        500        NaN         NaN
# 46     174271        NaN         NaN
# 47   87135500        NaN         NaN
# 48      87136        NaN         NaN
# 49          0        NaN         NaN
# 50          0        NaN         NaN
# 51   87222636        NaN         NaN

# %%
def get_df_in_transaction(transaction, key):
    df = transaction[transaction['Unnamed: 0']==key]
    return df

def get_values_of_key_in_transaction(transaction, key):
    df = get_df_in_transaction(transaction, key)
    srs = df.dropna(axis=1).iloc[0]
    values = list(srs[1:])
    return values

def get_data_in_transaction(transaction, keys):
    dct = {}
    for key in keys:
        values = get_values_of_key_in_transaction(transaction, key)
        dct[key] = values
    return dct

def get_df_sellbuy(transaction):
    df = transaction[~transaction['Unnamed: 6'].isna()].dropna(axis=1)
    df.columns = ['amount', 'currency', 'price_executed']
    return df

def get_ticker_in_transaction(data):
    isin_code, abbr_code = data['ISIN Code / Abbr. Code'][-1].split('/')
    isin_code, abbr_code = isin_code.strip(), abbr_code.strip()
    ticker = f'{isin_code[3:-3]} KS'
    return ticker

# %%
get_df_sellbuy(transaction)
# Out:
#    amount currency  price_executed
# 24      1   /  KRW        172600.0
# 25     15   /  KRW        173200.0
# 26      1   /  KRW        173300.0
# 27      5   /  KRW        173400.0
# 28      6   /  KRW        173500.0
# 29      7   /  KRW        173600.0
# 30     37   /  KRW        173700.0
# 31     37   /  KRW        173800.0
# 32      4   /  KRW        173900.0
# 33     24   /  KRW        174000.0
# 34     48   /  KRW        174100.0
# 35     31   /  KRW        174200.0
# 36     83   /  KRW        174300.0
# 37     26   /  KRW        174400.0
# 38     17   /  KRW        174500.0
# 39     42   /  KRW        174600.0
# 40     28   /  KRW        174700.0
# 41     32   /  KRW        174800.0
# 42     39   /  KRW        174900.0
# 43     17   /  KRW        175000.0

# %%
data = get_data_in_transaction(transaction, KEYS_TRANSACTION)
data
# Out:
# {'Type': ['KSE', 'Buy'],
#  'ISIN Code / Abbr. Code': ['KR7003030004 / A003030'],
#  'Security Description': ['SeAH Steel Holdings'],
#  'Total No. of Shares': ['Shs', 500],
#  'Average Price': ['KRW', 174271],
#  'Considerations': ['KRW', 87135500],
#  'Commission': ['KRW', 87136],
#  'Sales Tax': ['KRW', 0],
#  'Capital Gains Tax': ['KRW', 0],
#  'Net Amount': ['KRW', 87222636]}

# %%
ticker = get_ticker_in_transaction(data)
ticker
# Out:
# '003030 KS'

# %%
df = get_df_sellbuy(transaction)
data = get_data_in_transaction(transaction, KEYS_TRANSACTION)
df['ticker'] = get_ticker_in_transaction(data)
df = df.set_index('ticker')
df
# Out:
#           amount currency  price_executed
# ticker
# 003030 KS      1   /  KRW        172600.0
# 003030 KS     15   /  KRW        173200.0
# 003030 KS      1   /  KRW        173300.0
# 003030 KS      5   /  KRW        173400.0
# 003030 KS      6   /  KRW        173500.0
# 003030 KS      7   /  KRW        173600.0
# 003030 KS     37   /  KRW        173700.0
# 003030 KS     37   /  KRW        173800.0
# 003030 KS      4   /  KRW        173900.0
# 003030 KS     24   /  KRW        174000.0
# 003030 KS     48   /  KRW        174100.0
# 003030 KS     31   /  KRW        174200.0
# 003030 KS     83   /  KRW        174300.0
# 003030 KS     26   /  KRW        174400.0
# 003030 KS     17   /  KRW        174500.0
# 003030 KS     42   /  KRW        174600.0
# 003030 KS     28   /  KRW        174700.0
# 003030 KS     32   /  KRW        174800.0
# 003030 KS     39   /  KRW        174900.0
# 003030 KS     17   /  KRW        175000.0

# %%
transaction[~transaction['Unnamed: 6'].isna()].dropna(axis=1)
# Out:
#    Unnamed: 4 Unnamed: 5  Unnamed: 6
# 24          1     /  KRW    172600.0
# 25         15     /  KRW    173200.0
# 26          1     /  KRW    173300.0
# 27          5     /  KRW    173400.0
# 28          6     /  KRW    173500.0
# 29          7     /  KRW    173600.0
# 30         37     /  KRW    173700.0
# 31         37     /  KRW    173800.0
# 32          4     /  KRW    173900.0
# 33         24     /  KRW    174000.0
# 34         48     /  KRW    174100.0
# 35         31     /  KRW    174200.0
# 36         83     /  KRW    174300.0
# 37         26     /  KRW    174400.0
# 38         17     /  KRW    174500.0
# 39         42     /  KRW    174600.0
# 40         28     /  KRW    174700.0
# 41         32     /  KRW    174800.0
# 42         39     /  KRW    174900.0
# 43         17     /  KRW    175000.0

# %%
get_data_in_transaction(transaction,  'Security Description')
# Out:
# ['SeAH Steel Holdings']

# %%
list(transaction['Unnamed: 0'].dropna())
# Out:
# ['Type',
#  'ISIN Code / Abbr. Code',
#  'Security Description',
#  'No. of Shares / Price',
#  'Total No. of Shares',
#  'Average Price',
#  'Considerations',
#  'Commission',
#  'Sales Tax',
#  'Capital Gains Tax',
#  'Net Amount']

# %%
keys_in_transaction = []
for key, indices in tr.indices.items():
    if len(indices) == tr.num_transaction:
        keys_in_transaction.append(key)
keys_in_transaction
# Out:
# ['Average Price',
#  'Capital Gains Tax',
#  'Commission',
#  'Considerations',
#  'ISIN Code / Abbr. Code',
#  'Net Amount',
#  'No. of Shares / Price',
#  'Sales Tax',
#  'Security Description',
#  'Total No. of Shares',
#  'Type']

# %%
keys_in_transaction
# Out:
# ['Average Price',
#  'Capital Gains Tax',
#  'Commission',
#  'Considerations',
#  'ISIN Code / Abbr. Code',
#  'Net Amount',
#  'No. of Shares / Price',
#  'Sales Tax',
#  'Security Description',
#  'Total No. of Shares',
#  'Type']

# %%
transaction[transaction['Unnamed: 0']=='Net Amount'].dropna(axis=1)
# Out:
#     Unnamed: 0 Unnamed: 2 Unnamed: 4
# 51  Net Amount        KRW   87222636

# %%
transaction[transaction['Unnamed: 0']=='Sales Tax'].dropna(axis=1)
# Out:
#    Unnamed: 0 Unnamed: 2 Unnamed: 4
# 49  Sales Tax        KRW          0

# %%
tr.indices['ISIN Code / Abbr. Code']
# Out:
# [21, 54, 88]

# %%
transaction[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[340], line 1
# ----> 1 transaction[0]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 0

# %%
tr.dct_indices
# Out:
# {' Trade Confirmation': [5],
#  '*Samsung Securities is a self-clearing house, the same BIC code for both executing and clearing.': [126],
#  '11, 74-gil Seocho-daero Seocho-gu, Seoul 06620, ': [2],
#  '9th Fl. Samsung Electronics Bldg., ': [1],
#  'A/C Name :': [18],
#  'Average Price': [46, 80, 111],
#  'BIC Code : SAMCKRS1': [125],
#  'Capital Gains Tax': [50, 84, 115],
#  'Commission': [48, 82, 113],
#  'Considerations': [47, 81, 112],
#  'Date': [7],
#  'From': [9],
#  'ISIN Code / Abbr. Code': [21, 54, 88],
#  'KSD Participant Number : 30-0000': [124],
#  'Korea IRC No. :': [17],
#  'Net Amount': [51, 85, 116],
#  'No. of Shares / Price': [24, 57, 91],
#  'Note we shall not be liable for any indirect or consequential loss or for any buy-in or replacement costs, penalties or charges ': [132],
#  'Our Reference No. :': [16],
#  'PSET BIC : KSDCKRSE': [123],
#  'Place of Settlement (PSET) : KSD (Korea Securities Depository)': [122],
#  'Please notify us by email (middle.st@samsung.com/ settle.clearing@samsung.com) of any potential discrepancies or errors': [130],
#  'Republic of Korea': [3],
#  'Sales Tax': [49, 83, 114],
#  "Samsung Securities's Settlement Instructions": [119],
#  'Security Description': [22, 55, 89],
#  'Settlement Date :': [13],
#  'Settlement Method : Delivery Versus Payment': [121],
#  'To': [10],
#  'Total No. of Shares': [45, 79, 110],
#  'Trade Date :': [12],
#  'Type': [20, 53, 87],
#  'in this confirmation by 5pm (Korea time) on the business day following the trade date.': [131],
#  'incurred in respect of this transaction.': [133]}

# %%
isin_abbr_code = tr.dct_indices['ISIN Code / Abbr. Code']
isin_abbr_code
# Out:
# [21, 54, 88]

# %%
isin_abbr_code = tr.dct_indices['ISIN Code / Abbr. Code']
lst = list(tr.raw.loc[isin_abbr_code[0]].dropna())
isin_code, abbr_code = lst[-1].split('/')
isin_code, abbr_code = isin_code.strip(), abbr_code.strip()
isin_code, abbr_code
# Out:
# ('KR7003030004', 'A003030')

# %%
dct[1]
# Out:
#                 Unnamed: 0 Unnamed: 1 Unnamed: 2              Unnamed: 3  \
# 53                    Type        NaN        NaN                     KSE
# 54  ISIN Code / Abbr. Code        NaN        NaN  KR7007340003 / A007340
# 55    Security Description        NaN        NaN           DN AUTOMOTIVE
# 56                     NaN        NaN        NaN                     NaN
# 57   No. of Shares / Price        NaN        NaN                     NaN
# 58                     NaN        NaN        NaN                     NaN
# 59                     NaN        NaN        NaN                     NaN
# 60                     NaN        NaN        NaN                     NaN
# 61                     NaN        NaN        NaN                     NaN
# 62                     NaN        NaN        NaN                     NaN
# 63                     NaN        NaN        NaN                     NaN
# 64                     NaN        NaN        NaN                     NaN
# 65                     NaN        NaN        NaN                     NaN
# 66                     NaN        NaN        NaN                     NaN
# 67                     NaN        NaN        NaN                     NaN
# 68                     NaN        NaN        NaN                     NaN
# 69                     NaN        NaN        NaN                     NaN
# 70                     NaN        NaN        NaN                     NaN
# 71                     NaN        NaN        NaN                     NaN
# 72                     NaN        NaN        NaN                     NaN
# 73                     NaN        NaN        NaN                     NaN
# 74                     NaN        NaN        NaN                     NaN
# 75                     NaN        NaN        NaN                     NaN
# 76                     NaN        NaN        NaN                     NaN
# 77                     NaN        NaN        NaN                     NaN
# 78                     NaN        NaN        NaN                     NaN
# 79     Total No. of Shares        NaN        Shs                     NaN
# 80           Average Price        NaN        KRW                     NaN
# 81          Considerations        NaN        KRW                     NaN
# 82              Commission        NaN        KRW                     NaN
# 83               Sales Tax        NaN        KRW                     NaN
# 84       Capital Gains Tax        NaN        KRW                     NaN
#
#     Unnamed: 4 Unnamed: 5  Unnamed: 6
# 53         Buy        NaN         NaN
# 54         NaN        NaN         NaN
# 55         NaN        NaN         NaN
# 56         NaN        NaN         NaN
# 57          27     /  KRW     91900.0
# 58          37     /  KRW     92000.0
# 59          36     /  KRW     92100.0
# 60          17     /  KRW     92200.0
# 61         155     /  KRW     92300.0
# 62           6     /  KRW     92400.0
# 63          70     /  KRW     92500.0
# 64           1     /  KRW     92700.0
# 65           6     /  KRW     92800.0
# 66          24     /  KRW     92900.0
# 67          96     /  KRW     93000.0
# 68          25     /  KRW     93100.0
# 69          29     /  KRW     93200.0
# 70           1     /  KRW     93300.0
# 71          84     /  KRW     93400.0
# 72         193     /  KRW     93500.0
# 73          40     /  KRW     93600.0
# 74          20     /  KRW     93700.0
# 75          50     /  KRW     93800.0
# 76         252     /  KRW     93900.0
# 77        1062     /  KRW     94000.0
# 78         NaN        NaN         NaN
# 79        2231        NaN         NaN
# 80  93556.6114        NaN         NaN
# 81   208724800        NaN         NaN
# 82      208725        NaN         NaN
# 83           0        NaN         NaN
# 84           0        NaN         NaN

# %%
regex = FILE_NAME_PREFIX_TRADE
file_name = scan_files_including_regex(file_folder=file_folder['trade'], regex=regex)[-1]
file_name
# Out:
# 'LKEF Trade 20240909.xls'

# %%
file_name = scan_files_including_regex(file_folder=file_folder['trade'], regex=FILE_NAME_PREFIX_TRADE)[-1]
file_name
# Out:
# 'LKEF Trade 20240909.xls'

# %%
df = open_excel(file_folder=file_folder['trade'], file_name=file_name, engine='xlrd')
df
# Out:
#                                             Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0                                                  NaN        NaN        NaN
# 1                  9th Fl. Samsung Electronics Bldg.,         NaN        NaN
# 2     11, 74-gil Seocho-daero Seocho-gu, Seoul 06620,         NaN        NaN
# 3                                    Republic of Korea        NaN        NaN
# 4                                                  NaN        NaN        NaN
# ..                                                 ...        ...        ...
# 129                                                NaN        NaN        NaN
# 130  Please notify us by email (middle.st@samsung.c...        NaN        NaN
# 131  in this confirmation by 5pm (Korea time) on th...        NaN        NaN
# 132  Note we shall not be liable for any indirect o...        NaN        NaN
# 133           incurred in respect of this transaction.        NaN        NaN
#
#     Unnamed: 3 Unnamed: 4 Unnamed: 5  Unnamed: 6
# 0          NaN        NaN        NaN         NaN
# 1          NaN        NaN        NaN         NaN
# 2          NaN        NaN        NaN         NaN
# 3          NaN        NaN        NaN         NaN
# 4          NaN        NaN        NaN         NaN
# ..         ...        ...        ...         ...
# 129        NaN        NaN        NaN         NaN
# 130        NaN        NaN        NaN         NaN
# 131        NaN        NaN        NaN         NaN
# 132        NaN        NaN        NaN         NaN
# 133        NaN        NaN        NaN         NaN
#
# [134 rows x 7 columns]

# %%
get_dates_of_trades_in_file_folder()
# Out:
# ['2024-09-02', '2024-09-05', '2024-09-06', '2024-09-09']

# %%
df = open_df_trade_by_index(index=-2)
df
# Out:
#                                            Unnamed: 0  \
# 0                                                 NaN
# 1                 9th Fl. Samsung Electronics Bldg.,
# 2    11, 74-gil Seocho-daero Seocho-gu, Seoul 06620,
# 3                                   Republic of Korea
# 4                                                 NaN
# 5                                  Trade Confirmation
# 6                                                 NaN
# 7                                                Date
# 8                                                 NaN
# 9                                                From
# 10                                                 To
# 11                                                NaN
# 12                                       Trade Date :
# 13                                  Settlement Date :
# 14                                                NaN
# 15                                                NaN
# 16                                Our Reference No. :
# 17                                    Korea IRC No. :
# 18                                         A/C Name :
# 19                                                NaN
# 20                                               Type
# 21                             ISIN Code / Abbr. Code
# 22                               Security Description
# 23                                                NaN
# 24                              No. of Shares / Price
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                Total No. of Shares
# 37                                      Average Price
# 38                                     Considerations
# 39                                         Commission
# 40                                          Sales Tax
# 41                                  Capital Gains Tax
# 42                                         Net Amount
# 43                                                NaN
# 44                                                NaN
# 45       Samsung Securities's Settlement Instructions
# 46                                                NaN
# 47        Settlement Method : Delivery Versus Payment
# 48  Place of Settlement (PSET) : KSD (Korea Securi...
# 49                                PSET BIC : KSDCKRSE
# 50                   KSD Participant Number : 30-0000
# 51                                BIC Code : SAMCKRS1
# 52  *Samsung Securities is a self-clearing house, ...
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56  Please notify us by email (middle.st@samsung.c...
# 57  in this confirmation by 5pm (Korea time) on th...
# 58  Note we shall not be liable for any indirect o...
# 59           incurred in respect of this transaction.
#
#                           Unnamed: 1 Unnamed: 2                  Unnamed: 3  \
# 0                                NaN        NaN                         NaN
# 1                                NaN        NaN                         NaN
# 2                                NaN        NaN                         NaN
# 3                                NaN        NaN                         NaN
# 4                                NaN        NaN                         NaN
# 5                                NaN        NaN                         NaN
# 6                                NaN        NaN                         NaN
# 7                       06 Sep. 2024        NaN                         NaN
# 8                                NaN        NaN                         NaN
# 9       Samsung Securities Co., Ltd.        NaN                         NaN
# 10  OP INVESTMENT MANAGEMENT LIMITED        NaN                         NaN
# 11                               NaN        NaN                         NaN
# 12                               NaN        NaN                06 Sep. 2024
# 13                               NaN        NaN                10 Sep. 2024
# 14                               NaN        NaN                         NaN
# 15                               NaN        NaN                         NaN
# 16                               NaN        NaN                715543911501
# 17                               NaN        NaN        213800QGQF7FJ5PN1850
# 18                               NaN        NaN  LIFE Korea Engagement Fund
# 19                               NaN        NaN                         NaN
# 20                               NaN        NaN                         KSE
# 21                               NaN        NaN      KR7007340003 / A007340
# 22                               NaN        NaN               DN AUTOMOTIVE
# 23                               NaN        NaN                         NaN
# 24                               NaN        NaN                         NaN
# 25                               NaN        NaN                         NaN
# 26                               NaN        NaN                         NaN
# 27                               NaN        NaN                         NaN
# 28                               NaN        NaN                         NaN
# 29                               NaN        NaN                         NaN
# 30                               NaN        NaN                         NaN
# 31                               NaN        NaN                         NaN
# 32                               NaN        NaN                         NaN
# 33                               NaN        NaN                         NaN
# 34                               NaN        NaN                         NaN
# 35                               NaN        NaN                         NaN
# 36                               NaN        Shs                         NaN
# 37                               NaN        KRW                         NaN
# 38                               NaN        KRW                         NaN
# 39                               NaN        KRW                         NaN
# 40                               NaN        KRW                         NaN
# 41                               NaN        KRW                         NaN
# 42                               NaN        KRW                         NaN
# 43                               NaN        NaN                         NaN
# 44                               NaN        NaN                         NaN
# 45                               NaN        NaN                         NaN
# 46                               NaN        NaN                         NaN
# 47                               NaN        NaN                         NaN
# 48                               NaN        NaN                         NaN
# 49                               NaN        NaN                         NaN
# 50                               NaN        NaN                         NaN
# 51                               NaN        NaN                         NaN
# 52                               NaN        NaN                         NaN
# 53                               NaN        NaN                         NaN
# 54                               NaN        NaN                         NaN
# 55                               NaN        NaN                         NaN
# 56                               NaN        NaN                         NaN
# 57                               NaN        NaN                         NaN
# 58                               NaN        NaN                         NaN
# 59                               NaN        NaN                         NaN
#
#    Unnamed: 4 Unnamed: 5  Unnamed: 6
# 0         NaN        NaN         NaN
# 1         NaN        NaN         NaN
# 2         NaN        NaN         NaN
# 3         NaN        NaN         NaN
# 4         NaN        NaN         NaN
# 5         NaN        NaN         NaN
# 6         NaN        NaN         NaN
# 7         NaN        NaN         NaN
# 8         NaN        NaN         NaN
# 9         NaN        NaN         NaN
# 10        NaN        NaN         NaN
# 11        NaN        NaN         NaN
# 12        NaN        NaN         NaN
# 13        NaN        NaN         NaN
# 14        NaN        NaN         NaN
# 15        NaN        NaN         NaN
# 16        NaN        NaN         NaN
# 17        NaN        NaN         NaN
# 18        NaN        NaN         NaN
# 19        NaN        NaN         NaN
# 20        Buy        NaN         NaN
# 21        NaN        NaN         NaN
# 22        NaN        NaN         NaN
# 23        NaN        NaN         NaN
# 24        200     /  KRW     90400.0
# 25          1     /  KRW     90600.0
# 26         52     /  KRW     90700.0
# 27         32     /  KRW     90800.0
# 28         82     /  KRW     90900.0
# 29        211     /  KRW     91000.0
# 30         49     /  KRW     91100.0
# 31        169     /  KRW     91200.0
# 32         54     /  KRW     91300.0
# 33        102     /  KRW     91400.0
# 34         48     /  KRW     91500.0
# 35        NaN        NaN         NaN
# 36       1000        NaN         NaN
# 37    90969.1        NaN         NaN
# 38   90969100        NaN         NaN
# 39      90969        NaN         NaN
# 40          0        NaN         NaN
# 41          0        NaN         NaN
# 42   91060069        NaN         NaN
# 43        NaN        NaN         NaN
# 44        NaN        NaN         NaN
# 45        NaN        NaN         NaN
# 46        NaN        NaN         NaN
# 47        NaN        NaN         NaN
# 48        NaN        NaN         NaN
# 49        NaN        NaN         NaN
# 50        NaN        NaN         NaN
# 51        NaN        NaN         NaN
# 52        NaN        NaN         NaN
# 53        NaN        NaN         NaN
# 54        NaN        NaN         NaN
# 55        NaN        NaN         NaN
# 56        NaN        NaN         NaN
# 57        NaN        NaN         NaN
# 58        NaN        NaN         NaN
# 59        NaN        NaN         NaN

# %%
file_names = scan_files_including_regex(file_folder=file_folder['trade'], regex='LKEF Trade')
file_names
# Out:
# ['LKEF Trade 20240902.xls',
#  'LKEF Trade 20240905.xls',
#  'LKEF Trade 20240906.xls',
#  'LKEF Trade 20240909.xls']

# %%
df = open_excel(file_folder=file_folder['trade'], file_name=file_name, engine='xlrd')
df

# %%
df = open_df_trade_by_index(index=-1, verbose=True)
df
# Out:
# File Name:  LKEF Trade 20240909.xls
#                                             Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0                                                  NaN        NaN        NaN
# 1                  9th Fl. Samsung Electronics Bldg.,         NaN        NaN
# 2     11, 74-gil Seocho-daero Seocho-gu, Seoul 06620,         NaN        NaN
# 3                                    Republic of Korea        NaN        NaN
# 4                                                  NaN        NaN        NaN
# ..                                                 ...        ...        ...
# 129                                                NaN        NaN        NaN
# 130  Please notify us by email (middle.st@samsung.c...        NaN        NaN
# 131  in this confirmation by 5pm (Korea time) on th...        NaN        NaN
# 132  Note we shall not be liable for any indirect o...        NaN        NaN
# 133           incurred in respect of this transaction.        NaN        NaN
#
#     Unnamed: 3 Unnamed: 4 Unnamed: 5  Unnamed: 6
# 0          NaN        NaN        NaN         NaN
# 1          NaN        NaN        NaN         NaN
# 2          NaN        NaN        NaN         NaN
# 3          NaN        NaN        NaN         NaN
# 4          NaN        NaN        NaN         NaN
# ..         ...        ...        ...         ...
# 129        NaN        NaN        NaN         NaN
# 130        NaN        NaN        NaN         NaN
# 131        NaN        NaN        NaN         NaN
# 132        NaN        NaN        NaN         NaN
# 133        NaN        NaN        NaN         NaN
#
# [134 rows x 7 columns]

# %%
keys = get_keys_from_df_trade(df)
keys
# Out:
# [' Trade Confirmation',
#  '*Samsung Securities is a self-clearing house, the same BIC code for both executing and clearing.',
#  '11, 74-gil Seocho-daero Seocho-gu, Seoul 06620, ',
#  '9th Fl. Samsung Electronics Bldg., ',
#  'A/C Name :',
#  'Average Price',
#  'Average Price',
#  'Average Price',
#  'BIC Code : SAMCKRS1',
#  'Capital Gains Tax',
#  'Capital Gains Tax',
#  'Capital Gains Tax',
#  'Commission',
#  'Commission',
#  'Commission',
#  'Considerations',
#  'Considerations',
#  'Considerations',
#  'Date',
#  'From',
#  'ISIN Code / Abbr. Code',
#  'ISIN Code / Abbr. Code',
#  'ISIN Code / Abbr. Code',
#  'KSD Participant Number : 30-0000',
#  'Korea IRC No. :',
#  'Net Amount',
#  'Net Amount',
#  'Net Amount',
#  'No. of Shares / Price',
#  'No. of Shares / Price',
#  'No. of Shares / Price',
#  'Note we shall not be liable for any indirect or consequential loss or for any buy-in or replacement costs, penalties or charges ',
#  'Our Reference No. :',
#  'PSET BIC : KSDCKRSE',
#  'Place of Settlement (PSET) : KSD (Korea Securities Depository)',
#  'Please notify us by email (middle.st@samsung.com/ settle.clearing@samsung.com) of any potential discrepancies or errors',
#  'Republic of Korea',
#  'Sales Tax',
#  'Sales Tax',
#  'Sales Tax',
#  "Samsung Securities's Settlement Instructions",
#  'Security Description',
#  'Security Description',
#  'Security Description',
#  'Settlement Date :',
#  'Settlement Method : Delivery Versus Payment',
#  'To',
#  'Total No. of Shares',
#  'Total No. of Shares',
#  'Total No. of Shares',
#  'Trade Date :',
#  'Type',
#  'Type',
#  'Type',
#  'in this confirmation by 5pm (Korea time) on the business day following the trade date.',
#  'incurred in respect of this transaction.']

# %%
dct_indices = get_data_indicies_of_keys(keys, df)
dct_indices
# Out:
# {' Trade Confirmation': [5],
#  '*Samsung Securities is a self-clearing house, the same BIC code for both executing and clearing.': [126],
#  '11, 74-gil Seocho-daero Seocho-gu, Seoul 06620, ': [2],
#  '9th Fl. Samsung Electronics Bldg., ': [1],
#  'A/C Name :': [18],
#  'Average Price': [46, 80, 111],
#  'BIC Code : SAMCKRS1': [125],
#  'Capital Gains Tax': [50, 84, 115],
#  'Commission': [48, 82, 113],
#  'Considerations': [47, 81, 112],
#  'Date': [7],
#  'From': [9],
#  'ISIN Code / Abbr. Code': [21, 54, 88],
#  'KSD Participant Number : 30-0000': [124],
#  'Korea IRC No. :': [17],
#  'Net Amount': [51, 85, 116],
#  'No. of Shares / Price': [24, 57, 91],
#  'Note we shall not be liable for any indirect or consequential loss or for any buy-in or replacement costs, penalties or charges ': [132],
#  'Our Reference No. :': [16],
#  'PSET BIC : KSDCKRSE': [123],
#  'Place of Settlement (PSET) : KSD (Korea Securities Depository)': [122],
#  'Please notify us by email (middle.st@samsung.com/ settle.clearing@samsung.com) of any potential discrepancies or errors': [130],
#  'Republic of Korea': [3],
#  'Sales Tax': [49, 83, 114],
#  "Samsung Securities's Settlement Instructions": [119],
#  'Security Description': [22, 55, 89],
#  'Settlement Date :': [13],
#  'Settlement Method : Delivery Versus Payment': [121],
#  'To': [10],
#  'Total No. of Shares': [45, 79, 110],
#  'Trade Date :': [12],
#  'Type': [20, 53, 87],
#  'in this confirmation by 5pm (Korea time) on the business day following the trade date.': [131],
#  'incurred in respect of this transaction.': [133]}

# %%
pairs_trade = get_pairs_index_of_trades(dct_indices)
pair_info = get_pair_index_of_info(dct_indices)

# %%
pairs_trade, pair_info
# Out:
# ([(20, 51), (53, 85), (87, 116)], (0, 19))

# %%
df.loc[pairs_trade[0][0]:pairs_trade[0][1], :]
# Out:
#                 Unnamed: 0 Unnamed: 1 Unnamed: 2              Unnamed: 3  \
# 20                    Type        NaN        NaN                     KSE
# 21  ISIN Code / Abbr. Code        NaN        NaN  KR7003030004 / A003030
# 22    Security Description        NaN        NaN     SeAH Steel Holdings
# 23                     NaN        NaN        NaN                     NaN
# 24   No. of Shares / Price        NaN        NaN                     NaN
# 25                     NaN        NaN        NaN                     NaN
# 26                     NaN        NaN        NaN                     NaN
# 27                     NaN        NaN        NaN                     NaN
# 28                     NaN        NaN        NaN                     NaN
# 29                     NaN        NaN        NaN                     NaN
# 30                     NaN        NaN        NaN                     NaN
# 31                     NaN        NaN        NaN                     NaN
# 32                     NaN        NaN        NaN                     NaN
# 33                     NaN        NaN        NaN                     NaN
# 34                     NaN        NaN        NaN                     NaN
# 35                     NaN        NaN        NaN                     NaN
# 36                     NaN        NaN        NaN                     NaN
# 37                     NaN        NaN        NaN                     NaN
# 38                     NaN        NaN        NaN                     NaN
# 39                     NaN        NaN        NaN                     NaN
# 40                     NaN        NaN        NaN                     NaN
# 41                     NaN        NaN        NaN                     NaN
# 42                     NaN        NaN        NaN                     NaN
# 43                     NaN        NaN        NaN                     NaN
# 44                     NaN        NaN        NaN                     NaN
# 45     Total No. of Shares        NaN        Shs                     NaN
# 46           Average Price        NaN        KRW                     NaN
# 47          Considerations        NaN        KRW                     NaN
# 48              Commission        NaN        KRW                     NaN
# 49               Sales Tax        NaN        KRW                     NaN
# 50       Capital Gains Tax        NaN        KRW                     NaN
# 51              Net Amount        NaN        KRW                     NaN
#
#    Unnamed: 4 Unnamed: 5  Unnamed: 6
# 20        Buy        NaN         NaN
# 21        NaN        NaN         NaN
# 22        NaN        NaN         NaN
# 23        NaN        NaN         NaN
# 24          1     /  KRW    172600.0
# 25         15     /  KRW    173200.0
# 26          1     /  KRW    173300.0
# 27          5     /  KRW    173400.0
# 28          6     /  KRW    173500.0
# 29          7     /  KRW    173600.0
# 30         37     /  KRW    173700.0
# 31         37     /  KRW    173800.0
# 32          4     /  KRW    173900.0
# 33         24     /  KRW    174000.0
# 34         48     /  KRW    174100.0
# 35         31     /  KRW    174200.0
# 36         83     /  KRW    174300.0
# 37         26     /  KRW    174400.0
# 38         17     /  KRW    174500.0
# 39         42     /  KRW    174600.0
# 40         28     /  KRW    174700.0
# 41         32     /  KRW    174800.0
# 42         39     /  KRW    174900.0
# 43         17     /  KRW    175000.0
# 44        NaN        NaN         NaN
# 45        500        NaN         NaN
# 46     174271        NaN         NaN
# 47   87135500        NaN         NaN
# 48      87136        NaN         NaN
# 49          0        NaN         NaN
# 50          0        NaN         NaN
# 51   87222636        NaN         NaN

# %%
df.loc[pairs_trade[1][0]:pairs_trade[1][1], :]
# Out:
#                 Unnamed: 0 Unnamed: 1 Unnamed: 2              Unnamed: 3  \
# 53                    Type        NaN        NaN                     KSE
# 54  ISIN Code / Abbr. Code        NaN        NaN  KR7007340003 / A007340
# 55    Security Description        NaN        NaN           DN AUTOMOTIVE
# 56                     NaN        NaN        NaN                     NaN
# 57   No. of Shares / Price        NaN        NaN                     NaN
# 58                     NaN        NaN        NaN                     NaN
# 59                     NaN        NaN        NaN                     NaN
# 60                     NaN        NaN        NaN                     NaN
# 61                     NaN        NaN        NaN                     NaN
# 62                     NaN        NaN        NaN                     NaN
# 63                     NaN        NaN        NaN                     NaN
# 64                     NaN        NaN        NaN                     NaN
# 65                     NaN        NaN        NaN                     NaN
# 66                     NaN        NaN        NaN                     NaN
# 67                     NaN        NaN        NaN                     NaN
# 68                     NaN        NaN        NaN                     NaN
# 69                     NaN        NaN        NaN                     NaN
# 70                     NaN        NaN        NaN                     NaN
# 71                     NaN        NaN        NaN                     NaN
# 72                     NaN        NaN        NaN                     NaN
# 73                     NaN        NaN        NaN                     NaN
# 74                     NaN        NaN        NaN                     NaN
# 75                     NaN        NaN        NaN                     NaN
# 76                     NaN        NaN        NaN                     NaN
# 77                     NaN        NaN        NaN                     NaN
# 78                     NaN        NaN        NaN                     NaN
# 79     Total No. of Shares        NaN        Shs                     NaN
# 80           Average Price        NaN        KRW                     NaN
# 81          Considerations        NaN        KRW                     NaN
# 82              Commission        NaN        KRW                     NaN
# 83               Sales Tax        NaN        KRW                     NaN
# 84       Capital Gains Tax        NaN        KRW                     NaN
# 85              Net Amount        NaN        KRW                     NaN
#
#     Unnamed: 4 Unnamed: 5  Unnamed: 6
# 53         Buy        NaN         NaN
# 54         NaN        NaN         NaN
# 55         NaN        NaN         NaN
# 56         NaN        NaN         NaN
# 57          27     /  KRW     91900.0
# 58          37     /  KRW     92000.0
# 59          36     /  KRW     92100.0
# 60          17     /  KRW     92200.0
# 61         155     /  KRW     92300.0
# 62           6     /  KRW     92400.0
# 63          70     /  KRW     92500.0
# 64           1     /  KRW     92700.0
# 65           6     /  KRW     92800.0
# 66          24     /  KRW     92900.0
# 67          96     /  KRW     93000.0
# 68          25     /  KRW     93100.0
# 69          29     /  KRW     93200.0
# 70           1     /  KRW     93300.0
# 71          84     /  KRW     93400.0
# 72         193     /  KRW     93500.0
# 73          40     /  KRW     93600.0
# 74          20     /  KRW     93700.0
# 75          50     /  KRW     93800.0
# 76         252     /  KRW     93900.0
# 77        1062     /  KRW     94000.0
# 78         NaN        NaN         NaN
# 79        2231        NaN         NaN
# 80  93556.6114        NaN         NaN
# 81   208724800        NaN         NaN
# 82      208725        NaN         NaN
# 83           0        NaN         NaN
# 84           0        NaN         NaN
# 85   208933525        NaN         NaN

# %%
df.loc[pairs_trade[2][0]:pairs_trade[2][1], :]
# Out:
#                  Unnamed: 0 Unnamed: 1 Unnamed: 2              Unnamed: 3  \
# 87                     Type        NaN        NaN                     KSE
# 88   ISIN Code / Abbr. Code        NaN        NaN  KR7271560005 / A271560
# 89     Security Description        NaN        NaN                   ORION
# 90                      NaN        NaN        NaN                     NaN
# 91    No. of Shares / Price        NaN        NaN                     NaN
# 92                      NaN        NaN        NaN                     NaN
# 93                      NaN        NaN        NaN                     NaN
# 94                      NaN        NaN        NaN                     NaN
# 95                      NaN        NaN        NaN                     NaN
# 96                      NaN        NaN        NaN                     NaN
# 97                      NaN        NaN        NaN                     NaN
# 98                      NaN        NaN        NaN                     NaN
# 99                      NaN        NaN        NaN                     NaN
# 100                     NaN        NaN        NaN                     NaN
# 101                     NaN        NaN        NaN                     NaN
# 102                     NaN        NaN        NaN                     NaN
# 103                     NaN        NaN        NaN                     NaN
# 104                     NaN        NaN        NaN                     NaN
# 105                     NaN        NaN        NaN                     NaN
# 106                     NaN        NaN        NaN                     NaN
# 107                     NaN        NaN        NaN                     NaN
# 108                     NaN        NaN        NaN                     NaN
# 109                     NaN        NaN        NaN                     NaN
# 110     Total No. of Shares        NaN        Shs                     NaN
# 111           Average Price        NaN        KRW                     NaN
# 112          Considerations        NaN        KRW                     NaN
# 113              Commission        NaN        KRW                     NaN
# 114               Sales Tax        NaN        KRW                     NaN
# 115       Capital Gains Tax        NaN        KRW                     NaN
# 116              Net Amount        NaN        KRW                     NaN
#
#     Unnamed: 4 Unnamed: 5  Unnamed: 6
# 87         Buy        NaN         NaN
# 88         NaN        NaN         NaN
# 89         NaN        NaN         NaN
# 90         NaN        NaN         NaN
# 91          43     /  KRW     87400.0
# 92          90     /  KRW     87500.0
# 93          81     /  KRW     87600.0
# 94          23     /  KRW     87700.0
# 95          23     /  KRW     87800.0
# 96          75     /  KRW     87900.0
# 97          25     /  KRW     88000.0
# 98          71     /  KRW     88100.0
# 99          37     /  KRW     88200.0
# 100        166     /  KRW     88300.0
# 101         42     /  KRW     88400.0
# 102          2     /  KRW     88500.0
# 103         28     /  KRW     88600.0
# 104         32     /  KRW     88700.0
# 105        114     /  KRW     88800.0
# 106         49     /  KRW     88900.0
# 107         51     /  KRW     89000.0
# 108         48     /  KRW     89100.0
# 109        NaN        NaN         NaN
# 110       1000        NaN         NaN
# 111    88238.2        NaN         NaN
# 112   88238200        NaN         NaN
# 113      88238        NaN         NaN
# 114          0        NaN         NaN
# 115          0        NaN         NaN
# 116   88326438        NaN         NaN

# %%
df.loc[pair_info[0]:pair_info[1], :]
# Out:
#                                           Unnamed: 0  \
# 0                                                NaN
# 1                9th Fl. Samsung Electronics Bldg.,
# 2   11, 74-gil Seocho-daero Seocho-gu, Seoul 06620,
# 3                                  Republic of Korea
# 4                                                NaN
# 5                                 Trade Confirmation
# 6                                                NaN
# 7                                               Date
# 8                                                NaN
# 9                                               From
# 10                                                To
# 11                                               NaN
# 12                                      Trade Date :
# 13                                 Settlement Date :
# 14                                               NaN
# 15                                               NaN
# 16                               Our Reference No. :
# 17                                   Korea IRC No. :
# 18                                        A/C Name :
# 19                                               NaN
#
#                           Unnamed: 1 Unnamed: 2                  Unnamed: 3  \
# 0                                NaN        NaN                         NaN
# 1                                NaN        NaN                         NaN
# 2                                NaN        NaN                         NaN
# 3                                NaN        NaN                         NaN
# 4                                NaN        NaN                         NaN
# 5                                NaN        NaN                         NaN
# 6                                NaN        NaN                         NaN
# 7                       09 Sep. 2024        NaN                         NaN
# 8                                NaN        NaN                         NaN
# 9       Samsung Securities Co., Ltd.        NaN                         NaN
# 10  OP INVESTMENT MANAGEMENT LIMITED        NaN                         NaN
# 11                               NaN        NaN                         NaN
# 12                               NaN        NaN                09 Sep. 2024
# 13                               NaN        NaN                11 Sep. 2024
# 14                               NaN        NaN                         NaN
# 15                               NaN        NaN                         NaN
# 16                               NaN        NaN                715543911501
# 17                               NaN        NaN        213800QGQF7FJ5PN1850
# 18                               NaN        NaN  LIFE Korea Engagement Fund
# 19                               NaN        NaN                         NaN
#
#    Unnamed: 4 Unnamed: 5  Unnamed: 6
# 0         NaN        NaN         NaN
# 1         NaN        NaN         NaN
# 2         NaN        NaN         NaN
# 3         NaN        NaN         NaN
# 4         NaN        NaN         NaN
# 5         NaN        NaN         NaN
# 6         NaN        NaN         NaN
# 7         NaN        NaN         NaN
# 8         NaN        NaN         NaN
# 9         NaN        NaN         NaN
# 10        NaN        NaN         NaN
# 11        NaN        NaN         NaN
# 12        NaN        NaN         NaN
# 13        NaN        NaN         NaN
# 14        NaN        NaN         NaN
# 15        NaN        NaN         NaN
# 16        NaN        NaN         NaN
# 17        NaN        NaN         NaN
# 18        NaN        NaN         NaN
# 19        NaN        NaN         NaN

# %%
indices_i = dct_keys['Type']
indices_f = dct_keys['Net Amount']

# %%
df.loc[indices_i[0]:indices_f[0]]
# Out:
#                 Unnamed: 0 Unnamed: 1 Unnamed: 2              Unnamed: 3  \
# 20                    Type        NaN        NaN                     KSE
# 21  ISIN Code / Abbr. Code        NaN        NaN  KR7003030004 / A003030
# 22    Security Description        NaN        NaN     SeAH Steel Holdings
# 23                     NaN        NaN        NaN                     NaN
# 24   No. of Shares / Price        NaN        NaN                     NaN
# 25                     NaN        NaN        NaN                     NaN
# 26                     NaN        NaN        NaN                     NaN
# 27                     NaN        NaN        NaN                     NaN
# 28                     NaN        NaN        NaN                     NaN
# 29                     NaN        NaN        NaN                     NaN
# 30                     NaN        NaN        NaN                     NaN
# 31                     NaN        NaN        NaN                     NaN
# 32                     NaN        NaN        NaN                     NaN
# 33                     NaN        NaN        NaN                     NaN
# 34                     NaN        NaN        NaN                     NaN
# 35                     NaN        NaN        NaN                     NaN
# 36                     NaN        NaN        NaN                     NaN
# 37                     NaN        NaN        NaN                     NaN
# 38                     NaN        NaN        NaN                     NaN
# 39                     NaN        NaN        NaN                     NaN
# 40                     NaN        NaN        NaN                     NaN
# 41                     NaN        NaN        NaN                     NaN
# 42                     NaN        NaN        NaN                     NaN
# 43                     NaN        NaN        NaN                     NaN
# 44                     NaN        NaN        NaN                     NaN
# 45     Total No. of Shares        NaN        Shs                     NaN
# 46           Average Price        NaN        KRW                     NaN
# 47          Considerations        NaN        KRW                     NaN
# 48              Commission        NaN        KRW                     NaN
# 49               Sales Tax        NaN        KRW                     NaN
# 50       Capital Gains Tax        NaN        KRW                     NaN
# 51              Net Amount        NaN        KRW                     NaN
#
#    Unnamed: 4 Unnamed: 5  Unnamed: 6
# 20        Buy        NaN         NaN
# 21        NaN        NaN         NaN
# 22        NaN        NaN         NaN
# 23        NaN        NaN         NaN
# 24          1     /  KRW    172600.0
# 25         15     /  KRW    173200.0
# 26          1     /  KRW    173300.0
# 27          5     /  KRW    173400.0
# 28          6     /  KRW    173500.0
# 29          7     /  KRW    173600.0
# 30         37     /  KRW    173700.0
# 31         37     /  KRW    173800.0
# 32          4     /  KRW    173900.0
# 33         24     /  KRW    174000.0
# 34         48     /  KRW    174100.0
# 35         31     /  KRW    174200.0
# 36         83     /  KRW    174300.0
# 37         26     /  KRW    174400.0
# 38         17     /  KRW    174500.0
# 39         42     /  KRW    174600.0
# 40         28     /  KRW    174700.0
# 41         32     /  KRW    174800.0
# 42         39     /  KRW    174900.0
# 43         17     /  KRW    175000.0
# 44        NaN        NaN         NaN
# 45        500        NaN         NaN
# 46     174271        NaN         NaN
# 47   87135500        NaN         NaN
# 48      87136        NaN         NaN
# 49          0        NaN         NaN
# 50          0        NaN         NaN
# 51   87222636        NaN         NaN

# %%
file_folder['trade']
# Out:
# '/Users/juneyoungpark/dev/module-cayman_office_system/cayman_office_system/dataset-trade'

# %%
file_names = scan_files_including_regex(file_folder=file_folder['trade'], regex='LKEF Trade')
file_names
# Out:
# ['LKEF Trade 20240902.xls',
#  'LKEF Trade 20240905.xls',
#  'LKEF Trade 20240906.xls',
#  'LKEF Trade 20240909.xls']

# %%
df = open_excel(file_folder=file_folder['trade'], file_name=file_names[-1], engine='xlrd')
df
# Out:
#                                             Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0                                                  NaN        NaN        NaN
# 1                  9th Fl. Samsung Electronics Bldg.,         NaN        NaN
# 2     11, 74-gil Seocho-daero Seocho-gu, Seoul 06620,         NaN        NaN
# 3                                    Republic of Korea        NaN        NaN
# 4                                                  NaN        NaN        NaN
# ..                                                 ...        ...        ...
# 129                                                NaN        NaN        NaN
# 130  Please notify us by email (middle.st@samsung.c...        NaN        NaN
# 131  in this confirmation by 5pm (Korea time) on th...        NaN        NaN
# 132  Note we shall not be liable for any indirect o...        NaN        NaN
# 133           incurred in respect of this transaction.        NaN        NaN
#
#     Unnamed: 3 Unnamed: 4 Unnamed: 5  Unnamed: 6
# 0          NaN        NaN        NaN         NaN
# 1          NaN        NaN        NaN         NaN
# 2          NaN        NaN        NaN         NaN
# 3          NaN        NaN        NaN         NaN
# 4          NaN        NaN        NaN         NaN
# ..         ...        ...        ...         ...
# 129        NaN        NaN        NaN         NaN
# 130        NaN        NaN        NaN         NaN
# 131        NaN        NaN        NaN         NaN
# 132        NaN        NaN        NaN         NaN
# 133        NaN        NaN        NaN         NaN
#
# [134 rows x 7 columns]

# %%
keys = sorted(list(df['Unnamed: 0'].dropna()))
keys
# Out:
# [' Trade Confirmation',
#  '*Samsung Securities is a self-clearing house, the same BIC code for both executing and clearing.',
#  '11, 74-gil Seocho-daero Seocho-gu, Seoul 06620, ',
#  '9th Fl. Samsung Electronics Bldg., ',
#  'A/C Name :',
#  'Average Price',
#  'Average Price',
#  'Average Price',
#  'BIC Code : SAMCKRS1',
#  'Capital Gains Tax',
#  'Capital Gains Tax',
#  'Capital Gains Tax',
#  'Commission',
#  'Commission',
#  'Commission',
#  'Considerations',
#  'Considerations',
#  'Considerations',
#  'Date',
#  'From',
#  'ISIN Code / Abbr. Code',
#  'ISIN Code / Abbr. Code',
#  'ISIN Code / Abbr. Code',
#  'KSD Participant Number : 30-0000',
#  'Korea IRC No. :',
#  'Net Amount',
#  'Net Amount',
#  'Net Amount',
#  'No. of Shares / Price',
#  'No. of Shares / Price',
#  'No. of Shares / Price',
#  'Note we shall not be liable for any indirect or consequential loss or for any buy-in or replacement costs, penalties or charges ',
#  'Our Reference No. :',
#  'PSET BIC : KSDCKRSE',
#  'Place of Settlement (PSET) : KSD (Korea Securities Depository)',
#  'Please notify us by email (middle.st@samsung.com/ settle.clearing@samsung.com) of any potential discrepancies or errors',
#  'Republic of Korea',
#  'Sales Tax',
#  'Sales Tax',
#  'Sales Tax',
#  "Samsung Securities's Settlement Instructions",
#  'Security Description',
#  'Security Description',
#  'Security Description',
#  'Settlement Date :',
#  'Settlement Method : Delivery Versus Payment',
#  'To',
#  'Total No. of Shares',
#  'Total No. of Shares',
#  'Total No. of Shares',
#  'Trade Date :',
#  'Type',
#  'Type',
#  'Type',
#  'in this confirmation by 5pm (Korea time) on the business day following the trade date.',
#  'incurred in respect of this transaction.']

# %%
dct_indices = {}
for key in keys:
    indices_of_key = list(df[df['Unnamed: 0']==key].index)
    dct_indices[key] = indices_of_key
dct_indices
# Out:
# {' Trade Confirmation': [5],
#  '*Samsung Securities is a self-clearing house, the same BIC code for both executing and clearing.': [126],
#  '11, 74-gil Seocho-daero Seocho-gu, Seoul 06620, ': [2],
#  '9th Fl. Samsung Electronics Bldg., ': [1],
#  'A/C Name :': [18],
#  'Average Price': [46, 80, 111],
#  'BIC Code : SAMCKRS1': [125],
#  'Capital Gains Tax': [50, 84, 115],
#  'Commission': [48, 82, 113],
#  'Considerations': [47, 81, 112],
#  'Date': [7],
#  'From': [9],
#  'ISIN Code / Abbr. Code': [21, 54, 88],
#  'KSD Participant Number : 30-0000': [124],
#  'Korea IRC No. :': [17],
#  'Net Amount': [51, 85, 116],
#  'No. of Shares / Price': [24, 57, 91],
#  'Note we shall not be liable for any indirect or consequential loss or for any buy-in or replacement costs, penalties or charges ': [132],
#  'Our Reference No. :': [16],
#  'PSET BIC : KSDCKRSE': [123],
#  'Place of Settlement (PSET) : KSD (Korea Securities Depository)': [122],
#  'Please notify us by email (middle.st@samsung.com/ settle.clearing@samsung.com) of any potential discrepancies or errors': [130],
#  'Republic of Korea': [3],
#  'Sales Tax': [49, 83, 114],
#  "Samsung Securities's Settlement Instructions": [119],
#  'Security Description': [22, 55, 89],
#  'Settlement Date :': [13],
#  'Settlement Method : Delivery Versus Payment': [121],
#  'To': [10],
#  'Total No. of Shares': [45, 79, 110],
#  'Trade Date :': [12],
#  'Type': [20, 53, 87],
#  'in this confirmation by 5pm (Korea time) on the business day following the trade date.': [131],
#  'incurred in respect of this transaction.': [133]}

# %%
dct_n = {}
for k, indices in dct_indices.items():
    print('key:', k)
    n = len(indices)
    dct_n[k] = n
dct_n
# Out:
# key:  Trade Confirmation
# key: *Samsung Securities is a self-clearing house, the same BIC code for both executing and clearing.
# key: 11, 74-gil Seocho-daero Seocho-gu, Seoul 06620,
# key: 9th Fl. Samsung Electronics Bldg.,
# key: A/C Name :
# key: Average Price
# key: BIC Code : SAMCKRS1
# key: Capital Gains Tax
# key: Commission
# key: Considerations
# key: Date
# key: From
# key: ISIN Code / Abbr. Code
# key: KSD Participant Number : 30-0000
# key: Korea IRC No. :
# key: Net Amount
# key: No. of Shares / Price
# key: Note we shall not be liable for any indirect or consequential loss or for any buy-in or replacement costs, penalties or charges
# key: Our Reference No. :
# key: PSET BIC : KSDCKRSE
# key: Place of Settlement (PSET) : KSD (Korea Securities Depository)
# key: Please notify us by email (middle.st@samsung.com/ settle.clearing@samsung.com) of any potential discrepancies or errors
# key: Republic of Korea
# key: Sales Tax
# key: Samsung Securities's Settlement Instructions
# key: Security Description
# key: Settlement Date :
# key: Settlement Method : Delivery Versus Payment
# key: To
# key: Total No. of Shares
# key: Trade Date :
# key: Type
# key: in this confirmation by 5pm (Korea time) on the business day following the trade date.
# key: incurred in respect of this transaction.
# {' Trade Confirmation': 1,
#  '*Samsung Securities is a self-clearing house, the same BIC code for both executing and clearing.': 1,
#  '11, 74-gil Seocho-daero Seocho-gu, Seoul 06620, ': 1,
#  '9th Fl. Samsung Electronics Bldg., ': 1,
#  'A/C Name :': 1,
#  'Average Price': 3,
#  'BIC Code : SAMCKRS1': 1,
#  'Capital Gains Tax': 3,
#  'Commission': 3,
#  'Considerations': 3,
#  'Date': 1,
#  'From': 1,
#  'ISIN Code / Abbr. Code': 3,
#  'KSD Participant Number : 30-0000': 1,
#  'Korea IRC No. :': 1,
#  'Net Amount': 3,
#  'No. of Shares / Price': 3,
#  'Note we shall not be liable for any indirect or consequential loss or for any buy-in or replacement costs, penalties or charges ': 1,
#  'Our Reference No. :': 1,
#  'PSET BIC : KSDCKRSE': 1,
#  'Place of Settlement (PSET) : KSD (Korea Securities Depository)': 1,
#  'Please notify us by email (middle.st@samsung.com/ settle.clearing@samsung.com) of any potential discrepancies or errors': 1,
#  'Republic of Korea': 1,
#  'Sales Tax': 3,
#  "Samsung Securities's Settlement Instructions": 1,
#  'Security Description': 3,
#  'Settlement Date :': 1,
#  'Settlement Method : Delivery Versus Payment': 1,
#  'To': 1,
#  'Total No. of Shares': 3,
#  'Trade Date :': 1,
#  'Type': 3,
#  'in this confirmation by 5pm (Korea time) on the business day following the trade date.': 1,
#  'incurred in respect of this transaction.': 1}

# %%
ns = sorted(set(sorted(dct_n.values())))
ns
# Out:
# [1, 3]

# %%
dct_k = {}
for n in ns:
    dct_k[n] = [k for k, v in dct_n.items() if v==n]
dct_k
# Out:
# {1: [' Trade Confirmation',
#   '*Samsung Securities is a self-clearing house, the same BIC code for both executing and clearing.',
#   '11, 74-gil Seocho-daero Seocho-gu, Seoul 06620, ',
#   '9th Fl. Samsung Electronics Bldg., ',
#   'A/C Name :',
#   'BIC Code : SAMCKRS1',
#   'Date',
#   'From',
#   'KSD Participant Number : 30-0000',
#   'Korea IRC No. :',
#   'Note we shall not be liable for any indirect or consequential loss or for any buy-in or replacement costs, penalties or charges ',
#   'Our Reference No. :',
#   'PSET BIC : KSDCKRSE',
#   'Place of Settlement (PSET) : KSD (Korea Securities Depository)',
#   'Please notify us by email (middle.st@samsung.com/ settle.clearing@samsung.com) of any potential discrepancies or errors',
#   'Republic of Korea',
#   "Samsung Securities's Settlement Instructions",
#   'Settlement Date :',
#   'Settlement Method : Delivery Versus Payment',
#   'To',
#   'Trade Date :',
#   'in this confirmation by 5pm (Korea time) on the business day following the trade date.',
#   'incurred in respect of this transaction.'],
#  3: ['Average Price',
#   'Capital Gains Tax',
#   'Commission',
#   'Considerations',
#   'ISIN Code / Abbr. Code',
#   'Net Amount',
#   'No. of Shares / Price',
#   'Sales Tax',
#   'Security Description',
#   'Total No. of Shares',
#   'Type']}

# %%
indices_type = dct_indices['Type'] + [-1]
indices_type
# Out:
# [20, 53, 87, -1]

# %%
index_pairs_type = [(indices_type[i], indices_type[i+1]-1) for i in range(len(indices_type)-1)]
index_pairs_type
# Out:
# [(20, 52), (53, 86), (87, -2)]

# %%
df.loc[index_pairs_type[0][0]:index_pairs_type[0][1], :]
# Out:
#                 Unnamed: 0 Unnamed: 1 Unnamed: 2              Unnamed: 3  \
# 20                    Type        NaN        NaN                     KSE
# 21  ISIN Code / Abbr. Code        NaN        NaN  KR7003030004 / A003030
# 22    Security Description        NaN        NaN     SeAH Steel Holdings
# 23                     NaN        NaN        NaN                     NaN
# 24   No. of Shares / Price        NaN        NaN                     NaN
# 25                     NaN        NaN        NaN                     NaN
# 26                     NaN        NaN        NaN                     NaN
# 27                     NaN        NaN        NaN                     NaN
# 28                     NaN        NaN        NaN                     NaN
# 29                     NaN        NaN        NaN                     NaN
# 30                     NaN        NaN        NaN                     NaN
# 31                     NaN        NaN        NaN                     NaN
# 32                     NaN        NaN        NaN                     NaN
# 33                     NaN        NaN        NaN                     NaN
# 34                     NaN        NaN        NaN                     NaN
# 35                     NaN        NaN        NaN                     NaN
# 36                     NaN        NaN        NaN                     NaN
# 37                     NaN        NaN        NaN                     NaN
# 38                     NaN        NaN        NaN                     NaN
# 39                     NaN        NaN        NaN                     NaN
# 40                     NaN        NaN        NaN                     NaN
# 41                     NaN        NaN        NaN                     NaN
# 42                     NaN        NaN        NaN                     NaN
# 43                     NaN        NaN        NaN                     NaN
# 44                     NaN        NaN        NaN                     NaN
# 45     Total No. of Shares        NaN        Shs                     NaN
# 46           Average Price        NaN        KRW                     NaN
# 47          Considerations        NaN        KRW                     NaN
# 48              Commission        NaN        KRW                     NaN
# 49               Sales Tax        NaN        KRW                     NaN
# 50       Capital Gains Tax        NaN        KRW                     NaN
# 51              Net Amount        NaN        KRW                     NaN
# 52                     NaN        NaN        NaN                     NaN
#
#    Unnamed: 4 Unnamed: 5  Unnamed: 6
# 20        Buy        NaN         NaN
# 21        NaN        NaN         NaN
# 22        NaN        NaN         NaN
# 23        NaN        NaN         NaN
# 24          1     /  KRW    172600.0
# 25         15     /  KRW    173200.0
# 26          1     /  KRW    173300.0
# 27          5     /  KRW    173400.0
# 28          6     /  KRW    173500.0
# 29          7     /  KRW    173600.0
# 30         37     /  KRW    173700.0
# 31         37     /  KRW    173800.0
# 32          4     /  KRW    173900.0
# 33         24     /  KRW    174000.0
# 34         48     /  KRW    174100.0
# 35         31     /  KRW    174200.0
# 36         83     /  KRW    174300.0
# 37         26     /  KRW    174400.0
# 38         17     /  KRW    174500.0
# 39         42     /  KRW    174600.0
# 40         28     /  KRW    174700.0
# 41         32     /  KRW    174800.0
# 42         39     /  KRW    174900.0
# 43         17     /  KRW    175000.0
# 44        NaN        NaN         NaN
# 45        500        NaN         NaN
# 46     174271        NaN         NaN
# 47   87135500        NaN         NaN
# 48      87136        NaN         NaN
# 49          0        NaN         NaN
# 50          0        NaN         NaN
# 51   87222636        NaN         NaN
# 52        NaN        NaN         NaN

# %%
keys_multi = list(dct_k.values())[-1]
keys_multi
# Out:
# ['Average Price',
#  'Capital Gains Tax',
#  'Commission',
#  'Considerations',
#  'ISIN Code / Abbr. Code',
#  'Net Amount',
#  'No. of Shares / Price',
#  'Sales Tax',
#  'Security Description',
#  'Total No. of Shares',
#  'Type']

# %%
df[df['Unnamed: 0']==keys_multi[6]]
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 49   Sales Tax        NaN        KRW        NaN          0        NaN
# 83   Sales Tax        NaN        KRW        NaN          0        NaN
# 114  Sales Tax        NaN        KRW        NaN          0        NaN
#
#      Unnamed: 6
# 49          NaN
# 83          NaN
# 114         NaN

# %%
indices_of_num_of_shares = dct_indices[keys_multi[6]]
indices_of_num_of_shares
# Out:
# [24, 57, 91]

# %%
df[~df['Unnamed: 6'].isna()].loc[indices_of_num_of_shares[0]:indices_of_num_of_shares[1]-1, :]
# Out:
#                Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 24  No. of Shares / Price        NaN        NaN        NaN          1
# 25                    NaN        NaN        NaN        NaN         15
# 26                    NaN        NaN        NaN        NaN          1
# 27                    NaN        NaN        NaN        NaN          5
# 28                    NaN        NaN        NaN        NaN          6
# 29                    NaN        NaN        NaN        NaN          7
# 30                    NaN        NaN        NaN        NaN         37
# 31                    NaN        NaN        NaN        NaN         37
# 32                    NaN        NaN        NaN        NaN          4
# 33                    NaN        NaN        NaN        NaN         24
# 34                    NaN        NaN        NaN        NaN         48
# 35                    NaN        NaN        NaN        NaN         31
# 36                    NaN        NaN        NaN        NaN         83
# 37                    NaN        NaN        NaN        NaN         26
# 38                    NaN        NaN        NaN        NaN         17
# 39                    NaN        NaN        NaN        NaN         42
# 40                    NaN        NaN        NaN        NaN         28
# 41                    NaN        NaN        NaN        NaN         32
# 42                    NaN        NaN        NaN        NaN         39
# 43                    NaN        NaN        NaN        NaN         17
#
#    Unnamed: 5  Unnamed: 6
# 24     /  KRW    172600.0
# 25     /  KRW    173200.0
# 26     /  KRW    173300.0
# 27     /  KRW    173400.0
# 28     /  KRW    173500.0
# 29     /  KRW    173600.0
# 30     /  KRW    173700.0
# 31     /  KRW    173800.0
# 32     /  KRW    173900.0
# 33     /  KRW    174000.0
# 34     /  KRW    174100.0
# 35     /  KRW    174200.0
# 36     /  KRW    174300.0
# 37     /  KRW    174400.0
# 38     /  KRW    174500.0
# 39     /  KRW    174600.0
# 40     /  KRW    174700.0
# 41     /  KRW    174800.0
# 42     /  KRW    174900.0
# 43     /  KRW    175000.0

# %%
df[~df['Unnamed: 6'].isna()].loc[indices_of_num_of_shares[1]:indices_of_num_of_shares[2]-1, :]
# Out:
#                Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 57  No. of Shares / Price        NaN        NaN        NaN         27
# 58                    NaN        NaN        NaN        NaN         37
# 59                    NaN        NaN        NaN        NaN         36
# 60                    NaN        NaN        NaN        NaN         17
# 61                    NaN        NaN        NaN        NaN        155
# 62                    NaN        NaN        NaN        NaN          6
# 63                    NaN        NaN        NaN        NaN         70
# 64                    NaN        NaN        NaN        NaN          1
# 65                    NaN        NaN        NaN        NaN          6
# 66                    NaN        NaN        NaN        NaN         24
# 67                    NaN        NaN        NaN        NaN         96
# 68                    NaN        NaN        NaN        NaN         25
# 69                    NaN        NaN        NaN        NaN         29
# 70                    NaN        NaN        NaN        NaN          1
# 71                    NaN        NaN        NaN        NaN         84
# 72                    NaN        NaN        NaN        NaN        193
# 73                    NaN        NaN        NaN        NaN         40
# 74                    NaN        NaN        NaN        NaN         20
# 75                    NaN        NaN        NaN        NaN         50
# 76                    NaN        NaN        NaN        NaN        252
# 77                    NaN        NaN        NaN        NaN       1062
#
#    Unnamed: 5  Unnamed: 6
# 57     /  KRW     91900.0
# 58     /  KRW     92000.0
# 59     /  KRW     92100.0
# 60     /  KRW     92200.0
# 61     /  KRW     92300.0
# 62     /  KRW     92400.0
# 63     /  KRW     92500.0
# 64     /  KRW     92700.0
# 65     /  KRW     92800.0
# 66     /  KRW     92900.0
# 67     /  KRW     93000.0
# 68     /  KRW     93100.0
# 69     /  KRW     93200.0
# 70     /  KRW     93300.0
# 71     /  KRW     93400.0
# 72     /  KRW     93500.0
# 73     /  KRW     93600.0
# 74     /  KRW     93700.0
# 75     /  KRW     93800.0
# 76     /  KRW     93900.0
# 77     /  KRW     94000.0

# %%
indices = dct[keys_multi[1]]
indices
# Out:
# [50, 84, 115]

# %%
df.iloc[indices[0]]
# Out:
# incurred in respect of this transaction.
# Unnamed: 0    Capital Gains Tax
# Unnamed: 1                  NaN
# Unnamed: 2                  KRW
# Unnamed: 3                  NaN
# Unnamed: 4                    0
# Unnamed: 5                  NaN
# Unnamed: 6                  NaN
# Name: 50, dtype: object

# %%
for k, n in dct_n.items():
    for n in ns:
        if n == dct_n[k]:
            print(k, n)

# %%
bucket[6]
# Out:
# incurred in respect of this transaction.           Unnamed: 0 Unnamed: 1  \
# 125                                       BIC Code : SAMCKRS1        NaN
#
# incurred in respect of this transaction. Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 125                                             NaN        NaN        NaN
#
# incurred in respect of this transaction. Unnamed: 5  Unnamed: 6
# 125                                             NaN         NaN

# %%
indices_division = [0] + list(df[df['Unnamed: 0']=='Type'].index) + [-1]
indices_division
# Out:
# [0, 20, 53, 87, -1]

# %%
def get_indices_division_of_sibject(df, subject):
    indices_division = [0] + list(df[df['Unnamed: 0']==subject].index) + [-1]
    return indices_division

# %%
df1 = df.iloc[indices_division[0]:indices_division[1], :]
df1 = df1.dropna(axis=0, how='all')
df1 = df1.dropna(axis=1, how='all')
df1
# Out:
#                                           Unnamed: 0  \
# 1                9th Fl. Samsung Electronics Bldg.,
# 2   11, 74-gil Seocho-daero Seocho-gu, Seoul 06620,
# 3                                  Republic of Korea
# 5                                 Trade Confirmation
# 7                                               Date
# 9                                               From
# 10                                                To
# 12                                      Trade Date :
# 13                                 Settlement Date :
# 16                               Our Reference No. :
# 17                                   Korea IRC No. :
# 18                                        A/C Name :
#
#                           Unnamed: 1                  Unnamed: 3
# 1                                NaN                         NaN
# 2                                NaN                         NaN
# 3                                NaN                         NaN
# 5                                NaN                         NaN
# 7                       09 Sep. 2024                         NaN
# 9       Samsung Securities Co., Ltd.                         NaN
# 10  OP INVESTMENT MANAGEMENT LIMITED                         NaN
# 12                               NaN                09 Sep. 2024
# 13                               NaN                11 Sep. 2024
# 16                               NaN                715543911501
# 17                               NaN        213800QGQF7FJ5PN1850
# 18                               NaN  LIFE Korea Engagement Fund

# %%
df2 = df.iloc[indices_division[1]:indices_division[2], :]
df2 = df2.dropna(axis=0, how='all')
df2 = df2.dropna(axis=1, how='all')
df2
# Out:
#                 Unnamed: 0 Unnamed: 2              Unnamed: 3 Unnamed: 4  \
# 20                    Type        NaN                     KSE        Buy
# 21  ISIN Code / Abbr. Code        NaN  KR7003030004 / A003030        NaN
# 22    Security Description        NaN     SeAH Steel Holdings        NaN
# 24   No. of Shares / Price        NaN                     NaN          1
# 25                     NaN        NaN                     NaN         15
# 26                     NaN        NaN                     NaN          1
# 27                     NaN        NaN                     NaN          5
# 28                     NaN        NaN                     NaN          6
# 29                     NaN        NaN                     NaN          7
# 30                     NaN        NaN                     NaN         37
# 31                     NaN        NaN                     NaN         37
# 32                     NaN        NaN                     NaN          4
# 33                     NaN        NaN                     NaN         24
# 34                     NaN        NaN                     NaN         48
# 35                     NaN        NaN                     NaN         31
# 36                     NaN        NaN                     NaN         83
# 37                     NaN        NaN                     NaN         26
# 38                     NaN        NaN                     NaN         17
# 39                     NaN        NaN                     NaN         42
# 40                     NaN        NaN                     NaN         28
# 41                     NaN        NaN                     NaN         32
# 42                     NaN        NaN                     NaN         39
# 43                     NaN        NaN                     NaN         17
# 45     Total No. of Shares        Shs                     NaN        500
# 46           Average Price        KRW                     NaN     174271
# 47          Considerations        KRW                     NaN   87135500
# 48              Commission        KRW                     NaN      87136
# 49               Sales Tax        KRW                     NaN          0
# 50       Capital Gains Tax        KRW                     NaN          0
# 51              Net Amount        KRW                     NaN   87222636
#
#    Unnamed: 5  Unnamed: 6
# 20        NaN         NaN
# 21        NaN         NaN
# 22        NaN         NaN
# 24     /  KRW    172600.0
# 25     /  KRW    173200.0
# 26     /  KRW    173300.0
# 27     /  KRW    173400.0
# 28     /  KRW    173500.0
# 29     /  KRW    173600.0
# 30     /  KRW    173700.0
# 31     /  KRW    173800.0
# 32     /  KRW    173900.0
# 33     /  KRW    174000.0
# 34     /  KRW    174100.0
# 35     /  KRW    174200.0
# 36     /  KRW    174300.0
# 37     /  KRW    174400.0
# 38     /  KRW    174500.0
# 39     /  KRW    174600.0
# 40     /  KRW    174700.0
# 41     /  KRW    174800.0
# 42     /  KRW    174900.0
# 43     /  KRW    175000.0
# 45        NaN         NaN
# 46        NaN         NaN
# 47        NaN         NaN
# 48        NaN         NaN
# 49        NaN         NaN
# 50        NaN         NaN
# 51        NaN         NaN

# %%
df = df2.T 
df.columns = df.iloc[0, :]
df = df.iloc[1:, :]
df
# Out:
# Unnamed: 0 Type  ISIN Code / Abbr. Code Security Description  \
# Unnamed: 2  NaN                     NaN                  NaN
# Unnamed: 3  KSE  KR7003030004 / A003030  SeAH Steel Holdings
# Unnamed: 4  Buy                     NaN                  NaN
# Unnamed: 5  NaN                     NaN                  NaN
# Unnamed: 6  NaN                     NaN                  NaN
#
# Unnamed: 0 No. of Shares / Price       NaN       NaN       NaN       NaN  \
# Unnamed: 2                   NaN       NaN       NaN       NaN       NaN
# Unnamed: 3                   NaN       NaN       NaN       NaN       NaN
# Unnamed: 4                     1        15         1         5         6
# Unnamed: 5                /  KRW    /  KRW    /  KRW    /  KRW    /  KRW
# Unnamed: 6              172600.0  173200.0  173300.0  173400.0  173500.0
#
# Unnamed: 0       NaN       NaN  ...       NaN       NaN       NaN  \
# Unnamed: 2       NaN       NaN  ...       NaN       NaN       NaN
# Unnamed: 3       NaN       NaN  ...       NaN       NaN       NaN
# Unnamed: 4         7        37  ...        32        39        17
# Unnamed: 5    /  KRW    /  KRW  ...    /  KRW    /  KRW    /  KRW
# Unnamed: 6  173600.0  173700.0  ...  174800.0  174900.0  175000.0
#
# Unnamed: 0 Total No. of Shares Average Price Considerations Commission  \
# Unnamed: 2                 Shs           KRW            KRW        KRW
# Unnamed: 3                 NaN           NaN            NaN        NaN
# Unnamed: 4                 500        174271       87135500      87136
# Unnamed: 5                 NaN           NaN            NaN        NaN
# Unnamed: 6                 NaN           NaN            NaN        NaN
#
# Unnamed: 0 Sales Tax Capital Gains Tax Net Amount
# Unnamed: 2       KRW               KRW        KRW
# Unnamed: 3       NaN               NaN        NaN
# Unnamed: 4         0                 0   87222636
# Unnamed: 5       NaN               NaN        NaN
# Unnamed: 6       NaN               NaN        NaN
#
# [5 rows x 30 columns]

# %%
df['Type'].dropna()
# Out:
# Unnamed: 3    KSE
# Unnamed: 4    Buy
# Name: Type, dtype: object

# %%
df3 = df.iloc[indices_division[2]:indices_division[3], :]
df3 = df3.dropna(axis=0, how='all')
df3 = df3.dropna(axis=1, how='all')
df3
# Out:
#                 Unnamed: 0 Unnamed: 2              Unnamed: 3  Unnamed: 4  \
# 53                    Type        NaN                     KSE         Buy
# 54  ISIN Code / Abbr. Code        NaN  KR7007340003 / A007340         NaN
# 55    Security Description        NaN           DN AUTOMOTIVE         NaN
# 57   No. of Shares / Price        NaN                     NaN          27
# 58                     NaN        NaN                     NaN          37
# 59                     NaN        NaN                     NaN          36
# 60                     NaN        NaN                     NaN          17
# 61                     NaN        NaN                     NaN         155
# 62                     NaN        NaN                     NaN           6
# 63                     NaN        NaN                     NaN          70
# 64                     NaN        NaN                     NaN           1
# 65                     NaN        NaN                     NaN           6
# 66                     NaN        NaN                     NaN          24
# 67                     NaN        NaN                     NaN          96
# 68                     NaN        NaN                     NaN          25
# 69                     NaN        NaN                     NaN          29
# 70                     NaN        NaN                     NaN           1
# 71                     NaN        NaN                     NaN          84
# 72                     NaN        NaN                     NaN         193
# 73                     NaN        NaN                     NaN          40
# 74                     NaN        NaN                     NaN          20
# 75                     NaN        NaN                     NaN          50
# 76                     NaN        NaN                     NaN         252
# 77                     NaN        NaN                     NaN        1062
# 79     Total No. of Shares        Shs                     NaN        2231
# 80           Average Price        KRW                     NaN  93556.6114
# 81          Considerations        KRW                     NaN   208724800
# 82              Commission        KRW                     NaN      208725
# 83               Sales Tax        KRW                     NaN           0
# 84       Capital Gains Tax        KRW                     NaN           0
# 85              Net Amount        KRW                     NaN   208933525
#
#    Unnamed: 5  Unnamed: 6
# 53        NaN         NaN
# 54        NaN         NaN
# 55        NaN         NaN
# 57     /  KRW     91900.0
# 58     /  KRW     92000.0
# 59     /  KRW     92100.0
# 60     /  KRW     92200.0
# 61     /  KRW     92300.0
# 62     /  KRW     92400.0
# 63     /  KRW     92500.0
# 64     /  KRW     92700.0
# 65     /  KRW     92800.0
# 66     /  KRW     92900.0
# 67     /  KRW     93000.0
# 68     /  KRW     93100.0
# 69     /  KRW     93200.0
# 70     /  KRW     93300.0
# 71     /  KRW     93400.0
# 72     /  KRW     93500.0
# 73     /  KRW     93600.0
# 74     /  KRW     93700.0
# 75     /  KRW     93800.0
# 76     /  KRW     93900.0
# 77     /  KRW     94000.0
# 79        NaN         NaN
# 80        NaN         NaN
# 81        NaN         NaN
# 82        NaN         NaN
# 83        NaN         NaN
# 84        NaN         NaN
# 85        NaN         NaN

# %%
df4 = df.iloc[indices_division[3]:indices_division[4], :]
df4 = df4.dropna(axis=0, how='all')
df4 = df4.dropna(axis=1, how='all')
df4
# Out:
#                                             Unnamed: 0 Unnamed: 2  \
# 87                                                Type        NaN
# 88                              ISIN Code / Abbr. Code        NaN
# 89                                Security Description        NaN
# 91                               No. of Shares / Price        NaN
# 92                                                 NaN        NaN
# 93                                                 NaN        NaN
# 94                                                 NaN        NaN
# 95                                                 NaN        NaN
# 96                                                 NaN        NaN
# 97                                                 NaN        NaN
# 98                                                 NaN        NaN
# 99                                                 NaN        NaN
# 100                                                NaN        NaN
# 101                                                NaN        NaN
# 102                                                NaN        NaN
# 103                                                NaN        NaN
# 104                                                NaN        NaN
# 105                                                NaN        NaN
# 106                                                NaN        NaN
# 107                                                NaN        NaN
# 108                                                NaN        NaN
# 110                                Total No. of Shares        Shs
# 111                                      Average Price        KRW
# 112                                     Considerations        KRW
# 113                                         Commission        KRW
# 114                                          Sales Tax        KRW
# 115                                  Capital Gains Tax        KRW
# 116                                         Net Amount        KRW
# 119       Samsung Securities's Settlement Instructions        NaN
# 121        Settlement Method : Delivery Versus Payment        NaN
# 122  Place of Settlement (PSET) : KSD (Korea Securi...        NaN
# 123                                PSET BIC : KSDCKRSE        NaN
# 124                   KSD Participant Number : 30-0000        NaN
# 125                                BIC Code : SAMCKRS1        NaN
# 126  *Samsung Securities is a self-clearing house, ...        NaN
# 130  Please notify us by email (middle.st@samsung.c...        NaN
# 131  in this confirmation by 5pm (Korea time) on th...        NaN
# 132  Note we shall not be liable for any indirect o...        NaN
#
#                  Unnamed: 3 Unnamed: 4 Unnamed: 5  Unnamed: 6
# 87                      KSE        Buy        NaN         NaN
# 88   KR7271560005 / A271560        NaN        NaN         NaN
# 89                    ORION        NaN        NaN         NaN
# 91                      NaN         43     /  KRW     87400.0
# 92                      NaN         90     /  KRW     87500.0
# 93                      NaN         81     /  KRW     87600.0
# 94                      NaN         23     /  KRW     87700.0
# 95                      NaN         23     /  KRW     87800.0
# 96                      NaN         75     /  KRW     87900.0
# 97                      NaN         25     /  KRW     88000.0
# 98                      NaN         71     /  KRW     88100.0
# 99                      NaN         37     /  KRW     88200.0
# 100                     NaN        166     /  KRW     88300.0
# 101                     NaN         42     /  KRW     88400.0
# 102                     NaN          2     /  KRW     88500.0
# 103                     NaN         28     /  KRW     88600.0
# 104                     NaN         32     /  KRW     88700.0
# 105                     NaN        114     /  KRW     88800.0
# 106                     NaN         49     /  KRW     88900.0
# 107                     NaN         51     /  KRW     89000.0
# 108                     NaN         48     /  KRW     89100.0
# 110                     NaN       1000        NaN         NaN
# 111                     NaN    88238.2        NaN         NaN
# 112                     NaN   88238200        NaN         NaN
# 113                     NaN      88238        NaN         NaN
# 114                     NaN          0        NaN         NaN
# 115                     NaN          0        NaN         NaN
# 116                     NaN   88326438        NaN         NaN
# 119                     NaN        NaN        NaN         NaN
# 121                     NaN        NaN        NaN         NaN
# 122                     NaN        NaN        NaN         NaN
# 123                     NaN        NaN        NaN         NaN
# 124                     NaN        NaN        NaN         NaN
# 125                     NaN        NaN        NaN         NaN
# 126                     NaN        NaN        NaN         NaN
# 130                     NaN        NaN        NaN         NaN
# 131                     NaN        NaN        NaN         NaN
# 132                     NaN        NaN        NaN         NaN

# %%
list(df.iloc[:, 0])
# Out:
# [nan,
#  '9th Fl. Samsung Electronics Bldg., ',
#  '11, 74-gil Seocho-daero Seocho-gu, Seoul 06620, ',
#  'Republic of Korea',
#  nan,
#  ' Trade Confirmation',
#  nan,
#  'Date',
#  nan,
#  'From',
#  'To',
#  nan,
#  'Trade Date :',
#  'Settlement Date :',
#  nan,
#  nan,
#  'Our Reference No. :',
#  'Korea IRC No. :',
#  'A/C Name :',
#  nan,
#  'Type',
#  'ISIN Code / Abbr. Code',
#  'Security Description',
#  nan,
#  'No. of Shares / Price',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Total No. of Shares',
#  'Average Price',
#  'Considerations',
#  'Commission',
#  'Sales Tax',
#  'Capital Gains Tax',
#  'Net Amount',
#  nan,
#  'Type',
#  'ISIN Code / Abbr. Code',
#  'Security Description',
#  nan,
#  'No. of Shares / Price',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Total No. of Shares',
#  'Average Price',
#  'Considerations',
#  'Commission',
#  'Sales Tax',
#  'Capital Gains Tax',
#  'Net Amount',
#  nan,
#  'Type',
#  'ISIN Code / Abbr. Code',
#  'Security Description',
#  nan,
#  'No. of Shares / Price',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Total No. of Shares',
#  'Average Price',
#  'Considerations',
#  'Commission',
#  'Sales Tax',
#  'Capital Gains Tax',
#  'Net Amount',
#  nan,
#  nan,
#  "Samsung Securities's Settlement Instructions",
#  nan,
#  'Settlement Method : Delivery Versus Payment',
#  'Place of Settlement (PSET) : KSD (Korea Securities Depository)',
#  'PSET BIC : KSDCKRSE',
#  'KSD Participant Number : 30-0000',
#  'BIC Code : SAMCKRS1',
#  '*Samsung Securities is a self-clearing house, the same BIC code for both executing and clearing.',
#  nan,
#  nan,
#  nan,
#  'Please notify us by email (middle.st@samsung.com/ settle.clearing@samsung.com) of any potential discrepancies or errors',
#  'in this confirmation by 5pm (Korea time) on the business day following the trade date.',
#  'Note we shall not be liable for any indirect or consequential loss or for any buy-in or replacement costs, penalties or charges ',
#  'incurred in respect of this transaction.']

# %%
list(df.iloc[:, 2])
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Shs',
#  'KRW',
#  'KRW',
#  'KRW',
#  'KRW',
#  'KRW',
#  'KRW',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Shs',
#  'KRW',
#  'KRW',
#  'KRW',
#  'KRW',
#  'KRW',
#  'KRW',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Shs',
#  'KRW',
#  'KRW',
#  'KRW',
#  'KRW',
#  'KRW',
#  'KRW',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan]
