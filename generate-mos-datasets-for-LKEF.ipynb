# %%
from cayman_office_system import *
# Out:
# INFO:shining_pebbles:Shining Pebbles package initialized
# INFO:numexpr.utils:Note: NumExpr detected 10 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# /Users/juneyoungpark/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
trades = Trades()
# Out:
# - import trade of (date, index) = (2024-09-02, None)
# - net_amount: 614581438.0
# - import trade of (date, index) = (2024-09-05, None)
# - net_amount: 529470241.0
# - import trade of (date, index) = (2024-09-06, None)
# - net_amount: 91060069.0
# - import trade of (date, index) = (2024-09-09, None)
# - net_amount: 384482599.0
# - import trade of (date, index) = (2024-09-10, None)
# - net_amount: 625076151.0
# - import trade of (date, index) = (2024-09-12, None)
# - net_amount: 528686258.0
# - import trade of (date, index) = (2024-09-13, None)
# - net_amount: 519691172.0
# - import trade of (date, index) = (2024-09-19, None)
# - net_amount: 727234488.0
# - import trade of (date, index) = (2024-09-20, None)
# - net_amount: 1931465216.0
# - import trade of (date, index) = (2024-09-23, None)
# - net_amount: 726876600.0
# - import trade of (date, index) = (2024-09-24, None)
# - net_amount: 1282227226.0
# - import trade of (date, index) = (2024-09-26, None)
# - net_amount: 405884829.0

# %%
lkef = CaymanFund(trades=trades)

# %%
df_nav = lkef.get_timeseries_nav()
df_nav
# Out:
#                  nav_krw       nav_usd    price_krw    price_usd  return_krw  \
# date
# 2024-09-01  2.050955e+10  1.533081e+07  1000.000000  1000.000000    0.000000
# 2024-09-02  2.051594e+10  1.532928e+07  1000.311587   999.900505    0.031159
# 2024-09-03  2.058266e+10  1.533845e+07  1003.564665  1000.498404    0.325206
# 2024-09-04  2.056874e+10  1.532807e+07  1002.885713   999.821527   -0.067654
# 2024-09-05  2.046552e+10  1.533515e+07   997.853107  1000.283157   -0.501812
# 2024-09-06  2.046317e+10  1.532822e+07   997.738703   999.831338   -0.011465
# 2024-09-07  2.046317e+10  1.532822e+07   997.738703   999.831338    0.000000
# 2024-09-08  2.046317e+10  1.532822e+07   997.738703   999.831338    0.000000
# 2024-09-09  2.048584e+10  1.534520e+07   998.843925  1000.938878    0.110773
# 2024-09-10  2.055091e+10  1.529086e+07  1002.016513   997.394115    0.317626
# 2024-09-11  2.052352e+10  1.531263e+07  1000.681073   998.814548   -0.133275
# ...

# %%
df_nav.to_csv(f'dataset-lkef-nav-save{get_today()}.csv')

# %%
df_weight = lkef.timeseries
df_weight
# Out:
#                 cash_usd      cash_krw     stock_usd     stock_krw  \
# date
# 2024-09-01  1.533081e+07  2.050955e+10  0.000000e+00  0.000000e+00
# 2024-09-02  1.487160e+07  1.990340e+10  4.576830e+05  6.125400e+08
# 2024-09-03  1.487160e+07  1.995620e+10  4.668492e+05  6.264650e+08
# 2024-09-04  1.487160e+07  1.995620e+10  4.564722e+05  6.125400e+08
# 2024-09-05  1.447486e+07  1.931742e+10  8.602900e+05  1.148100e+09
# 2024-09-06  1.440665e+07  1.923287e+10  9.215730e+05  1.230300e+09
# 2024-09-07  1.440665e+07  1.923287e+10  9.215730e+05  1.230300e+09
# 2024-09-08  1.440665e+07  1.923287e+10  9.215730e+05  1.230300e+09
# 2024-09-09  1.411865e+07  1.884839e+10  1.226554e+06  1.637450e+09
# 2024-09-10  1.365356e+07  1.835038e+10  1.637297e+06  2.200527e+09
# 2024-09-11  1.365356e+07  1.829987e+10  1.659073e+06  2.223656e+09
# 2024-09-12  1.325961e+07  1.779439e+10  2.102452e+06  2.821491e+09
# 2024-09-13  1.286990e+07  1.716266e+10  2.472397e+06  3.297064e+09
# ...

# %%
df_weight.to_csv(f'dataset-lkef-weight-save{get_today()}.csv')

# %%
df_holdings = lkef.holdings.pl
df_holdings
# Out:
#                                    name  num_shares    net_amount  \
# ticker
# 000660 KS                  SK HYNIX INC        5500  8.983855e+08
# 003030 KS      SEAH STEEL HOLDINGS CORP        5999  1.078803e+09
# 006040 KS     DONGWON INDUSTRIES CO LTD       10000  3.127836e+08
# 007340 KS            DN AUTOMOTIVE CORP       29231  2.816697e+09
# 023160 KS                TK CORPORATION       40000  5.788190e+08
# 271560 KS  ORION CORP/REPUBLIC OF KOREA       21800  1.979422e+09
# 282690 KS  DONG AH TIRE & RUBBER CO LTD        2500  3.255249e+07
# 316140 KS     WOORI FINANCIAL GROUP INC       42500  6.692726e+08
#
#              evaluation           pl  price_average  price_last    return
# ticker
# 000660 KS  9.300500e+08   31664513.0  163342.815818    169100.0  3.524602
# 003030 KS  1.027029e+09  -51774426.0  179830.509418    171200.0 -4.799246
# 006040 KS  3.105000e+08   -2283571.0   31278.357100     31050.0 -0.730080
# ...

# %%
get_price_of_date_by_ticker(ticker='000660 KS', date='2024-09-30')
# Out:
# 174600
