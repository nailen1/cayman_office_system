# %%
from cayman_office_system import *
# Out:
# INFO:shining_pebbles:Shining Pebbles package initialized
# INFO:numexpr.utils:Note: NumExpr detected 10 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# /Users/juneyoungpark/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
acc = Account()
# Out:
# - set (date, index) = (2024-09-02, None)
# - net_amount: 614581438.0
# - set (date, index) = (2024-09-05, None)
# - net_amount: 529470241.0
# - set (date, index) = (2024-09-06, None)
# - net_amount: 91060069.0
# - set (date, index) = (2024-09-09, None)
# - net_amount: 384482599.0
# - set (date, index) = (2024-09-10, None)
# - net_amount: 625076151.0
# - set (date, index) = (2024-09-12, None)
# - net_amount: 528686258.0
# - set (date, index) = (2024-09-13, None)
# - net_amount: 519691172.0
# - set (date, index) = (2024-09-19, None)
# - net_amount: 727234488.0
# - set (date, index) = (2024-09-20, None)
# - net_amount: 1931465216.0

# %%
acc.get_timeseries_nav(currency='krw')
# Out:
#                 cash_krw     stock_krw       nav_krw  weight_cash  \
# date
# 2024-09-01  2.050955e+10  0.000000e+00  2.050955e+10   100.000000
# 2024-09-02  1.990340e+10  6.125400e+08  2.051594e+10    97.014322
# 2024-09-03  1.990340e+10  6.264650e+08  2.052987e+10    96.956346
# 2024-09-04  1.990340e+10  6.125400e+08  2.051594e+10    97.008141
# 2024-09-05  1.931742e+10  1.148100e+09  2.046552e+10    94.390077
# 2024-09-06  1.923287e+10  1.230300e+09  2.046317e+10    93.987736
# 2024-09-09  1.884839e+10  1.637450e+09  2.048584e+10    92.006918
# 2024-09-10  1.835038e+10  2.200527e+09  2.055091e+10    89.292314
# 2024-09-11  1.835038e+10  2.223656e+09  2.057404e+10    89.165330
# 2024-09-12  1.779439e+10  2.821491e+09  2.061588e+10    86.313993
# 2024-09-13  1.716266e+10  3.297064e+09  2.045972e+10    83.885095
# 2024-09-19  1.637751e+10  4.076298e+09  2.045380e+10    80.070711
# 2024-09-20  1.444604e+10  6.158816e+09  2.060486e+10    70.109882
#
#             weight_stock
# date
# 2024-09-01      0.000000
# 2024-09-02      2.985678
# 2024-09-03      3.043654
# 2024-09-04      2.991859
# 2024-09-05      5.609923
# 2024-09-06      6.012264
# 2024-09-09      7.993082
# 2024-09-10     10.707686
# 2024-09-11     10.834670
# 2024-09-12     13.686007
# 2024-09-13     16.114905
# 2024-09-19     19.929289
# 2024-09-20     29.890118

# %%
nav = acc.nav
nav
# Out:
#                 cash_usd     stock_usd       nav_usd  weight_cash  \
# date
# 2024-09-01  1.533081e+07  0.000000e+00  1.533081e+07   100.000000
# 2024-09-02  1.487160e+07  4.576830e+05  1.532928e+07    97.014322
# 2024-09-03  1.487160e+07  4.668492e+05  1.533845e+07    96.956346
# 2024-09-04  1.487160e+07  4.586597e+05  1.533026e+07    97.008141
# 2024-09-05  1.447486e+07  8.602900e+05  1.533515e+07    94.390077
# 2024-09-06  1.440665e+07  9.215730e+05  1.532822e+07    93.987736
# 2024-09-09  1.411865e+07  1.226554e+06  1.534520e+07    92.006918
# 2024-09-10  1.365356e+07  1.637297e+06  1.529086e+07    89.292314
# 2024-09-11  1.365356e+07  1.659073e+06  1.531263e+07    89.165330
# 2024-09-12  1.325961e+07  2.102452e+06  1.536206e+07    86.313993
# 2024-09-13  1.286990e+07  2.472397e+06  1.534230e+07    83.885095
# 2024-09-19  1.232272e+07  3.067076e+06  1.538979e+07    80.070711
# 2024-09-20  1.086945e+07  4.633999e+06  1.550345e+07    70.109882
#
#             weight_stock
# date
# 2024-09-01      0.000000
# 2024-09-02      2.985678
# 2024-09-03      3.043654
# 2024-09-04      2.991859
# 2024-09-05      5.609923
# 2024-09-06      6.012264
# 2024-09-09      7.993082
# 2024-09-10     10.707686
# 2024-09-11     10.834670
# 2024-09-12     13.686007
# 2024-09-13     16.114905
# 2024-09-19     19.929289
# 2024-09-20     29.890118

# %%
cash = acc.cash
cash
# Out:
#                 cash_usd      cash_krw
# date
# 2024-09-01  1.533081e+07  2.050955e+10
# 2024-09-02  1.487160e+07  1.990340e+10
# 2024-09-05  1.447486e+07  1.931742e+10
# 2024-09-06  1.440665e+07  1.923287e+10
# 2024-09-09  1.411865e+07  1.884839e+10
# 2024-09-10  1.365356e+07  1.835038e+10
# 2024-09-12  1.325961e+07  1.779439e+10
# 2024-09-13  1.286990e+07  1.716266e+10
# 2024-09-19  1.232272e+07  1.637751e+10
# 2024-09-20  1.086945e+07  1.444604e+10

# %%
eval = acc.evaluation
eval
# Out:
#                stock_usd     stock_krw
# date
# 2024-09-02  4.576830e+05  6.125400e+08
# 2024-09-03  4.668492e+05  6.264650e+08
# 2024-09-04  4.586597e+05  6.125400e+08
# 2024-09-05  8.602900e+05  1.148100e+09
# 2024-09-06  9.215730e+05  1.230300e+09
# 2024-09-09  1.226554e+06  1.637450e+09
# 2024-09-10  1.637297e+06  2.200527e+09
# 2024-09-11  1.659073e+06  2.223656e+09
# 2024-09-12  2.102452e+06  2.821491e+09
# 2024-09-13  2.472397e+06  3.297064e+09
# 2024-09-19  3.067076e+06  4.076298e+09
# 2024-09-20  4.633999e+06  6.158816e+09

# %%
trades = Trades()
# Out:
# - set (date, index) = (2024-09-02, None)
# - net_amount: 614581438.0
# - set (date, index) = (2024-09-05, None)
# - net_amount: 529470241.0
# - set (date, index) = (2024-09-06, None)
# - net_amount: 91060069.0
# - set (date, index) = (2024-09-09, None)
# - net_amount: 384482599.0
# - set (date, index) = (2024-09-10, None)
# - net_amount: 625076151.0
# - set (date, index) = (2024-09-12, None)
# - net_amount: 528686258.0
# - set (date, index) = (2024-09-13, None)
# - net_amount: 519691172.0
# - set (date, index) = (2024-09-19, None)
# - net_amount: 727234488.0
# - set (date, index) = (2024-09-20, None)
# - net_amount: 1931465216.0

# %%
trades.pl
# Out:
#           date     ticker                          name  num_shares  \
# 0   2024-09-02  003030 KS      SEAH STEEL HOLDINGS CORP         900
# 1   2024-09-02  007340 KS            DN AUTOMOTIVE CORP        2500
# 2   2024-09-02  271560 KS  ORION CORP/REPUBLIC OF KOREA        2200
# 3   2024-09-02  282690 KS  DONG AH TIRE & RUBBER CO LTD        2500
# 4   2024-09-05  003030 KS      SEAH STEEL HOLDINGS CORP         800
# 5   2024-09-05  007340 KS            DN AUTOMOTIVE CORP        2500
# 6   2024-09-05  271560 KS  ORION CORP/REPUBLIC OF KOREA        1800
# 7   2024-09-06  007340 KS            DN AUTOMOTIVE CORP        1000
# 8   2024-09-09  003030 KS      SEAH STEEL HOLDINGS CORP         500
# 9   2024-09-09  007340 KS            DN AUTOMOTIVE CORP        2231
# 10  2024-09-09  271560 KS  ORION CORP/REPUBLIC OF KOREA        1000
# 11  2024-09-10  000660 KS                  SK HYNIX INC        1200
# 12  2024-09-10  003030 KS      SEAH STEEL HOLDINGS CORP         200
# 13  2024-09-10  007340 KS            DN AUTOMOTIVE CORP        3500
# 14  2024-09-10  271560 KS  ORION CORP/REPUBLIC OF KOREA        1000
# 15  2024-09-12  000660 KS                  SK HYNIX INC        1200
# 16  2024-09-12  003030 KS      SEAH STEEL HOLDINGS CORP         350
# 17  2024-09-12  007340 KS            DN AUTOMOTIVE CORP        1500
# 18  2024-09-12  271560 KS  ORION CORP/REPUBLIC OF KOREA        1400
# 19  2024-09-13  000660 KS                  SK HYNIX INC        1200
# 20  2024-09-13  003030 KS      SEAH STEEL HOLDINGS CORP         350
# 21  2024-09-13  007340 KS            DN AUTOMOTIVE CORP        1500
# 22  2024-09-13  271560 KS  ORION CORP/REPUBLIC OF KOREA        1400
# 23  2024-09-19  003030 KS      SEAH STEEL HOLDINGS CORP         699
# 24  2024-09-19  007340 KS            DN AUTOMOTIVE CORP        1500
# 25  2024-09-19  023160 KS                TK CORPORATION        8500
# 26  2024-09-19  271560 KS  ORION CORP/REPUBLIC OF KOREA        2000
# 27  2024-09-19  316140 KS     WOORI FINANCIAL GROUP INC       10000
# 28  2024-09-20  000660 KS                  SK HYNIX INC         800
# 29  2024-09-20  003030 KS      SEAH STEEL HOLDINGS CORP        1200
# 30  2024-09-20  006040 KS     DONGWON INDUSTRIES CO LTD        2500
# 31  2024-09-20  007340 KS            DN AUTOMOTIVE CORP        4500
# 32  2024-09-20  023160 KS                TK CORPORATION       15000
# 33  2024-09-20  271560 KS  ORION CORP/REPUBLIC OF KOREA        6000
# 34  2024-09-20  316140 KS     WOORI FINANCIAL GROUP INC       18000
#
#     price_average  price_last   net_amount   evaluation          pl     return
# 0   177645.666667    187000.0  160040981.0  168300000.0   8259019.0   5.265726
# 1    88110.280000    102200.0  220495976.0  255500000.0  35004024.0  15.991006
# 2    91495.772727     90700.0  201491991.0  199540000.0  -1951991.0  -0.869737
# 3    13007.988000     13500.0   32552490.0   33750000.0   1197510.0   3.782384
# 4   175209.750000    187000.0  140307968.0  149600000.0   9292032.0   6.729220
# 5    91637.240000    102200.0  229322193.0  255500000.0  26177807.0  11.526711
# 6    88711.333333     90700.0  159840080.0  163260000.0   3419920.0   2.241728
# 7    90969.100000    102200.0   91060069.0  102200000.0  11139931.0  12.345841
# 8   174271.000000    187000.0   87222636.0   93500000.0   6277364.0   7.304141
# 9    93556.611385    102200.0  208933525.0  228008200.0  19074675.0   9.238672
# 10   88238.200000     90700.0   88326438.0   90700000.0   2373562.0   2.789948
# 11  155763.750000    157100.0  187103416.0  188520000.0   1416584.0   0.857870
# 12  167672.000000    187000.0   33567934.0   37400000.0   3832066.0  11.527268
# 13   90417.457143    102200.0  316777561.0  357700000.0  40922439.0  13.031270
# 14   87539.700000     90700.0   87627240.0   90700000.0   3072760.0   3.610133
# 15  169193.000000    157100.0  203234632.0  188520000.0 -14714632.0  -7.147459
# 16  174357.714286    187000.0   61086225.0   65450000.0   4363775.0   7.250775
# 17   92685.933333    102200.0  139167929.0  153300000.0  14132071.0  10.264844
# 18   89337.428571     90700.0  125197472.0  126980000.0   1782528.0   1.525197
# 19  162684.416667    157100.0  195416521.0  188520000.0  -6896521.0  -3.432668
# 20  171938.857143    187000.0   60238779.0   65450000.0   5211221.0   8.759592
# 21   92786.400000    102200.0  139318780.0  153300000.0  13981220.0  10.145452
# 22   88994.642857     90700.0  124717092.0  126980000.0   2262908.0   1.916247
# 23  179751.359084    187000.0  125771846.0  130713000.0   4941154.0   4.032593
# 24   95794.600000    102200.0  143835592.0  153300000.0   9464408.0   6.686598
# 25   14075.971765     14520.0  119765406.0  123420000.0   3654594.0   3.154512
# 26   90117.200000     90700.0  180414634.0  181400000.0    985366.0   0.646713
# 27   15728.972000     15650.0  157447010.0  156500000.0   -947010.0  -0.502080
# 28  157177.625000    157100.0  125867842.0  125680000.0   -187842.0  -0.049387
# 29  185050.583333    187000.0  222282761.0  224400000.0   2117239.0   1.053451
# 30   30808.260000     30850.0   77097671.0   77125000.0     27329.0   0.135483
# 31  102093.444444    102200.0  459879920.0  459900000.0     20080.0   0.104371
# 32   14427.932667     14520.0  216635409.0  217800000.0   1164591.0   0.638119
# 33   90870.500000     90700.0  545768223.0  544200000.0  -1568223.0  -0.187630
# 34   15758.318889     15650.0  283933390.0  281700000.0  -2233390.0  -0.687376

# %%
holdings = Holdings()
# Out:
# - set (date, index) = (2024-09-02, None)
# - net_amount: 614581438.0
# - set (date, index) = (2024-09-05, None)
# - net_amount: 529470241.0
# - set (date, index) = (2024-09-06, None)
# - net_amount: 91060069.0
# - set (date, index) = (2024-09-09, None)
# - net_amount: 384482599.0
# - set (date, index) = (2024-09-10, None)
# - net_amount: 625076151.0
# - set (date, index) = (2024-09-12, None)
# - net_amount: 528686258.0
# - set (date, index) = (2024-09-13, None)
# - net_amount: 519691172.0
# - set (date, index) = (2024-09-19, None)
# - net_amount: 727234488.0
# - set (date, index) = (2024-09-20, None)
# - net_amount: 1931465216.0

# %%
df = holdings.list
df.columns.name = get_today()
df
# Out:
# 2024-09-20                          name  num_shares    net_amount  \
# ticker
# 007340 KS             DN AUTOMOTIVE CORP       20731  1.948792e+09
# 271560 KS   ORION CORP/REPUBLIC OF KOREA       16800  1.513383e+09
# 003030 KS       SEAH STEEL HOLDINGS CORP        4999  8.905191e+08
# 000660 KS                   SK HYNIX INC        4400  7.116224e+08
# 316140 KS      WOORI FINANCIAL GROUP INC       28000  4.413804e+08
# 023160 KS                 TK CORPORATION       23500  3.364008e+08
# 006040 KS      DONGWON INDUSTRIES CO LTD        2500  7.709767e+07
# 282690 KS   DONG AH TIRE & RUBBER CO LTD        2500  3.255249e+07
#
# 2024-09-20    evaluation    return     weight
# ticker
# 007340 KS   2.118708e+09  8.719078  10.282567
# 271560 KS   1.523760e+09  0.685671   7.395149
# 003030 KS   9.348130e+08  4.973938   4.536857
# 000660 KS   6.912400e+08 -2.864217   3.354743
# 316140 KS   4.382000e+08 -0.720558   2.126683
# 023160 KS   3.412200e+08  1.432572   1.656017
# 006040 KS   7.712500e+07  0.035447   0.374305
# 282690 KS   3.375000e+07  3.678705   0.163796

# %%
df['weight'] = 100*df['evaluation']/nav_latest.nav_krw
df
# Out:
#                                    name  num_shares    net_amount  \
# ticker
# 007340 KS            DN AUTOMOTIVE CORP       20731  1.948792e+09
# 271560 KS  ORION CORP/REPUBLIC OF KOREA       16800  1.513383e+09
# 003030 KS      SEAH STEEL HOLDINGS CORP        4999  8.905191e+08
# 000660 KS                  SK HYNIX INC        4400  7.116224e+08
# 316140 KS     WOORI FINANCIAL GROUP INC       28000  4.413804e+08
# 023160 KS                TK CORPORATION       23500  3.364008e+08
# 006040 KS     DONGWON INDUSTRIES CO LTD        2500  7.709767e+07
# 282690 KS  DONG AH TIRE & RUBBER CO LTD        2500  3.255249e+07
#
#              evaluation    return     weight
# ticker
# 007340 KS  2.118708e+09  8.719078  10.282567
# 271560 KS  1.523760e+09  0.685671   7.395149
# 003030 KS  9.348130e+08  4.973938   4.536857
# 000660 KS  6.912400e+08 -2.864217   3.354743
# 316140 KS  4.382000e+08 -0.720558   2.126683
# 023160 KS  3.412200e+08  1.432572   1.656017
# 006040 KS  7.712500e+07  0.035447   0.374305
# 282690 KS  3.375000e+07  3.678705   0.163796

# %%
nav_latest = acc.nav.iloc[-1]
nav_latest
# Out:
# cash_krw        1.444604e+10
# stock_krw       6.158816e+09
# nav_krw         2.060486e+10
# weight_cash     7.010988e+01
# weight_stock    2.989012e+01
# Name: 2024-09-20, dtype: float64

# %%
trd = Trade()
trd.transactions[0].df_sellbuy
# Out:
# - set (date, index) = (2024-09-20, -1)
# - net_amount: 1931465216.0
#                ticker num_shares currency  price_executed      amount
# date
# 2024-09-20  000660 KS         10   /  KRW        156400.0   1564000.0
# 2024-09-20  000660 KS         34   /  KRW        156500.0   5321000.0
# 2024-09-20  000660 KS         75   /  KRW        156600.0  11745000.0
# 2024-09-20  000660 KS         71   /  KRW        156700.0  11125700.0
# 2024-09-20  000660 KS         98   /  KRW        156800.0  15366400.0
# 2024-09-20  000660 KS         33   /  KRW        156900.0   5177700.0
# 2024-09-20  000660 KS         16   /  KRW        157000.0   2512000.0
# 2024-09-20  000660 KS        193   /  KRW        157100.0  30320300.0
# 2024-09-20  000660 KS         21   /  KRW        157200.0   3301200.0
# 2024-09-20  000660 KS         23   /  KRW        157300.0   3617900.0
# 2024-09-20  000660 KS         12   /  KRW        157400.0   1888800.0
# 2024-09-20  000660 KS          8   /  KRW        157500.0   1260000.0
# 2024-09-20  000660 KS         48   /  KRW        157600.0   7564800.0
# 2024-09-20  000660 KS         30   /  KRW        157700.0   4731000.0
# 2024-09-20  000660 KS         25   /  KRW        157800.0   3945000.0
# 2024-09-20  000660 KS          5   /  KRW        157900.0    789500.0
# 2024-09-20  000660 KS         12   /  KRW        158000.0   1896000.0
# 2024-09-20  000660 KS         15   /  KRW        158100.0   2371500.0
# 2024-09-20  000660 KS          2   /  KRW        158200.0    316400.0
# 2024-09-20  000660 KS         17   /  KRW        158300.0   2691100.0
# 2024-09-20  000660 KS         52   /  KRW        158400.0   8236800.0

# %%
df = cash.merge(eval, how='outer', right_index=True, left_index=True)
df['cash_usd'] = df['cash_usd'].ffill()
df['cash_krw'] = df['cash_krw'].ffill()
df['evaluation_usd'] = df['evaluation_usd'].fillna(0)
df['evaluation_krw'] = df['evaluation_krw'].fillna(0)
df['nav_usd'] = df['cash_usd'] + df['evaluation_usd']
df['nav_krw'] = df['cash_krw'] + df['evaluation_krw']
df
# Out:
#                 cash_usd      cash_krw  evaluation_usd  evaluation_krw  \
# date
# 2024-09-01  1.533081e+07  2.050955e+10    0.000000e+00    0.000000e+00
# 2024-09-02  1.487160e+07  1.990340e+10    4.576830e+05    6.125400e+08
# 2024-09-03  1.487160e+07  1.990340e+10    4.668492e+05    6.264650e+08
# 2024-09-04  1.487160e+07  1.990340e+10    4.586597e+05    6.125400e+08
# 2024-09-05  1.447486e+07  1.931742e+10    8.602900e+05    1.148100e+09
# 2024-09-06  1.440665e+07  1.923287e+10    9.215730e+05    1.230300e+09
# 2024-09-09  1.411865e+07  1.884839e+10    1.226554e+06    1.637450e+09
# 2024-09-10  1.411865e+07  1.884839e+10    1.174477e+06    1.578497e+09
# 2024-09-11  1.411865e+07  1.884839e+10    1.188567e+06    1.593036e+09
# 2024-09-12  1.411865e+07  1.884839e+10    1.219643e+06    1.636761e+09
# 2024-09-13  1.411865e+07  1.884839e+10    1.212909e+06    1.617474e+09
# 2024-09-19  1.411865e+07  1.884839e+10    1.256614e+06    1.670103e+09
# 2024-09-20  1.411865e+07  1.884839e+10    1.309099e+06    1.739858e+09
#
#                  nav_usd       nav_krw
# date
# 2024-09-01  1.533081e+07  2.050955e+10
# 2024-09-02  1.532928e+07  2.051594e+10
# 2024-09-03  1.533845e+07  2.052987e+10
# 2024-09-04  1.533026e+07  2.051594e+10
# 2024-09-05  1.533515e+07  2.046552e+10
# 2024-09-06  1.532822e+07  2.046317e+10
# 2024-09-09  1.534520e+07  2.048584e+10
# 2024-09-10  1.529312e+07  2.042689e+10
# 2024-09-11  1.530721e+07  2.044143e+10
# 2024-09-12  1.533829e+07  2.048515e+10
# 2024-09-13  1.533155e+07  2.046587e+10
# 2024-09-19  1.537526e+07  2.051850e+10
# 2024-09-20  1.542774e+07  2.058825e+10

# %%
df.filter(regex='krw')
# Out:
#                 cash_krw  evaluation_krw       nav_krw
# date
# 2024-09-01  2.050955e+10    0.000000e+00  2.050955e+10
# 2024-09-02  1.990340e+10    6.125400e+08  2.051594e+10
# 2024-09-03  1.990340e+10    6.264650e+08  2.052987e+10
# 2024-09-04  1.990340e+10    6.125400e+08  2.051594e+10
# 2024-09-05  1.931742e+10    1.148100e+09  2.046552e+10
# 2024-09-06  1.923287e+10    1.230300e+09  2.046317e+10
# 2024-09-09  1.884839e+10    1.637450e+09  2.048584e+10
# 2024-09-10  1.884839e+10    1.578497e+09  2.042689e+10
# 2024-09-11  1.884839e+10    1.593036e+09  2.044143e+10
# 2024-09-12  1.884839e+10    1.636761e+09  2.048515e+10
# 2024-09-13  1.884839e+10    1.617474e+09  2.046587e+10
# 2024-09-19  1.884839e+10    1.670103e+09  2.051850e+10
# 2024-09-20  1.884839e+10    1.739858e+09  2.058825e+10

# %%
df = acc.get_timeseries_nav(currency='krw')
df
# Out:
#                 cash_krw     stock_krw       nav_krw  weight_cash  \
# date
# 2024-09-01  2.050955e+10  0.000000e+00  2.050955e+10   100.000000
# 2024-09-02  1.990340e+10  6.125400e+08  2.051594e+10    97.014322
# 2024-09-03  1.990340e+10  6.264650e+08  2.052987e+10    96.956346
# 2024-09-04  1.990340e+10  6.125400e+08  2.051594e+10    97.008141
# 2024-09-05  1.931742e+10  1.148100e+09  2.046552e+10    94.390077
# 2024-09-06  1.923287e+10  1.230300e+09  2.046317e+10    93.987736
# 2024-09-09  1.884839e+10  1.637450e+09  2.048584e+10    92.006918
# 2024-09-10  1.835038e+10  2.200527e+09  2.055091e+10    89.292314
# 2024-09-11  1.835038e+10  2.223656e+09  2.057404e+10    89.165330
# 2024-09-12  1.779439e+10  2.821491e+09  2.061588e+10    86.313993
# 2024-09-13  1.716266e+10  3.297064e+09  2.045972e+10    83.885095
# 2024-09-19  1.637751e+10  4.076298e+09  2.045380e+10    80.070711
# 2024-09-20  1.444604e+10  6.158816e+09  2.060486e+10    70.109882
#
#             weight_stock
# date
# 2024-09-01      0.000000
# 2024-09-02      2.985678
# 2024-09-03      3.043654
# 2024-09-04      2.991859
# 2024-09-05      5.609923
# 2024-09-06      6.012264
# 2024-09-09      7.993082
# 2024-09-10     10.707686
# 2024-09-11     10.834670
# 2024-09-12     13.686007
# 2024-09-13     16.114905
# 2024-09-19     19.929289
# 2024-09-20     29.890118

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_nav(df_nav):
    df = df_nav

    fig, ax = plt.subplots(figsize=(12, 6))

    ax.fill_between(df.index, 0, df['cash_krw'], label='Cash', alpha=0.5)
    ax.fill_between(df.index, df['cash_krw'], df['nav_krw'], label='Stock', alpha=0.5)

    ax.plot(df.index, df['nav_krw'], label='NAV', color='red', linewidth=2)

    ax.set_title('Cash, Stock, and NAV over time')
    ax.set_xlabel('Date')
    ax.set_ylabel('Amount (KRW)')
    ax.legend(loc='lower right')

    ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: format(int(x/1e9), ',')))

    ax.grid(True, linestyle='--', alpha=0.7)

    plt.xticks(rotation=45)
    fig.autofmt_xdate()

    plt.tight_layout()
    plt.show()

    return None
# Out:
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %%
df.filter(regex='krw').plot(figsize=(10, 6))
# Out:
# <Axes: xlabel='date'>

# %%
df.filter(regex='usd').plot(figsize=(10, 6))
# Out:
# <Axes: xlabel='date'>

# %%
frame = acc.frame
frame
# Out:
#             initial_balance_usd
# date
# 2024-09-01           15330806.5

# %%
amounts = acc.trades.timeseries_amount
amounts
# Out:
#             amount_order  total_amount_order
# date
# 2024-09-02   614581438.0        6.145814e+08
# 2024-09-05   529470241.0        1.144052e+09
# 2024-09-06    91060069.0        1.235112e+09
# 2024-09-09   384482599.0        1.619594e+09

# %%
frame = acc.frame
amounts = acc.trades.timeseries_amount
df = frame.merge(amounts[['amount_order']], how='outer', left_index=True, right_index=True)
df['initial_balance_usd'] = df['initial_balance_usd'].fillna(method='ffill')
df['amount_order'] = df['amount_order'].fillna(0)
df['usdkrw'] = df.index.map(get_usdkrw_of_date)
df['amount_usd'] = df['amount_order'] / df['usdkrw']
df['cash_usd'] = df['initial_balance_usd'] - df['amount_usd'].cumsum()
df['cash_krw'] = df['cash_usd'] * df['usdkrw']
cols_to_keep = ['cash_usd', 'cash_krw']
df = df[cols_to_keep]
df
# Out:
# /var/folders/_1/0byqfsn56tzdr_b7z00g95xw0000gn/T/ipykernel_80174/1488149704.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['initial_balance_usd'] = df['initial_balance_usd'].fillna(method='ffill')
#                 cash_usd      cash_krw
# date
# 2024-09-01  1.533081e+07  2.050955e+10
# 2024-09-02  1.487160e+07  1.990340e+10
# 2024-09-05  1.447486e+07  1.931742e+10
# 2024-09-06  1.440665e+07  1.923287e+10
# 2024-09-09  1.411865e+07  1.884839e+10

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = frame.merge(amounts[['amount_usd']], how='outer', left_index=True, right_index=True)
#       2 df['amount_usd'] = df['amount_usd'].fillna(0)
#       3 df['balance_usd'] = df['balance_usd'].ffill()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['amount_usd'], dtype='object')] are in the [columns]"

# %%
cash = df[['cash_usd']]

# %%
acc.trades.timeseries_amount
# Out:
#             amount_order  total_amount_order
# date
# 2024-09-02   614581438.0        6.145814e+08
# 2024-09-05   529470241.0        1.144052e+09
# 2024-09-06    91060069.0        1.235112e+09
# 2024-09-09   384482599.0        1.619594e+09

# %%
acc.trades.timeseries_evaluation
# Out:
#             evaluation: 2024-09-02  evaluation: 2024-09-05  \
# date
# 2024-09-02               612540000                     0.0
# 2024-09-03               626465000                     0.0
# 2024-09-04               612540000                     0.0
# 2024-09-05               617490000             530610000.0
# 2024-09-06               613320000             526580000.0
# 2024-09-09               621840000             535100000.0
# 2024-09-10               601220000             515810000.0
# 2024-09-11               605520000             520160000.0
# 2024-09-12               621880000             534990000.0
# 2024-09-13               615260000             528720000.0
# 2024-09-19               633940000             546110000.0
#
#             evaluation: 2024-09-06  evaluation: 2024-09-09  total_evaluation
# date
# 2024-09-02                     0.0                     0.0      6.125400e+08
# 2024-09-03                     0.0                     0.0      6.264650e+08
# 2024-09-04                     0.0                     0.0      6.125400e+08
# 2024-09-05                     0.0                     0.0      1.148100e+09
# 2024-09-06              90400000.0                     0.0      1.230300e+09
# 2024-09-09              94200000.0             386310200.0      1.637450e+09
# 2024-09-10              89900000.0             371566900.0      1.578497e+09
# 2024-09-11              91800000.0             375555800.0      1.593036e+09
# 2024-09-12              93900000.0             385990900.0      1.636761e+09
# 2024-09-13              92400000.0             381094400.0      1.617474e+09
# 2024-09-19              95900000.0             394152900.0      1.670103e+09

# %%
acc.cash
# Out:
#                 cash_krw
# date
# 2024-09-01  2.050955e+10
# 2024-09-02  1.990340e+10
# 2024-09-05  1.931742e+10
# 2024-09-06  1.923287e+10
# 2024-09-09  1.884839e+10
# 2024-09-20  1.876439e+10

# %%
acc.today
# Out:
# {'date': '2024-09-20',
#  'cash_krw': 18764386202.515495,
#  'nav_krw': 20434489102.515495,
#  'eval_krw': 1670102900.0,
#  'cash_usd': 14118645.801524017,
#  'eval_usd': 1256614.047628005,
#  'nav_usd': 15375259.849152021}
